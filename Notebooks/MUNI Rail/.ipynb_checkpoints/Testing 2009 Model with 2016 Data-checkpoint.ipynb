# %%
import pandas as pd
import seaborn as sns
import numpy as np
import statsmodels.api as smf
from matplotlib import pyplot as plt

pd.set_option('display.max_columns', 500)

# %matplotlib inline

# %%
estimate = pd.read_csv('E:/Transit-Casa-Alex/MUNI Rail/Output/Modeling/2016/Quarter_Data.csv',thousands = ',')

# %%
estimate['FREQ_S'] = 1 / (estimate['HEADWAY_S'] / 60.0)

estimate['NUM_BUS_STOPS'] = estimate['NUM_BUS_STOPS'] - 1

drop = ['Unnamed: 0',
'STOP_LAT_x',
'STOP_LON_x',
'STOP_LAT_y',
'STOP_LON_y',
'geometry',
'index_right',
'ALAND',
'AWATER',
'COUNTYFP',
'NAME',
'TRACTCE',
'Id',
'Id2',
'Geography',
'geometry_e',
'geometry_f',
'STOP_LAT',
'STOP_LON',
'FID_1']

estimate = estimate.drop(drop,axis = 1)


change = ['BART_FROMS','BART_TOS','ON_BUS','OFF_BUS','CALTRAIN_OFF','CALTRAIN_ON','NUM_BUS_STOPS']

for column in change:
    estimate[column] = estimate[column].fillna(0)
    
    
change = ['Average Hourly Price',
'Count_',
'EDHLTH_RAC_SCALED',
'EDHLTH_WAC_SCALED',
'EMP_RAC_SCALED',
'EMP_WAC_SCALED',
'HOUSING16_SCALED',
'LEISER_RAC_SCALED',
'LEISER_WAC_SCALED',
'OTHER_RAC_SCALED',
'OTHER_WAC_SCALED',
'HH_0VEH',
'INC_0_15',
'INC_100P',
'INC_15_50',
'INC_50_100',
'PRICE12HR',
'PRICE1HR',
'PRICE2HR',
'PRICE3HR',
'PRICE4HR',
'PRICEDAY',
'PRICEDAYDISCOUNT',
'RETAIL_RAC_SCALED',
'RETAIL_WAC_SCALED',
'HH_SIZE',
'parking_rate']

changes = ['PARK_HOURLY_AVG_ON',
'TRANSBAY',
'EDHLTH_RAC_DEN',
'EDHLTH_WAC_DEN',
'EMP_RAC_DEN',
'EMP_WAC_DEN',
'HOUSING_16_DEN',
'LEISER_RAC_DEN',
'LEISER_WAC_DEN',
'OTHER_RAC_DEN',
'OTHER_WAC_DEN',
'SHR_HH_0VEH',
'SHR_INCOME_0_15',
'SHR_INCOME_100P',
'SHR_INCOME_15_50',
'SHR_INCOME_50_100',
'PARK_12_HR_OFF_PUB',
'PARK_1_HR_OFF_PUB',
'PARK_2_HR_OFF_PUB',
'PARK_3_HR_OFF_PUB',
'PARK_4_HR_OFF_PUB',
'PARK_DAY_OFF_PUB',
'PARK_DAY_DISCOUNT_OFF_PUB',
'RETAIL_RAC_DEN',
'RETAIL_WAC_DEN',
'AVG_HH_SIZE',
'PARKING_RATE_OFF_RESIDENTIAL']


def rename_column(old_columns,new_columns,df):
    num = len(old_columns)
    count = 0
    while count < num:
        df[new_columns[count]] = df[old_columns[count]]
        df = df.drop(old_columns[count],axis = 1)
        
        count = count + 1
    return df


estimate = rename_column(change,changes,estimate)

estimate['EXCLUDE'] = 0
check = ['EMP_WAC_DEN','LEISER_RAC_DEN','LEISER_WAC_DEN','OTHER_RAC_DEN','OTHER_WAC_DEN','RETAIL_RAC_DEN','RETAIL_WAC_DEN',' Total Boardings ']
count = 0
for column in check:
    while count < len(estimate[column]):
        if np.isnan(estimate[column][count]):
                print('Got One')
                estimate['EXCLUDE'][count] = 1
        count = count + 1
        
data = estimate[estimate['EXCLUDE'] == 0]

data['AVG_RIDE'] = (data[' Total Boardings '] + data[' Total Alightings '])/2
data['LOG_RIDERS'] = np.log(data.AVG_RIDE + 1)
data['AVG_BART'] = (data['BART_FROMS']+data['BART_TOS'])/2
data['CALTRAIN_AVG'] = (data.CALTRAIN_OFF + data.CALTRAIN_ON)/2
data['MUNI_BUS_AVG'] = (data.ON_BUS + data.OFF_BUS)/2


log_change = ['PARK_12_HR_OFF_PUB',   
'PARK_1_HR_OFF_PUB',
'PARK_2_HR_OFF_PUB',
'PARK_3_HR_OFF_PUB',
'PARK_4_HR_OFF_PUB',
'AVG_BART',
'AVG_HH_SIZE',
'BART_FROMS',
'BART_TOS',
'CALTRAIN_AVG',
'CALTRAIN_OFF',
'CALTRAIN_ON',
'PARK_DAY_DISCOUNT_OFF_PUB',
'PARK_DAY_OFF_PUB',
'DWELL_S',
'EDD_EMP',
'EDHLTH_RAC_DEN',
'EDHLTH_WAC_DEN',
'EMP_RAC_DEN',
'EMP_WAC_DEN',
'FREQ_S',
'HEADWAY_S',
'HH_DEN_ACS',
'PARK_HOURLY_AVG_ON',
'HOUSING_16_DEN',
'HU_DEN_ACS',
'LEISER_RAC_DEN',
'LEISER_WAC_DEN',
'NUM_BUS_STOPS',
'OCC_RATE',
'OFF_BUS',
'ON_BUS',
'ONTIME5_BUS',
'OTHER_RAC_DEN',
'OTHER_WAC_DEN',
'PARKING_RATE_OFF_RESIDENTIAL',
'POP_ACS',
'RETAIL_RAC_DEN',
'RETAIL_WAC_DEN',
'RUNSPEED_S',
'RUNTIME_S',
'SHR_HH_0VEH',
'SHR_INCOME_0_15',
'SHR_INCOME_100P',
'SHR_INCOME_15_50',
'SHR_INCOME_50_100',
'TOTSPEED_S',
'TOTTIME_S',
'VAC_RATE']

for column in log_change:
    data[column + '_LOG'] = data[column].apply(lambda value: np.log(value + 1))

def check(value):
    if value == 'N':
        value = ''
    else:
        value = value
    return value


data['DIST_FROM_LAST_STOP'] = data['SERVMILES_S'] / (data['FREQ_S']*24)

data['DIST_FROM_LAST_STOP_LOG'] = data['DIST_FROM_LAST_STOP'].apply(lambda value: np.log(value + 1))

data['SERVMILES_S_LOG'] = data['SERVMILES_S'].apply(lambda x : np.log(x + 1))

data['CAL_STATION'] = np.where(data['CALTRAIN_AVG'] > 0,1,0)

#this should be 0.5 for quarter mile buffers and .2 for tenth
data['CLOSE_STOP'] = np.where(data['DIST_FROM_LAST_STOP'] < 0.5, 1,0)


data['EOL_SOL'] = data['EOL'] + data['SOL']

# %%
estimate.columns
# Out:
# Index(['STOP_ID', 'ROUTE_SHORT_NAME', 'DIR', 'STOP NAME_x', 'Stop Latitude',
#        ' Total Alightings ', 'Stop Longitude', ' Total Boardings ', 'SEQ',
#        'HEADWAY_S', 'EOL', 'SOL', 'DWELL_S', 'RUNTIME_S', 'TOTTIME_S',
#        'SERVMILES_S', 'RUNSPEED_S', 'TOTSPEED_S', 'STOP NAME_y', 'POP_ACS',
#        'HU_ACS', 'VAC_RATE', 'OCC_RATE', 'POPDEN_ACS', 'HH_DEN_ACS',
#        'HU_DEN_ACS', 'BART_TOS', 'BART_FROMS', 'CALTRAIN_OFF', 'CALTRAIN_ON',
#        'ON_BUS', 'HEADWAY_S_BUS', 'ONTIME5_BUS', 'OFF_BUS', 'NUM_BUS_STOPS',
#        'EDD_EMP', 'geometry_d', 'DIR_e', 'DWELL_S_e', 'EOL_e', 'HEADWAY_S_e',
#        'ROUTE_SHOR', 'RUNSPEED_S_e', 'RUNTIME_S_e', 'SEQ_e', 'SERVMILES_',
#        'SOL_e', 'STOP_NAME', 'Stop_Latit', 'Stop_Longi', 'Sum_ID',
#        'Sum_OBJECT', 'Sum_Value', 'TOTSPEED_S_e', 'TOTTIME_S_e', 'Total_Ali',
#        'Total_Boa', 'FREQ_S', 'PARK_HOURLY_AVG_ON', 'TRANSBAY',
#        'EDHLTH_RAC_DEN', 'EDHLTH_WAC_DEN', 'EMP_RAC_DEN', 'EMP_WAC_DEN',
#        'HOUSING_16_DEN', 'LEISER_RAC_DEN', 'LEISER_WAC_DEN', 'OTHER_RAC_DEN',
#        'OTHER_WAC_DEN', 'SHR_HH_0VEH', 'SHR_INCOME_0_15', 'SHR_INCOME_100P',
#        'SHR_INCOME_15_50', 'SHR_INCOME_50_100', 'PARK_12_HR_OFF_PUB',
#        'PARK_1_HR_OFF_PUB', 'PARK_2_HR_OFF_PUB', 'PARK_3_HR_OFF_PUB',
#        'PARK_4_HR_OFF_PUB', 'PARK_DAY_OFF_PUB', 'PARK_DAY_DISCOUNT_OFF_PUB',
#        'RETAIL_RAC_DEN', 'RETAIL_WAC_DEN', 'AVG_HH_SIZE',
#        'PARKING_RATE_OFF_RESIDENTIAL', 'EXCLUDE'],
#       dtype='object')

# %%
data.head()
# Out:
#    STOP_ID ROUTE_SHORT_NAME  DIR            STOP NAME_x  Stop Latitude  \
# 0     3212                N    1    9th Ave & Irving St      37.763912
# 1     3266                L    0  15th Ave & Taraval St      37.743122
# 2     3267                L    1  15th Ave & Taraval St      37.743070
# 3     3268                L    0    15th Ave & Ulloa St      37.741524
# 4     3269                L    1    15th Ave & Ulloa St      37.741486
#
#     Total Alightings   Stop Longitude   Total Boardings    SEQ  HEADWAY_S  \
# 0               292.4     -122.466240             1046.3  16.0  21.853338
# 1               313.8     -122.471300              119.6  13.0  10.237869
# 2                92.3     -122.471405              240.7  18.0  17.298743
# 3               233.4     -122.471190               16.5  12.0  10.236721
# 4                23.3     -122.471300               90.4  19.0  17.299891
#
#    EOL  SOL  DWELL_S  RUNTIME_S  TOTTIME_S  SERVMILES_S  RUNSPEED_S  \
# 0  0.0  0.0      0.0     132.00     132.00       16.836        7.65
# 1  0.0  0.0      0.0      86.19      86.19       13.420        9.34
# 2  0.0  0.0      0.0     122.91     122.91       15.372        7.50
# 3  0.0  0.0      0.0     125.00     125.00       18.178        8.73
# 4  0.0  0.0      0.0      96.43      96.43       13.298        8.27
#
#    TOTSPEED_S            STOP NAME_y  POP_ACS  HU_ACS  VAC_RATE  OCC_RATE  \
# 0        7.65    9th Ave & Irving St   4467.0  2154.0  0.020891  0.979109
# 1        9.34  15th Ave & Taraval St   5681.0  2402.0  0.104080  0.895920
# 2        7.50  15th Ave & Taraval St   5681.0  2402.0  0.104080  0.895920
# 3        8.73    15th Ave & Ulloa St   5681.0  2402.0  0.104080  0.895920
# 4        8.27    15th Ave & Ulloa St   5681.0  2402.0  0.104080  0.895920
#
#    POPDEN_ACS  HH_DEN_ACS  HU_DEN_ACS  BART_TOS  BART_FROMS  CALTRAIN_OFF  \
# 0   50.827004    23.99690   24.508925       0.0         0.0           0.0
# 1   18.492738     7.00517    7.818968       0.0         0.0           0.0
# 2   18.492738     7.00517    7.818968       0.0         0.0           0.0
# 3   18.492738     7.00517    7.818968       0.0         0.0           0.0
# 4   18.492738     7.00517    7.818968       0.0         0.0           0.0
#
#    CALTRAIN_ON       ON_BUS  HEADWAY_S_BUS  ONTIME5_BUS      OFF_BUS  \
# 0          0.0  2986.630246      18.876169     0.586788  2680.466284
# 1          0.0  1203.674750      25.612057     0.582901  1133.604612
# 2          0.0  1214.728563      25.044111     0.581925  1153.997674
# 3          0.0    97.482449      25.286225     0.577345   152.712278
# 4          0.0    60.937324      25.620236     0.585526    64.305224
#
#    NUM_BUS_STOPS  EDD_EMP                                         geometry_d  \
# 0             10     1857  POLYGON ((-122.4601537301617 37.76401438951365...
# 1              8     1319  POLYGON ((-122.4652114399149 37.74322565099801...
# 2              8     1318  POLYGON ((-122.4653194445662 37.74317065657591...
# 3             18     2132  POLYGON ((-122.465106570708 37.74162664560667,...
# 4             18     2091  POLYGON ((-122.4652145742128 37.7415856511843,...
#
#    DIR_e  DWELL_S_e  EOL_e  HEADWAY_S_e ROUTE_SHOR  RUNSPEED_S_e  RUNTIME_S_e  \
# 0      1        0.0    0.0    21.853338          N          7.65       132.00
# 1      0        0.0    0.0    10.237869          L          9.34        86.19
# 2      1        0.0    0.0    17.298743          L          7.50       122.91
# 3      0        0.0    0.0    10.236721          L          8.73       125.00
# 4      1        0.0    0.0    17.299891          L          8.27        96.43
#
#    SEQ_e  SERVMILES_  SOL_e              STOP_NAME  Stop_Latit  Stop_Longi  \
# 0   16.0      16.836    0.0    9th Ave & Irving St   37.763912 -122.466240
# 1   13.0      13.420    0.0  15th Ave & Taraval St   37.743122 -122.471300
# 2   18.0      15.372    0.0  15th Ave & Taraval St   37.743070 -122.471405
# 3   12.0      18.178    0.0    15th Ave & Ulloa St   37.741524 -122.471190
# 4   19.0      13.298    0.0    15th Ave & Ulloa St   37.741486 -122.471300
#
#    Sum_ID  Sum_OBJECT  Sum_Value  TOTSPEED_S_e  TOTTIME_S_e  Total_Ali  \
# 0       0           0          0          7.65       132.00      292.4
# 1       0           0          0          9.34        86.19      313.8
# 2       0           0          0          7.50       122.91       92.3
# 3       0           0          0          8.73       125.00      233.4
# 4       0           0          0          8.27        96.43       23.3
#
#    Total_Boa    FREQ_S  PARK_HOURLY_AVG_ON  TRANSBAY  EDHLTH_RAC_DEN  \
# 0     1046.3  2.745576               200.0         0      760.885760
# 1      119.6  5.860595               200.0         0      431.765859
# 2      240.7  3.468460               200.0         0      430.661147
# 3       16.5  5.861252               200.0         0      389.539094
# 4       90.4  3.468230               200.0         0      390.140718
#
#    EDHLTH_WAC_DEN  EMP_RAC_DEN   EMP_WAC_DEN  HOUSING_16_DEN  LEISER_RAC_DEN  \
# 0    20558.021890  2876.034865  22804.189271     2644.833441      353.704460
# 1      292.041899  1972.939397    681.402754     1329.898435      241.825853
# 2      296.194732  1955.106101    693.839840     1333.969511      239.991096
# 3      267.689828  1725.383630    995.177141     1276.389665      222.412842
# 4      267.061453  1718.621634    969.133442     1279.866120      221.917212
#
#    LEISER_WAC_DEN  OTHER_RAC_DEN  OTHER_WAC_DEN  SHR_HH_0VEH  SHR_INCOME_0_15  \
# 0     1044.497097    1618.102324    1072.017157     0.223803         0.067330
# 1       41.291253    1165.282502     218.589524     0.090613         0.034851
# 2       46.082336    1152.205129     222.616297     0.090613         0.034851
# 3      156.867944     993.595656     386.372386     0.090613         0.034851
# 4      145.773424     988.206471     376.328514     0.090613         0.034851
#
#    SHR_INCOME_100P  SHR_INCOME_15_50  SHR_INCOME_50_100  PARK_12_HR_OFF_PUB  \
# 0         0.469417          0.132290           0.330963                 NaN
# 1         0.694703          0.134758           0.135688                 NaN
# 2         0.694703          0.134758           0.135688                 NaN
# 3         0.694703          0.134758           0.135688                 NaN
# 4         0.694703          0.134758           0.135688                 NaN
#
#    PARK_1_HR_OFF_PUB  PARK_2_HR_OFF_PUB  PARK_3_HR_OFF_PUB  PARK_4_HR_OFF_PUB  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#    PARK_DAY_OFF_PUB  PARK_DAY_DISCOUNT_OFF_PUB  RETAIL_RAC_DEN  \
# 0               NaN                        NaN      143.342320
# 1               NaN                        NaN      134.065183
# 2               NaN                        NaN      132.248728
# 3               NaN                        NaN      119.836039
# 4               NaN                        NaN      118.357232
#
#    RETAIL_WAC_DEN  AVG_HH_SIZE  PARKING_RATE_OFF_RESIDENTIAL  EXCLUDE  \
# 0      129.653128     2.118065                      0.802586        0
# 1      129.480078     2.639870                      1.655921        0
# 2      128.946474     2.639870                      1.525376        0
# 3      184.246983     2.639870                      1.655921        0
# 4      179.970051     2.639870                      1.525376        0
#
#    AVG_RIDE  LOG_RIDERS  AVG_BART  CALTRAIN_AVG  MUNI_BUS_AVG  \
# 0    669.35    6.507800       0.0           0.0   2833.548265
# 1    216.70    5.383118       0.0           0.0   1168.639681
# 2    166.50    5.120983       0.0           0.0   1184.363119
# 3    124.95    4.835885       0.0           0.0    125.097364
# 4     56.85    4.057853       0.0           0.0     62.621274
#
#    PARK_12_HR_OFF_PUB_LOG  PARK_1_HR_OFF_PUB_LOG  PARK_2_HR_OFF_PUB_LOG  \
# 0                     NaN                    NaN                    NaN
# 1                     NaN                    NaN                    NaN
# 2                     NaN                    NaN                    NaN
# 3                     NaN                    NaN                    NaN
# 4                     NaN                    NaN                    NaN
#
#    PARK_3_HR_OFF_PUB_LOG  PARK_4_HR_OFF_PUB_LOG  AVG_BART_LOG  \
# 0                    NaN                    NaN           0.0
# 1                    NaN                    NaN           0.0
# 2                    NaN                    NaN           0.0
# 3                    NaN                    NaN           0.0
# 4                    NaN                    NaN           0.0
#
#    AVG_HH_SIZE_LOG  BART_FROMS_LOG  BART_TOS_LOG  CALTRAIN_AVG_LOG  \
# 0         1.137213             0.0           0.0               0.0
# 1         1.291948             0.0           0.0               0.0
# 2         1.291948             0.0           0.0               0.0
# 3         1.291948             0.0           0.0               0.0
# 4         1.291948             0.0           0.0               0.0
#
#    CALTRAIN_OFF_LOG  CALTRAIN_ON_LOG  PARK_DAY_DISCOUNT_OFF_PUB_LOG  \
# 0               0.0              0.0                            NaN
# 1               0.0              0.0                            NaN
# 2               0.0              0.0                            NaN
# 3               0.0              0.0                            NaN
# 4               0.0              0.0                            NaN
#
#    PARK_DAY_OFF_PUB_LOG  DWELL_S_LOG  EDD_EMP_LOG  EDHLTH_RAC_DEN_LOG  \
# 0                   NaN          0.0     7.527256            6.635797
# 1                   NaN          0.0     7.185387            6.070197
# 2                   NaN          0.0     7.184629            6.067641
# 3                   NaN          0.0     7.665285            5.967528
# 4                   NaN          0.0     7.645876            5.969067
#
#    EDHLTH_WAC_DEN_LOG  EMP_RAC_DEN_LOG  EMP_WAC_DEN_LOG  FREQ_S_LOG  \
# 0            9.931055         7.964515        10.034743    1.320575
# 1            5.680316         7.587787         6.525620    1.925794
# 2            5.694388         7.578711         6.543681    1.497044
# 3            5.593558         7.453784         6.903925    1.925890
# 4            5.591216         7.449860         6.877434    1.496992
#
#    HEADWAY_S_LOG  HH_DEN_ACS_LOG  PARK_HOURLY_AVG_ON_LOG  HOUSING_16_DEN_LOG  \
# 0       3.129097        3.218752                5.303305            7.880741
# 1       2.419289        2.080088                5.303305            7.193610
# 2       2.906832        2.080088                5.303305            7.196664
# 3       2.419187        2.080088                5.303305            7.152574
# 4       2.906895        2.080088                5.303305            7.155292
#
#    HU_DEN_ACS_LOG  LEISER_RAC_DEN_LOG  LEISER_WAC_DEN_LOG  NUM_BUS_STOPS_LOG  \
# 0        3.239028            5.871285            6.952248           2.397895
# 1        2.176905            5.492345            3.744580           2.197225
# 2        2.176905            5.484760            3.851898           2.197225
# 3        2.176905            5.409021            5.061759           2.944439
# 4        2.176905            5.406800            4.988890           2.944439
#
#    OCC_RATE_LOG  OFF_BUS_LOG  ON_BUS_LOG  ONTIME5_BUS_LOG  OTHER_RAC_DEN_LOG  \
# 0      0.682647     7.894119    8.002236         0.461712           7.389627
# 1      0.639704     7.034040    7.093965         0.459260           7.061577
# 2      0.639704     7.051854    7.103099         0.458642           7.050300
# 3      0.639704     5.035083    4.589878         0.455743           6.902336
# 4      0.639704     4.179072    4.126123         0.460916           6.896903
#
#    OTHER_WAC_DEN_LOG  PARKING_RATE_OFF_RESIDENTIAL_LOG  POP_ACS_LOG  \
# 0           6.978230                          0.589222     8.404696
# 1           5.391760                          0.976792     8.645059
# 2           5.409932                          0.926390     8.645059
# 3           5.959386                          0.976792     8.645059
# 4           5.933116                          0.926390     8.645059
#
#    RETAIL_RAC_DEN_LOG  RETAIL_WAC_DEN_LOG  RUNSPEED_S_LOG  RUNTIME_S_LOG  \
# 0            4.972188            4.872546        2.157559       4.890349
# 1            4.905757            4.871221        2.336020       4.468090
# 2            4.892218            4.867123        2.140066       4.819555
# 3            4.794435            5.221690        2.275214       4.836282
# 4            4.782121            5.198332        2.226783       4.579134
#
#    SHR_HH_0VEH_LOG  SHR_INCOME_0_15_LOG  SHR_INCOME_100P_LOG  \
# 0         0.201963             0.065161             0.384866
# 1         0.086740             0.034258             0.527507
# 2         0.086740             0.034258             0.527507
# 3         0.086740             0.034258             0.527507
# 4         0.086740             0.034258             0.527507
#
#    SHR_INCOME_15_50_LOG  SHR_INCOME_50_100_LOG  TOTSPEED_S_LOG  TOTTIME_S_LOG  \
# 0              0.124242               0.285902        2.157559       4.890349
# 1              0.126420               0.127238        2.336020       4.468090
# 2              0.126420               0.127238        2.140066       4.819555
# 3              0.126420               0.127238        2.275214       4.836282
# 4              0.126420               0.127238        2.226783       4.579134
#
#    VAC_RATE_LOG  DIST_FROM_LAST_STOP  DIST_FROM_LAST_STOP_LOG  \
# 0      0.020676             0.255502                 0.227535
# 1      0.099012             0.095411                 0.091130
# 2      0.099012             0.184664                 0.169459
# 3      0.099012             0.129224                 0.121531
# 4      0.099012             0.159760                 0.148213
#
#    SERVMILES_S_LOG  CAL_STATION  CLOSE_STOP  EOL_SOL
# 0         2.881219            0           1      0.0
# 1         2.668616            0           1      0.0
# 2         2.795573            0           1      0.0
# 3         2.953764            0           1      0.0
# 4         2.660120            0           1      0.0

# %%
#Run the 2009 Model
# -- Looks pretty good but he muni bus variable is insignificant


mod = smf.formula.ols(formula="LOG_RIDERS \
                       ~ EDD_EMP_LOG \
                       + FREQ_S_LOG \
                       + HOUSING_16_DEN_LOG \
                       + AVG_BART_LOG \
                       + CLOSE_STOP \
                       + EOL_SOL \
                       + MUNI_BUS_AVG \
                       -1",
             data = data)

res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             LOG_RIDERS   R-squared:                       0.989
# Model:                            OLS   Adj. R-squared:                  0.988
# Method:                 Least Squares   F-statistic:                     3652.
# Date:                Mon, 24 Jul 2017   Prob (F-statistic):          4.04e-280
# Time:                        19:25:52   Log-Likelihood:                -290.01
# No. Observations:                 299   AIC:                             594.0
# Df Residuals:                     292   BIC:                             619.9
# Df Model:                           7
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# EDD_EMP_LOG            0.3100      0.037      8.376      0.000       0.237       0.383
# FREQ_S_LOG             0.7381      0.144      5.125      0.000       0.455       1.022
# HOUSING_16_DEN_LOG     0.3316      0.044      7.528      0.000       0.245       0.418
# AVG_BART_LOG          -0.0423      0.020     -2.144      0.033      -0.081      -0.003
# CLOSE_STOP            -0.3232      0.106     -3.060      0.002      -0.531      -0.115
# EOL_SOL                0.4489      0.189      2.370      0.018       0.076       0.822
# MUNI_BUS_AVG        7.479e-06   1.13e-05      0.663      0.508   -1.47e-05    2.97e-05
# ==============================================================================
# Omnibus:                       18.261   Durbin-Watson:                   1.322
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.121
# Skew:                          -0.439   Prob(JB):                     2.13e-06
# Kurtosis:                       4.151   Cond. No.                     3.96e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.96e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#Try the log-log relationship of muni bus variable 
# -- Looks really good, stick with it

data['MUNI_BUS_AVG_LOG'] = data.MUNI_BUS_AVG.apply(lambda x: np.log(1 + x))

mod = smf.formula.ols(formula="LOG_RIDERS \
                       ~ EDD_EMP_LOG \
                       + FREQ_S_LOG \
                       + HOUSING_16_DEN_LOG \
                       + AVG_BART_LOG \
                       + CLOSE_STOP \
                       + EOL_SOL \
                       + MUNI_BUS_AVG_LOG \
                       -1",
             data = data)

res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             LOG_RIDERS   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                     4284.
# Date:                Mon, 24 Jul 2017   Prob (F-statistic):          3.82e-290
# Time:                        19:32:10   Log-Likelihood:                -266.37
# No. Observations:                 299   AIC:                             546.7
# Df Residuals:                     292   BIC:                             572.6
# Df Model:                           7
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# EDD_EMP_LOG            0.2623      0.030      8.715      0.000       0.203       0.322
# FREQ_S_LOG             0.6423      0.131      4.889      0.000       0.384       0.901
# HOUSING_16_DEN_LOG     0.2708      0.040      6.706      0.000       0.191       0.350
# AVG_BART_LOG          -0.0643      0.014     -4.657      0.000      -0.091      -0.037
# CLOSE_STOP            -0.2351      0.098     -2.411      0.017      -0.427      -0.043
# EOL_SOL                0.3324      0.168      1.975      0.049       0.001       0.664
# MUNI_BUS_AVG_LOG       0.1463      0.021      7.109      0.000       0.106       0.187
# ==============================================================================
# Omnibus:                       35.983   Durbin-Watson:                   1.341
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               67.083
# Skew:                          -0.669   Prob(JB):                     2.71e-15
# Kurtosis:                       4.897   Cond. No.                         64.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
bad = []
for num in res.resid:
    if num < -1:
        bad.append(num)
    else:
        bad = bad

# %%
len(bad)
# Out:
# 14

# %%
bad
# Out:
# [-1.2195039268564631,
#  -1.6688917021352019,
#  -1.1477716403259608,
#  -1.0750295212186893,
#  -1.1345481204711145,
#  -1.1701893389170319,
#  -1.0052541960276651,
#  -1.3640138542800955,
#  -1.4983721913155286,
#  -1.424286875644861,
#  -1.2388290670100792,
#  -1.7937873259813131,
#  -1.8797388695843074,
#  -2.9009449295517244]

# %%
bad_index = []

# %%
residual = pd.DataFrame(res.resid)

# %%
outliers = residual[residual[0] < -1]

# %%
outliers.index
# Out:
# Int64Index([4, 11, 13, 51, 53, 83, 100, 157, 166, 167, 170, 201, 202, 306], dtype='int64')

# %%
data['index'] = data.index

# %%
bad = pd.DataFrame()
for outlier in outliers:
    bad = data[data['index'] ==  outlier]
    bad = bad.append(bad)

# %%
bad
# Out:
#    STOP_ID ROUTE_SHORT_NAME  DIR          STOP NAME_x  Stop Latitude  \
# 0     3212                N    1  9th Ave & Irving St      37.763912
# 0     3212                N    1  9th Ave & Irving St      37.763912
#
#     Total Alightings   Stop Longitude   Total Boardings    SEQ  HEADWAY_S  \
# 0               292.4      -122.46624             1046.3  16.0  21.853338
# 0               292.4      -122.46624             1046.3  16.0  21.853338
#
#    EOL  SOL  DWELL_S  RUNTIME_S  TOTTIME_S  SERVMILES_S  RUNSPEED_S  \
# 0  0.0  0.0      0.0      132.0      132.0       16.836        7.65
# 0  0.0  0.0      0.0      132.0      132.0       16.836        7.65
#
#    TOTSPEED_S          STOP NAME_y  POP_ACS  HU_ACS  VAC_RATE  OCC_RATE  \
# 0        7.65  9th Ave & Irving St   4467.0  2154.0  0.020891  0.979109
# 0        7.65  9th Ave & Irving St   4467.0  2154.0  0.020891  0.979109
#
#    POPDEN_ACS  HH_DEN_ACS  HU_DEN_ACS  BART_TOS  BART_FROMS  CALTRAIN_OFF  \
# 0   50.827004     23.9969   24.508925       0.0         0.0           0.0
# 0   50.827004     23.9969   24.508925       0.0         0.0           0.0
#
#    CALTRAIN_ON       ON_BUS  HEADWAY_S_BUS  ONTIME5_BUS      OFF_BUS  \
# 0          0.0  2986.630246      18.876169     0.586788  2680.466284
# 0          0.0  2986.630246      18.876169     0.586788  2680.466284
#
#    NUM_BUS_STOPS  EDD_EMP                                         geometry_d  \
# 0             10     1857  POLYGON ((-122.4601537301617 37.76401438951365...
# 0             10     1857  POLYGON ((-122.4601537301617 37.76401438951365...
#
#    DIR_e  DWELL_S_e  EOL_e  HEADWAY_S_e ROUTE_SHOR  RUNSPEED_S_e  RUNTIME_S_e  \
# 0      1        0.0    0.0    21.853338          N          7.65        132.0
# 0      1        0.0    0.0    21.853338          N          7.65        132.0
#
#    SEQ_e  SERVMILES_  SOL_e            STOP_NAME  Stop_Latit  Stop_Longi  \
# 0   16.0      16.836    0.0  9th Ave & Irving St   37.763912  -122.46624
# 0   16.0      16.836    0.0  9th Ave & Irving St   37.763912  -122.46624
#
#    Sum_ID  Sum_OBJECT  Sum_Value  TOTSPEED_S_e  TOTTIME_S_e  Total_Ali  \
# 0       0           0          0          7.65        132.0      292.4
# 0       0           0          0          7.65        132.0      292.4
#
#    Total_Boa    FREQ_S  PARK_HOURLY_AVG_ON  TRANSBAY  EDHLTH_RAC_DEN  \
# 0     1046.3  2.745576               200.0         0       760.88576
# 0     1046.3  2.745576               200.0         0       760.88576
#
#    EDHLTH_WAC_DEN  EMP_RAC_DEN   EMP_WAC_DEN  HOUSING_16_DEN  LEISER_RAC_DEN  \
# 0     20558.02189  2876.034865  22804.189271     2644.833441       353.70446
# 0     20558.02189  2876.034865  22804.189271     2644.833441       353.70446
#
#    LEISER_WAC_DEN  OTHER_RAC_DEN  OTHER_WAC_DEN  SHR_HH_0VEH  SHR_INCOME_0_15  \
# 0     1044.497097    1618.102324    1072.017157     0.223803          0.06733
# 0     1044.497097    1618.102324    1072.017157     0.223803          0.06733
#
#    SHR_INCOME_100P  SHR_INCOME_15_50  SHR_INCOME_50_100  PARK_12_HR_OFF_PUB  \
# 0         0.469417           0.13229           0.330963                 NaN
# 0         0.469417           0.13229           0.330963                 NaN
#
#    PARK_1_HR_OFF_PUB  PARK_2_HR_OFF_PUB  PARK_3_HR_OFF_PUB  PARK_4_HR_OFF_PUB  \
# 0                NaN                NaN                NaN                NaN
# 0                NaN                NaN                NaN                NaN
#
#    PARK_DAY_OFF_PUB  PARK_DAY_DISCOUNT_OFF_PUB  RETAIL_RAC_DEN  \
# 0               NaN                        NaN       143.34232
# 0               NaN                        NaN       143.34232
#
#    RETAIL_WAC_DEN  AVG_HH_SIZE  PARKING_RATE_OFF_RESIDENTIAL  EXCLUDE  \
# 0      129.653128     2.118065                      0.802586        0
# 0      129.653128     2.118065                      0.802586        0
#
#    AVG_RIDE  LOG_RIDERS  AVG_BART  CALTRAIN_AVG  MUNI_BUS_AVG  \
# 0    669.35      6.5078       0.0           0.0   2833.548265
# 0    669.35      6.5078       0.0           0.0   2833.548265
#
#    PARK_12_HR_OFF_PUB_LOG  PARK_1_HR_OFF_PUB_LOG  PARK_2_HR_OFF_PUB_LOG  \
# 0                     NaN                    NaN                    NaN
# 0                     NaN                    NaN                    NaN
#
#    PARK_3_HR_OFF_PUB_LOG  PARK_4_HR_OFF_PUB_LOG  AVG_BART_LOG  \
# 0                    NaN                    NaN           0.0
# 0                    NaN                    NaN           0.0
#
#    AVG_HH_SIZE_LOG  BART_FROMS_LOG  BART_TOS_LOG  CALTRAIN_AVG_LOG  \
# 0         1.137213             0.0           0.0               0.0
# 0         1.137213             0.0           0.0               0.0
#
#    CALTRAIN_OFF_LOG  CALTRAIN_ON_LOG  PARK_DAY_DISCOUNT_OFF_PUB_LOG  \
# 0               0.0              0.0                            NaN
# 0               0.0              0.0                            NaN
#
#    PARK_DAY_OFF_PUB_LOG  DWELL_S_LOG  EDD_EMP_LOG  EDHLTH_RAC_DEN_LOG  \
# 0                   NaN          0.0     7.527256            6.635797
# 0                   NaN          0.0     7.527256            6.635797
#
#    EDHLTH_WAC_DEN_LOG  EMP_RAC_DEN_LOG  EMP_WAC_DEN_LOG  FREQ_S_LOG  \
# 0            9.931055         7.964515        10.034743    1.320575
# 0            9.931055         7.964515        10.034743    1.320575
#
#    HEADWAY_S_LOG  HH_DEN_ACS_LOG  PARK_HOURLY_AVG_ON_LOG  HOUSING_16_DEN_LOG  \
# 0       3.129097        3.218752                5.303305            7.880741
# 0       3.129097        3.218752                5.303305            7.880741
#
#    HU_DEN_ACS_LOG  LEISER_RAC_DEN_LOG  LEISER_WAC_DEN_LOG  NUM_BUS_STOPS_LOG  \
# 0        3.239028            5.871285            6.952248           2.397895
# 0        3.239028            5.871285            6.952248           2.397895
#
#    OCC_RATE_LOG  OFF_BUS_LOG  ON_BUS_LOG  ONTIME5_BUS_LOG  OTHER_RAC_DEN_LOG  \
# 0      0.682647     7.894119    8.002236         0.461712           7.389627
# 0      0.682647     7.894119    8.002236         0.461712           7.389627
#
#    OTHER_WAC_DEN_LOG  PARKING_RATE_OFF_RESIDENTIAL_LOG  POP_ACS_LOG  \
# 0            6.97823                          0.589222     8.404696
# 0            6.97823                          0.589222     8.404696
#
#    RETAIL_RAC_DEN_LOG  RETAIL_WAC_DEN_LOG  RUNSPEED_S_LOG  RUNTIME_S_LOG  \
# 0            4.972188            4.872546        2.157559       4.890349
# 0            4.972188            4.872546        2.157559       4.890349
#
#    SHR_HH_0VEH_LOG  SHR_INCOME_0_15_LOG  SHR_INCOME_100P_LOG  \
# 0         0.201963             0.065161             0.384866
# 0         0.201963             0.065161             0.384866
#
#    SHR_INCOME_15_50_LOG  SHR_INCOME_50_100_LOG  TOTSPEED_S_LOG  TOTTIME_S_LOG  \
# 0              0.124242               0.285902        2.157559       4.890349
# 0              0.124242               0.285902        2.157559       4.890349
#
#    VAC_RATE_LOG  DIST_FROM_LAST_STOP  DIST_FROM_LAST_STOP_LOG  \
# 0      0.020676             0.255502                 0.227535
# 0      0.020676             0.255502                 0.227535
#
#    SERVMILES_S_LOG  CAL_STATION  CLOSE_STOP  EOL_SOL  MUNI_BUS_AVG_LOG  index
# 0         2.881219            0           1      0.0          7.949638      0
# 0         2.881219            0           1      0.0          7.949638      0

# %%
data.to_csv('E:/Transit-Casa-Alex/MUNI Rail/Output/Modeling/2016/Final_Model_Data.csv')

# %%
sns.distplot(res.resid)

# %%
plt.scatter(res.resid.index,res.resid)

# %%
smf.graphics.qqplot(res.resid,line = 'q')

# %%
smf.graphics.influence_plot(res)

# %%
min(res.resid)
# Out:
# -2.9009449295517244

# %%
max(res.resid)
# Out:
# 1.3396010402107486

# %%
dropped = data[['LOG_RIDERS','EDD_EMP_LOG','STOP_ID','AVG_RIDE','FREQ_S_LOG','EOL_SOL','HOUSING_16_DEN_LOG','MUNI_BUS_AVG','AVG_BART_LOG','CLOSE_STOP']].dropna()

# %%
dropped.to_csv('E:/Transit-Casa-Alex/MUNI Rail/Output/Modeling/2016/Final_Model_Data_Post_Drop.csv')
