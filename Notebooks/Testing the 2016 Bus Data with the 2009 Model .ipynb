# %%
import pandas as pd
import seaborn as sns
import numpy as np
import statsmodels.api as smf
from matplotlib import pyplot as plt

pd.set_option('display.max_columns', 500)


# %matplotlib inline

# %%
data = pd.read_csv('E:/Transit-Casa-Alex/Output/Modeling/2016/Final_Model_Data_Post_Drop.csv',thousands = ',')
len(data)
# Out:
# 5254

# %%
# Run 204
# Try the 2009 model with the 2016 bus data 

mod = smf.formula.ols(formula="LOG_RIDERS \
                       ~ EDD_EMP_LOG \
                       + FREQ_S_LOG \
                       + EOL_SOL \
                       + HOUSING_16_DEN_LOG \
                       + SHR_INCOME_100P \
                       + PARK_HOURLY_AVG_ON_LOG \
                       + ONTIME5 \
                       + AVG_BART_LOG \
                       + CLOSE_STOP \
                       + LIMITED \
                       + EXPRESS \
                       + TRANSBAY \
                       + MUNI_RAIL_AVG ",
               data = data)

res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             LOG_RIDERS   R-squared:                       0.555
# Model:                            OLS   Adj. R-squared:                  0.554
# Method:                 Least Squares   F-statistic:                     502.8
# Date:                Fri, 28 Jul 2017   Prob (F-statistic):               0.00
# Time:                        11:41:14   Log-Likelihood:                -7389.3
# No. Observations:                5254   AIC:                         1.481e+04
# Df Residuals:                    5240   BIC:                         1.490e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -0.9568      0.130     -7.337      0.000      -1.212      -0.701
# EDD_EMP_LOG                0.1432      0.010     14.330      0.000       0.124       0.163
# FREQ_S_LOG                 2.5776      0.046     56.337      0.000       2.488       2.667
# EOL_SOL                    0.5333      0.059      8.995      0.000       0.417       0.650
# HOUSING_16_DEN_LOG         0.1121      0.013      8.778      0.000       0.087       0.137
# SHR_INCOME_100P           -1.0918      0.080    -13.726      0.000      -1.248      -0.936
# PARK_HOURLY_AVG_ON_LOG     0.0404      0.007      5.703      0.000       0.026       0.054
# ONTIME5                    0.7356      0.095      7.756      0.000       0.550       0.922
# AVG_BART_LOG               0.0531      0.011      4.981      0.000       0.032       0.074
# CLOSE_STOP                -1.0847      0.048    -22.692      0.000      -1.178      -0.991
# LIMITED                   -0.5552      0.081     -6.896      0.000      -0.713      -0.397
# EXPRESS                   -1.3669      0.056    -24.578      0.000      -1.476      -1.258
# TRANSBAY                   0.0633      0.170      0.372      0.710      -0.270       0.397
# MUNI_RAIL_AVG          -3.413e-06   8.62e-06     -0.396      0.692   -2.03e-05    1.35e-05
# ==============================================================================
# Omnibus:                      137.468   Durbin-Watson:                   1.406
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              164.961
# Skew:                          -0.341   Prob(JB):                     1.51e-36
# Kurtosis:                       3.537   Cond. No.                     2.67e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.67e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
sns.distplot(res.resid)

# %%
plt.scatter(res.resid.index,res.resid)

# %%
smf.graphics.qqplot(res.resid,line = 'q')

# %%
smf.graphics.influence_plot(res)
