# %%
import numpy as np
import pandas as pd
import csv
import bokeh.plotting as bk
import datetime
import os

# %%
hdffile = "E:/Transit_Casa/Output/sfmuni_monthly_ts.h5"
store = pd.HDFStore(hdffile)
#df = store.get('rs_tod')

# %%
store
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: E:/Transit_Casa/Output/sfmuni_monthly_ts.h5
# /rs_day                  frame_table  (typ->appendable,nrows->301137,ncols->57,indexers->[index],dc->[MONTH,DOW,AGENCY_ID,ROUTE_SHORT_NAME,DIR,SEQ,NUMDAYS,OBSDAYS,TRIP_STOPS,OBS_TRIP_STOPS,WGT_TRIP_STOPS,STOP_ID,ROUTE_LONG_NAME,ROUTE_TYPE,TRIP_HEADSIGN,HEADWAY_S,FARE,STOPNAME,STOPNAME_AVL,STOP_LAT,STOP_LON,EOL,SOL,TIMEPOINT,ARRIVAL_TIME_DEV,DEPARTURE_TIME_DEV,DWELL_S,DWELL,RUNTIME_S,RUNTIME,TOTTIME_S,TOTTIME,SERVMILES_S,SERVMILES,RUNSPEED_S,RUNSPEED,TOTSPEED_S,TOTSPEED,ONTIME5,ON,OFF,LOAD_ARR,LOAD_DEP,PASSMILES,PASSHOURS,WAITHOURS,FULLFARE_REV,PASSDELAY_DEP,PASSDELAY_ARR,RDBRDNGS,DOORCYCLES,WHEELCHAIR,BIKERACK,CAPACITY,VC,CROWDED,CROWDHOURS])
# ...

# %%
df_22 = store.get('rs_tod', where="'ROUTE_SHORT_NAME'='22'")
len(df_22)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-e91d1f0be703> in <module>()
# ----> 1 df_22 = store.get('rs_tod', where="'ROUTE_SHORT_NAME'='22'")
#       2 len(df_22)
#
# TypeError: get() got an unexpected keyword argument 'where'

# %%
store.get?

# %%
df22 = store.select('rs_tod', where="ROUTE_SHORT_NAME='22'")
len(df22)
# Out:
# 34973

# %%
df22.head()
# Out:
#          MONTH  DOW        TOD AGENCY_ID ROUTE_SHORT_NAME  DIR  SEQ  NUMDAYS  \
# 857 2009-06-01    1  0300-0559     SFMTA               22    0    1       12
# 858 2009-06-01    1  0300-0559     SFMTA               22    0    2       12
# 859 2009-06-01    1  0300-0559     SFMTA               22    0    3       12
# 860 2009-06-01    1  0300-0559     SFMTA               22    0    4       12
# 861 2009-06-01    1  0300-0559     SFMTA               22    0    5       12
#
#      OBSDAYS  TRIP_STOPS    ...      PASSDELAY_DEP  PASSDELAY_ARR  RDBRDNGS  \
# 857        2           2    ...                0.0            0.0       0.0
# 858        2           2    ...                0.0            0.0       0.0
# 859        2           2    ...                0.0            0.0       0.0
# 860        2           2    ...                0.0            0.0       0.0
# 861        2           2    ...                0.0            0.0       0.0
#
# ...

# %% [raw]
# groups = df22.groupby(by=['MONTH', 'DOW', 'TOD', 'DIR', 'SEQ'])
# len(groups)

# %%
groups = df22.groupby(by=['DOW', 'TOD', 'DIR', 'SEQ', 'STOP_NAME'])
len(groups)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4154)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4018)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12368)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12322)()
#
# KeyError: 'STOP_NAME'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-6b7925d4ea04> in <module>()
# ...

# %%
groups

# %%
agg = df22.groupby(by=['DOW', 'TOD', 'DIR', 'SEQ', 'STOPNAME']).count()
len(agg)
# Out:
# 904

# %%
table = agg['OBSDAYS'].unstack(level=1)
table.to_csv('missing_months_obs.csv')
table
# Out:
# TOD                                         0300-0559  0600-0859  0900-1359  \
# DOW DIR SEQ STOPNAME
# 1   0   1   Fillmore St & Bay St                 53.0       53.0       53.0
#         2   Fillmore St & North Point St         52.0       52.0       52.0
#         3   Fillmore St & Beach St               52.0       52.0       52.0
#         4   Fillmore St & Jefferson St           52.0       52.0       52.0
#         5   Fillmore St & Beach St               52.0       52.0       52.0
#         6   Fillmore St & Cervantes Blvd         52.0       52.0       52.0
#         7   Fillmore St & Chestnut St            53.0       53.0       53.0
#         8   Fillmore St & Lombard St             52.0       52.0       52.0
#         9   Union St & Fillmore St               52.0       52.0       52.0
#         10  Steiner St & Union St                53.0       53.0       53.0
#         11  Steiner St & Green St                52.0       52.0       52.0
# ...
