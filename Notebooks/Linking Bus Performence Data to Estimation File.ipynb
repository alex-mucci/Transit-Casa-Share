# %%
import csv as csv
import pandas as pd
import numpy as np
import geopandas as gp
# %matplotlib inline
pd.set_option('display.height', 100)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 100)
# Out:
# height has been deprecated.

# %%
store = pd.HDFStore("E:/Transit_Casa/Output/sfmuni_monthly_ts.h5")

bus = store.get('stop_day')
bus = bus[bus["MONTH"].isin(pd.date_range('2009-01-01', '2009-12-01'))]

# %%
data = gp.read_file('E:/Transit-Casa-Alex/Output/Employment/Tenth of a Mile/Employment_Tenth_Intersect.shp')

# %%
employment.plot()

# %%
employment.head()
# Out:
#    ALAND10  AREA_FT  BUFF_DIST  EDHEALTH     GEOID10  Join_Count  LEISURE  ORIG_FID   OTHER  \
# 0   599776   498583      528.0    4779.0  2147483647          22    324.0         0   488.0
# 1   699953   133897      528.0      17.0  2147483647          16     48.0         1    65.0
# 2   154591    93888      528.0      37.0  2147483647          13     28.0         2   227.0
# 3  1058346    88441      528.0       3.0  2147483647          11      3.0         3    40.0
# 4   169458   280930      528.0     115.0  2147483647          13    399.0         4  7869.0
#
#    RETAIL  STOP_ID   STOP_LAT    STOP_LON  TARGET_FID  TOTAL_EMP  \
# 0   199.0      390  37.721190 -122.475096           0     5790.0
# 1    14.0      392  37.765159 -122.477210           1      144.0
# 2   144.0      660  37.723914 -122.435387           2      436.0
# 3     0.0      913  37.719192 -122.425802           3       46.0
# 4    81.0     3001  37.788530 -122.396044           4     8464.0
#
# ...

# %%
bus.head()
# Out:
#   AGENCY_ID  ARRIVAL_TIME_DEV_09  BIKERACK_09  CAPACITY_09  CROWDED_09  CROWDHOURS_09  \
# 0     SFMTA             0.934607     0.219167  2877.954545    0.060312      21.520189
# 1     SFMTA             3.542134     0.399840  1093.909091    0.031747       4.584047
# 2     SFMTA             1.770704     0.000000  1505.818182    0.000000       0.000000
# 3     SFMTA             4.582892     0.226340  1437.882353    0.000000       0.000000
# 4     SFMTA             2.883022     0.150224   804.681818    0.012185       0.929952
#
#    DEPARTURE_TIME_DEV_09  DOORCYCLES_09    DWELL_09  EOL_09  FARE_09  FULLFARE_REV_09  \
# 0               1.720306     475.422985  143.684262     0.0      2.0      4491.483310
# 1               3.865522     211.275633   38.722240     0.0      2.0       852.616110
# 2               1.777142       4.660845    1.116657     0.0      2.0         4.250322
# 3               4.908949      90.349191    0.000000     1.0      2.0        86.313190
# ...

# %%
print(len(bus))
len(employment)
# Out:
# 3645
# 3744

# %%
employment.head()
# Out:
#    ALAND10  AREA_FT  BUFF_DIST  EDHEALTH     GEOID10  Join_Count  LEISURE  ORIG_FID   OTHER  \
# 0   599776   498583      528.0    4779.0  2147483647          22    324.0         0   488.0
# 1   699953   133897      528.0      17.0  2147483647          16     48.0         1    65.0
# 2   154591    93888      528.0      37.0  2147483647          13     28.0         2   227.0
# 3  1058346    88441      528.0       3.0  2147483647          11      3.0         3    40.0
# 4   169458   280930      528.0     115.0  2147483647          13    399.0         4  7869.0
#
#    RETAIL  STOP_ID   STOP_LAT    STOP_LON  TARGET_FID  TOTAL_EMP  \
# 0   199.0      390  37.721190 -122.475096           0     5790.0
# 1    14.0      392  37.765159 -122.477210           1      144.0
# 2   144.0      660  37.723914 -122.435387           2      436.0
# 3     0.0      913  37.719192 -122.425802           3       46.0
# 4    81.0     3001  37.788530 -122.396044           4     8464.0
#
# ...

# %%
employment['Employment_DEN'] = (employment['TOTAL_EMP'] / employment['ALAND10'])/0.000247105
employment['RETAIL_DEN'] = (employment['RETAIL'] / employment['ALAND10'])/0.000247105
employment['LEISURE_DEN'] = (employment['LEISURE'] / employment['ALAND10'])/0.000247105
employment['OTHER_DEN'] = (employment['OTHER'] / employment['ALAND10'])/0.000247105
employment['EDHEALTH_DEN'] = (employment['EDHEALTH'] / employment['ALAND10'])/0.000247105

# %%
estimation_file = pd.merge(bus,employment, on = 'STOP_ID', how = 'left')

# %%
estimation_file.head()
# Out:
#        MONTH  DOW AGENCY_ID  STOP_ID  NUMDAYS  OBSDAYS  TRIP_STOPS  OBS_TRIP_STOPS  \
# 0 2009-06-01    1     SFMTA      390       12       12         306              51
# 1 2009-06-01    1     SFMTA      392       12       12         121              17
# 2 2009-06-01    1     SFMTA      660       12       12         134              27
# 3 2009-06-01    1     SFMTA      913       12        8          91              10
# 4 2009-06-01    1     SFMTA     3001       12       11          63              12
#
#    WGT_TRIP_STOPS  HEADWAY_S  FARE                    STOPNAME                    STOPNAME_AVL  \
# 0      277.742329  21.795987   2.0  19th Avenue &  Holloway St       19TH AVE&HOLLOWAY AVE NE-
# 1      113.259977  14.226891   2.0     19TH AVE &  LINCOLN WAY       19TH AVE & LINCOLN WAY SE
# 2      136.417078   9.327634   2.0   MISSION ST & OCEAN AVENUE       MISSION ST&OCEAN AVE -MI/
# ...

# %%
len(estimation_file)
# Out:
# 3645

# %%
buffers = gp.read_file('E:\Transit-Casa-Alex\Output\Buffers/Buffers_Tenth.shp')

# %%
len(buffers)
# Out:
# 3744

# %%
pop = gp.read_file('E:/Transit-Casa-Alex/Input/2010 Population (Blocks)/Population_Houses_Blocks.shp')

# %%
pop.head()
# Out:
#   BLOCKCE        BLOCKID10 COUNTYFP10  HOUSING10 PARTFLG  POP10 STATEFP10 TRACTCE10  \
# 0    3028  060750313023028        075         33       N    116        06    031302
# 1    6025  060750255006025        075          1       N      1        06    025500
# 2    1010  060750261001010        075         64       N    237        06    026100
# 3    1001  060750201001001        075          0       N      0        06    020100
# 4    2006  060750178022006        075        145       N    196        06    017802
#
#                                             geometry
# 0  POLYGON ((-122.469306 37.712526, -122.468748 3...
# 1  POLYGON ((-122.442387 37.725793, -122.443066 3...
# 2  POLYGON ((-122.439127 37.720972, -122.439382 3...
# 3  POLYGON ((-122.418618 37.773053, -122.418855 3...
# 4  POLYGON ((-122.413587 37.77466, -122.413161 37...

# %%
pop['BLOCKID10'] = pop.BLOCKID10.apply(lambda row: int(row))

# %%
for column in pop.columns:
    print(column)
# Out:
# BLOCKCE
# BLOCKID10
# COUNTYFP10
# HOUSING10
# PARTFLG
# POP10
# STATEFP10
# TRACTCE10
# geometry

# %%
l = ['STATEFP10',
'TRACTCE10',
'COUNTYFP10',
'BLOCKCE',]

# %%
for column in l:
    pop = pop.drop(column, axis = 1)

# %%
pop.head()
# Out:
#         BLOCKID10  HOUSING10 PARTFLG  POP10
# 0  60750313023028         33       N    116
# 1  60750255006025          1       N      1
# 2  60750261001010         64       N    237
# 3  60750201001001          0       N      0
# 4  60750178022006        145       N    196

# %%
pop.to_file('E:/Transit-Casa-Alex/Input/2010 Population (Blocks)/Population_Houses_Blocks.shp', driver = 'ESRI Shapefile')

# %%
# Out:
#   AGENCY_ID  ARRIVAL_TIME_DEV_09  BIKERACK_09  CAPACITY_09  CROWDED_09  CROWDHOURS_09  \
# 0     SFMTA             0.934607     0.219167  2877.954545    0.060312      21.520189
# 1     SFMTA             3.542134     0.399840  1093.909091    0.031747       4.584047
# 2     SFMTA             1.770704     0.000000  1505.818182    0.000000       0.000000
# 3     SFMTA             4.582892     0.226340  1437.882353    0.000000       0.000000
# 4     SFMTA             2.883022     0.150224   804.681818    0.012185       0.929952
#
#    DEPARTURE_TIME_DEV_09  DOORCYCLES_09    DWELL_09  EOL_09  FARE_09  FULLFARE_REV_09  \
# 0               1.720306     475.422985  143.684262     0.0      2.0      4491.483310
# 1               3.865522     211.275633   38.722240     0.0      2.0       852.616110
# 2               1.777142       4.660845    1.116657     0.0      2.0         4.250322
# 3               4.908949      90.349191    0.000000     1.0      2.0        86.313190
# ...

# %%
estimation_file.to_csv('E:\Transit-Casa-Alex\Output\Modeling\Estimation_File_09.csv')

# %%
estimation_file.head()
# Out:
#        MONTH  DOW AGENCY_ID  STOP_ID  NUMDAYS  OBSDAYS  TRIP_STOPS  OBS_TRIP_STOPS  \
# 0 2009-06-01    1     SFMTA      390       12       12         306              51
# 1 2009-06-01    1     SFMTA      392       12       12         121              17
# 2 2009-06-01    1     SFMTA      660       12       12         134              27
# 3 2009-06-01    1     SFMTA      913       12        8          91              10
# 4 2009-06-01    1     SFMTA     3001       12       11          63              12
#
#    WGT_TRIP_STOPS  HEADWAY_S  FARE                    STOPNAME                    STOPNAME_AVL  \
# 0      277.742329  21.795987   2.0  19th Avenue &  Holloway St       19TH AVE&HOLLOWAY AVE NE-
# 1      113.259977  14.226891   2.0     19TH AVE &  LINCOLN WAY       19TH AVE & LINCOLN WAY SE
# 2      136.417078   9.327634   2.0   MISSION ST & OCEAN AVENUE       MISSION ST&OCEAN AVE -MI/
# ...

# %%
#Change month to a string so that it can be wrote as a shapefile
estimation_file['MONTH'] = estimation_file.MONTH.astype(str)

# %%
estimate = gp.GeoDataFrame(estimation_file)

# %%
estimate.head()
# Out:
#         MONTH  DOW AGENCY_ID  STOP_ID  NUMDAYS  OBSDAYS  TRIP_STOPS  OBS_TRIP_STOPS  \
# 0  2009-06-01    1     SFMTA      390       12       12         306              51
# 1  2009-06-01    1     SFMTA      392       12       12         121              17
# 2  2009-06-01    1     SFMTA      660       12       12         134              27
# 3  2009-06-01    1     SFMTA      913       12        8          91              10
# 4  2009-06-01    1     SFMTA     3001       12       11          63              12
#
#    WGT_TRIP_STOPS  HEADWAY_S  FARE                    STOPNAME                    STOPNAME_AVL  \
# 0      277.742329  21.795987   2.0  19th Avenue &  Holloway St       19TH AVE&HOLLOWAY AVE NE-
# 1      113.259977  14.226891   2.0     19TH AVE &  LINCOLN WAY       19TH AVE & LINCOLN WAY SE
# 2      136.417078   9.327634   2.0   MISSION ST & OCEAN AVENUE       MISSION ST&OCEAN AVE -MI/
# ...

# %%
estimate.to_file('Estimate_File.shp',driver = 'ESRI Shapefile')

# %% [markdown]
# ## Changing the population and housing unit data to per acre

# %%
estimate = gp.read_file('E:\Transit-Casa-Alex\Output\Estimate_File.shp')

# %%
estimate.head()
# Out:
#   AGENCY_ID  ALAND10  AREA_FT  ARRIVAL_TI  BIKERACK_0  BUFF_DIST   CAPACITY_0  CROWDED_09  \
# 0     SFMTA   599776   498583    0.934607    0.219167      528.0  2877.954545    0.060312
# 1     SFMTA   699953   133897    3.542134    0.399840      528.0  1093.909091    0.031747
# 2     SFMTA   154591    93888    1.770704    0.000000      528.0  1505.818182    0.000000
# 3     SFMTA  1058346    88441    4.582892    0.226340      528.0  1437.882353    0.000000
# 4     SFMTA   169458   280930    2.883022    0.150224      528.0   804.681818    0.012185
#
#    CROWDHOURS  DEPARTURE_  DOORCYCLES    DWELL_09  EDHEALTH  EDHEALTH_D  EOL_09  Employment  \
# 0   21.520189    1.720306  475.422985  143.684262    4779.0   32.245299     0.0   39.066810
# 1    4.584047    3.865522  211.275633   38.722240      17.0    0.098288     0.0    0.832553
# 2    0.000000    1.777142    4.660845    1.116657      37.0    0.968581     0.0   11.413550
# ...

# %%
estimate['HOUSING10_DEN'] = (estimate['HOUSING10'] / estimate['ALAND10'])/0.000247105
estimate['POP10_DEN'] = (estimate['POP10'] / estimate['ALAND10'])/0.000247105

# %%
estimate.head()
# Out:
#   AGENCY_ID  ALAND10  AREA_FT  ARRIVAL_TI  BIKERACK_0  BUFF_DIST   CAPACITY_0  CROWDED_09  \
# 0     SFMTA   599776   498583    0.934607    0.219167      528.0  2877.954545    0.060312
# 1     SFMTA   699953   133897    3.542134    0.399840      528.0  1093.909091    0.031747
# 2     SFMTA   154591    93888    1.770704    0.000000      528.0  1505.818182    0.000000
# 3     SFMTA  1058346    88441    4.582892    0.226340      528.0  1437.882353    0.000000
# 4     SFMTA   169458   280930    2.883022    0.150224      528.0   804.681818    0.012185
#
#    CROWDHOURS  DEPARTURE_  DOORCYCLES    DWELL_09  EDHEALTH  EDHEALTH_D  EOL_09  Employment  \
# 0   21.520189    1.720306  475.422985  143.684262    4779.0   32.245299     0.0   39.066810
# 1    4.584047    3.865522  211.275633   38.722240      17.0    0.098288     0.0    0.832553
# 2    0.000000    1.777142    4.660845    1.116657      37.0    0.968581     0.0   11.413550
# ...

# %%
estimate.to_file('Estimate_File.shp', driver = 'ESRI Shapefile')

# %%
estimate.to_csv('E:\Transit-Casa-Alex\Output\Modeling\Estimation File.csv')
