# %%
import numpy as np
import pandas as pd
import csv
import bokeh.plotting as bk
import datetime
import os
pd.set_option('display.max_columns', None)

# %%
hdffile = "E:/Transit_Casa/Output/sfmuni_monthly_ts.h5"
store = pd.HDFStore(hdffile)
df = store.select('rs_tod', where = "MONTH = Timestamp('2009-09-01')")

# %%
hdffile = "E:/Transit_Casa/Output/sfmuni_monthly_ts.h5"
store = pd.HDFStore(hdffile)
df2 = store.select('rs_tod', where = "MONTH = Timestamp('2013-09-01')")

# %%
df.MONTH.unique()
# Out:
# array(['2009-09-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
df2.MONTH.unique()
# Out:
# array(['2013-09-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
df.to_csv('E:\Transit_Casa\Alex\C_Drive\Maps\df.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-21-f33b64d78c15> in <module>()
# ----> 1 df.to_csv('E:\Transit_Casa\Alex\C_Drive\Maps\df.csv')
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal, **kwds)
#    1342                                      doublequote=doublequote,
#    1343                                      escapechar=escapechar, decimal=decimal)
# -> 1344         formatter.save()
#    1345
#    1346         if path_or_buf is None:
#
# C:\Anaconda\lib\site-packages\pandas\formats\format.py in save(self)
#    1524             f = _get_handle(self.path_or_buf, self.mode,
# ...

# %%
#df = df2.sort_values('TOD')
df.head()
# Out:
#            MONTH  DOW        TOD AGENCY_ID ROUTE_SHORT_NAME  DIR  SEQ  \
# 95232 2009-09-01    1  0300-0559     SFMTA                1    0    1
# 95233 2009-09-01    1  0300-0559     SFMTA                1    0    2
# 95234 2009-09-01    1  0300-0559     SFMTA                1    0    3
# 95235 2009-09-01    1  0300-0559     SFMTA                1    0    5
# 95236 2009-09-01    1  0300-0559     SFMTA                1    0    6
#
#        NUMDAYS  OBSDAYS  TRIP_STOPS  OBS_TRIP_STOPS  WGT_TRIP_STOPS  STOP_ID  \
# 95232       22        9           2               0        2.772635     5056
# 95233       22        9           2               0        2.772635     5336
# 95234       22        9           2               0        2.772635     4445
# 95235       22        9           2               0        2.772635     6294
# 95236       22        9           2               0        2.772635     6290
#
#       ROUTE_LONG_NAME  ROUTE_TYPE     TRIP_HEADSIGN  HEADWAY_S  FARE  \
# ...

# %%
#df2 = df2.sort_values('TOD')
df2.head()
# Out:
#              MONTH  DOW        TOD AGENCY_ID ROUTE_SHORT_NAME  DIR  SEQ  \
# 1478448 2013-09-01    1  0300-0559     SFMTA                1    0    4
# 1478449 2013-09-01    1  0300-0559     SFMTA                1    0    5
# 1478450 2013-09-01    1  0300-0559     SFMTA                1    0    6
# 1478451 2013-09-01    1  0300-0559     SFMTA                1    0    7
# 1478452 2013-09-01    1  0300-0559     SFMTA                1    0    8
#
#          NUMDAYS  OBSDAYS  TRIP_STOPS  OBS_TRIP_STOPS  WGT_TRIP_STOPS  \
# 1478448       20       10           2               0        2.932909
# 1478449       20       10           2               0        2.932909
# 1478450       20       10           2               0        2.932909
# 1478451       20       10           2               0        2.932909
# 1478452       20       10           2               0        2.932909
#
#          STOP_ID ROUTE_LONG_NAME  ROUTE_TYPE          TRIP_HEADSIGN  \
# ...

# %%
df3 = pd.DataFrame(columns = ['ON_09', 'ON_13','Diff'])

# %%
df_final = pd.merge(df,df2, on = ['DOW','TOD','AGENCY_ID','ROUTE_SHORT_NAME','DIR','SEQ'])

# %%
df2[df2['TOD'] == '2013-09-01']
df.head()
# Out:
# Empty DataFrame
# Columns: [MONTH, DOW, TOD, AGENCY_ID, ROUTE_SHORT_NAME, DIR, SEQ, NUMDAYS, OBSDAYS, TRIP_STOPS, OBS_TRIP_STOPS, WGT_TRIP_STOPS, STOP_ID, ROUTE_LONG_NAME, ROUTE_TYPE, TRIP_HEADSIGN, HEADWAY_S, FARE, STOPNAME, STOPNAME_AVL, STOP_LAT, STOP_LON, EOL, SOL, TIMEPOINT, ARRIVAL_TIME_DEV, DEPARTURE_TIME_DEV, DWELL_S, DWELL, RUNTIME_S, RUNTIME, TOTTIME_S, TOTTIME, SERVMILES_S, SERVMILES, RUNSPEED_S, RUNSPEED, TOTSPEED_S, TOTSPEED, ONTIME5, ON, OFF, LOAD_ARR, LOAD_DEP, PASSMILES, PASSHOURS, WAITHOURS, FULLFARE_REV, PASSDELAY_DEP, PASSDELAY_ARR, RDBRDNGS, DOORCYCLES, WHEELCHAIR, BIKERACK, CAPACITY, VC, CROWDED, CROWDHOURS]
# Index: []

# %%
len(df_final)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-0bbf96632137> in <module>()
# ----> 1 len(df_final)
#
# NameError: name 'df_final' is not defined

# %%
df3['ON_09'] = df_final['ON_x']

# %%
df3['ON_13'] = df_final['ON_y']

# %%
df3['Diff'] = df_final['ON_13']-df_final['ON_09']

# %%
df3['ROUTE_SHORT_NAME'] = df_final['ROUTE_SHORT_NAME']

# %%
df3.to_csv('Route_Table.csv')

# %%
df3[df3['ROUTE_SHORT_NAME'] == '2'].to_csv('E:\Transit_Casa\Alex\Output\Performence Report\Route 2 (Sutter)/Route2_table.csv')

# %%
df3[df3['ROUTE_SHORT_NAME'] == '3'].to_csv('E:\Transit_Casa\Alex\Output\Performence Report\Route 3 (Presidio-Sutter/Route3_table.csv')

# %%
df3[df3['ROUTE_SHORT_NAME'] == '14'].to_csv('E:\Transit_Casa\Alex\Output\Performence Report\Route 14 (Mission)/Route14_table.csv')

# %%
df3[df3['ROUTE_SHORT_NAME'] == '22'].to_csv('E:\Transit_Casa\Alex\Output\Performence Report\Route 22 (Fillmore)/Route22_table.csv')

# %%
df3[df3['ROUTE_SHORT_NAME'] == '49'].to_csv('E:\Transit_Casa\Alex\Output\Performence Report\Route 49 (Van Ness and Mission)/Route49_table.csv')
