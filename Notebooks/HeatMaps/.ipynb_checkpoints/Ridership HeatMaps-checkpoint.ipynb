# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm, matplotlib.font_manager as fm
import seaborn as sns
sns.set(color_codes=False)
import geopandas as gp
from scipy import stats, integrate
import datetime

pd.set_option('display.max_columns', 500)

# %%
store = pd.HDFStore("E:/Transit_Casa/Output/sfmuni_monthly_ts.h5")
store.items
bus = store.get('rs_tod')

# %%
bus09.to_csv('bus.csv')

# %%
len(bus)
# Out:
# 1565864

# %%
bus09 = bus[bus["MONTH"].isin(pd.date_range('2009-01-01', '2009-12-01'))]

# %%
len(bus09)
# Out:
# 124247

# %%
bus09.MONTH.unique()
# Out:
# array(['2009-06-01T00:00:00.000000000', '2009-07-01T00:00:00.000000000',
#        '2009-08-01T00:00:00.000000000', '2009-09-01T00:00:00.000000000',
#        '2009-10-01T00:00:00.000000000', '2009-11-01T00:00:00.000000000',
#        '2009-12-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
bus09.head()
# Out:
#        MONTH  DOW        TOD AGENCY_ID ROUTE_SHORT_NAME  DIR  SEQ  NUMDAYS  \
# 0 2009-06-01    1  0300-0559     SFMTA                1    0    1       12
# 1 2009-06-01    1  0300-0559     SFMTA                1    0    2       12
# 2 2009-06-01    1  0300-0559     SFMTA                1    0    3       12
# 3 2009-06-01    1  0300-0559     SFMTA                1    0    5       12
# 4 2009-06-01    1  0300-0559     SFMTA                1    0    6       12
#
#    OBSDAYS  TRIP_STOPS  OBS_TRIP_STOPS  WGT_TRIP_STOPS  STOP_ID  \
# 0        6           2               0        2.810885     5056
# 1        6           2               0        2.810885     5336
# 2        6           2               0        2.810885     4445
# 3        6           2               0        2.810885     6294
# 4        6           2               0        2.810885     6290
#
#   ROUTE_LONG_NAME  ROUTE_TYPE     TRIP_HEADSIGN  HEADWAY_S  FARE  \
# 0      CALIFORNIA           3  Geary & 33rd Av.       30.0   2.0
# 1      CALIFORNIA           3  Geary & 33rd Av.       30.0   2.0
# 2      CALIFORNIA           3  Geary & 33rd Av.       30.0   2.0
# 3      CALIFORNIA           3  Geary & 33rd Av.       30.0   2.0
# 4      CALIFORNIA           3  Geary & 33rd Av.       30.0   2.0
#
#                        STOPNAME               STOPNAME_AVL   STOP_LAT  \
# 0        Howard St & Main St     HOWARD ST&MAIN ST E-NS/BZ  37.790410
# 1         Main St & Market St    MAIN ST&MARKET ST NE-MB/B  37.792530
# 2    Drumm St & California St    DRUMM ST&CALIFORNIA ST NE  37.793980
# 3    Sacramento St & Davis St    SACRAMENTO ST&DAVIS ST NE  37.794500
# 4  Sacramento St & Battery St     SACRAMENTO ST&BATTERY ST  37.794135
#
#      STOP_LON  EOL  SOL  TIMEPOINT  ARRIVAL_TIME_DEV  DEPARTURE_TIME_DEV  \
# 0 -122.393520    0    1        1.0         -2.589167             -1.2975
# 1 -122.395670    0    0        0.0         -0.194167              0.4625
# 2 -122.396350    0    0        0.0         -0.125000              0.7575
# 3 -122.397610    0    0        0.0          0.432500              0.5500
# 4 -122.400179    0    0        0.0         -0.249167             -0.1475
#
#    DWELL_S     DWELL  RUNTIME_S   RUNTIME  TOTTIME_S    TOTTIME  SERVMILES_S  \
# 0      0.0  0.000000       0.00  0.000000       0.00   0.000000        0.000
# 1      0.0  1.829286       4.24  9.304970       4.24  11.134256        0.382
# 2      0.0  2.401315       2.76  2.344340       2.76   4.745655        0.252
# 3      0.0  0.251369       2.20  2.175713       2.20   2.427083        0.198
# 4      0.0  0.274818       3.10  2.121527       3.10   2.396345        0.286
#
#    SERVMILES  RUNSPEED_S  RUNSPEED  TOTSPEED_S  TOTSPEED   ONTIME5         ON  \
# 0   0.000000        0.00      0.00        0.00      0.00  0.666667   4.119657
# 1   0.536879        5.41      3.46        5.41      2.89  1.000000   1.160714
# 2   0.354172        5.48      9.06        5.48      4.48  0.916667  16.422087
# 3   0.278278        5.40      7.67        5.40      6.88  0.916667   0.666667
# 4   0.401957        5.54     11.37        5.54     10.06  0.583333   2.477552
#
#         OFF   LOAD_ARR   LOAD_DEP  PASSMILES  PASSHOURS  WAITHOURS  \
# 0  0.000000   1.300636   5.420293   0.000000   0.000000   0.769737
# 1  0.696429   5.420293   5.884579   1.035276   0.418748   0.261161
# 2  0.232143   5.884579  22.074523   0.741457   0.377498   2.657059
# 3  0.000000  22.074523  22.741189   2.185378   0.290461   0.250000
# 4  0.333333  22.741189  24.885408   3.251990   0.336428   0.728739
#
#    FULLFARE_REV  PASSDELAY_DEP  PASSDELAY_ARR  RDBRDNGS  DOORCYCLES  \
# 0      8.239314       0.000000       0.000000       0.0    6.760224
# 1      2.321429       3.549464       0.673214       0.0    1.625000
# 2     32.844174      18.867710      13.905421       0.0    6.899876
# 3      1.333333       0.453333       0.066667       0.0    1.464286
# 4      4.955104       0.000000       0.000000       0.0    3.678465
#
#    WHEELCHAIR  BIKERACK  CAPACITY        VC  CROWDED  CROWDHOURS
# 0         0.0       0.0      73.5  0.006614      0.0         0.0
# 1         0.0       0.0      73.5  0.030423      0.0         0.0
# 2         0.0       0.0      73.5  0.033069      0.0         0.0
# 3         0.0       0.0      73.5  0.120370      0.0         0.0
# 4         0.0       0.0      73.5  0.125661      0.0         0.0

# %%
grouped = bus09.groupby(by = ['MONTH','DOW','TOD','AGENCY_ID','ROUTE_SHORT_NAME','DIR','SEQ']).first()

# %%
bus09.pivot?

# %%
route1 = bus09[(bus09['ROUTE_SHORT_NAME'] == '1') & (bus09['DIR'] == 1)]

# %%
print(len(route1))
route1.head()
# Out:
# 2455
#         MONTH  DOW        TOD AGENCY_ID ROUTE_SHORT_NAME  DIR  SEQ  NUMDAYS  \
# 51 2009-06-01    1  0300-0559     SFMTA                1    1    1       12
# 52 2009-06-01    1  0300-0559     SFMTA                1    1    2       12
# 53 2009-06-01    1  0300-0559     SFMTA                1    1    3       12
# 54 2009-06-01    1  0300-0559     SFMTA                1    1    4       12
# 55 2009-06-01    1  0300-0559     SFMTA                1    1    5       12
#
#     OBSDAYS  TRIP_STOPS  OBS_TRIP_STOPS  WGT_TRIP_STOPS  STOP_ID  \
# 51       10           5               1             5.0     4277
# 52       10           5               1             5.0     3555
# 53       10           5               1             5.0     3548
# 54       10           5               1             5.0     3546
# 55       10           5               1             5.0     3844
#
#    ROUTE_LONG_NAME  ROUTE_TYPE  TRIP_HEADSIGN  HEADWAY_S  FARE  \
# 51      CALIFORNIA           3  Howard & Main       19.0   2.0
# 52      CALIFORNIA           3  Howard & Main       19.0   2.0
# 53      CALIFORNIA           3  Howard & Main       19.0   2.0
# 54      CALIFORNIA           3  Howard & Main       19.0   2.0
# 55      CALIFORNIA           3  Howard & Main       19.0   2.0
#
#                       STOPNAME               STOPNAME_AVL   STOP_LAT  \
# 51     Geary Blvd & 33rd Ave    GEARY BLVD&33RD AVE NE-NS  37.779744
# 52     33rd Ave & Clement St    33RD AVE&CLEMENT ST SE-NS  37.781537
# 53     32nd Ave & Clement St    32ND AVE&CLEMENT ST NE-FS  37.781995
# 54  32nd Ave & California St    32ND AVE&CALIFORNIA ST SE  37.783419
# 55  California St & 30th Ave    CALIFORNIA ST&30TH AVE SE  37.783578
#
#       STOP_LON  EOL  SOL  TIMEPOINT  ARRIVAL_TIME_DEV  DEPARTURE_TIME_DEV  \
# 51 -122.493227    0    1        1.0         -0.800833            0.007333
# 52 -122.493354    0    0        0.0          0.284833            0.305833
# 53 -122.492335    0    0        0.0          0.318333            0.342000
# 54 -122.492442    0    0        0.0          0.374833            0.374833
# 55 -122.490087    0    0        0.0          0.269500            0.346333
#
#     DWELL_S     DWELL  RUNTIME_S   RUNTIME  TOTTIME_S   TOTTIME  SERVMILES_S  \
# 51      0.0  0.000000       0.00  0.000000       0.00  0.000000        0.000
# 52      0.0  0.110000       3.00  4.386667       3.00  4.496667        0.620
# 53      0.0  0.119167       1.85  1.885833       1.85  2.005000        0.430
# 54      0.0  0.000000       2.10  2.256667       2.10  2.256667        0.490
# 55      0.0  0.386667       3.00  2.470833       3.00  2.857500        0.705
#
#     SERVMILES  RUNSPEED_S  RUNSPEED  TOTSPEED_S  TOTSPEED   ONTIME5  \
# 51      0.000        0.00      0.00        0.00      0.00  0.616667
# 52      0.620       12.40      8.48       12.40      8.27  0.716667
# 53      0.430       13.95     13.68       13.95     12.87  0.750000
# 54      0.490       14.00     13.03       14.00     13.03  0.750000
# 55      0.705       14.10     17.12       14.10     14.80  0.750000
#
#            ON  OFF   LOAD_ARR   LOAD_DEP  PASSMILES  PASSHOURS  WAITHOURS  \
# 51  12.166667  0.0   3.000000  15.166667   0.000000   0.000000   2.406250
# 52   1.000000  0.0  15.166667  16.166667   1.880667   0.230139   0.072917
# 53   0.500000  0.0  16.166667  16.666667   1.390333   0.101611   0.072917
# 54   0.000000  0.0  16.666667  16.666667   1.633333   0.127306   0.000000
# 55   3.666667  0.0  16.666667  20.333333   2.350000   0.175250   0.458333
#
#     FULLFARE_REV  PASSDELAY_DEP  PASSDELAY_ARR  RDBRDNGS  DOORCYCLES  \
# 51     24.333333         5.8600           3.54       0.0    7.166667
# 52      2.000000         1.3250           1.22       0.0    2.000000
# 53      1.000000         0.4500           0.39       0.0    1.916667
# 54      0.000000         0.0000           0.00       0.0    0.000000
# 55      7.333333         4.7325           4.39       0.0    5.833333
#
#     WHEELCHAIR  BIKERACK  CAPACITY        VC  CROWDED  CROWDHOURS
# 51         0.0       0.0      88.2  0.009524      0.0         0.0
# 52         0.0       0.0      88.2  0.048148      0.0         0.0
# 53         0.0       0.0      88.2  0.051323      0.0         0.0
# 54         0.0       0.0      88.2  0.052910      0.0         0.0
# 55         0.0       0.0      88.2  0.052910      0.0         0.0

# %%
pivot = route1.pivot_table(values = 'LOAD_DEP',index = 'STOPNAME',columns = 'TOD',aggfunc = 'sum',margins = False, fill_value = 0)

# %%
bus09.head()
# Out:
#        MONTH  DOW        TOD AGENCY_ID ROUTE_SHORT_NAME  DIR  SEQ  NUMDAYS  \
# 0 2009-06-01    1  0300-0559     SFMTA                1    0    1       12
# 1 2009-06-01    1  0300-0559     SFMTA                1    0    2       12
# 2 2009-06-01    1  0300-0559     SFMTA                1    0    3       12
# 3 2009-06-01    1  0300-0559     SFMTA                1    0    5       12
# 4 2009-06-01    1  0300-0559     SFMTA                1    0    6       12
#
#    OBSDAYS  TRIP_STOPS  OBS_TRIP_STOPS  WGT_TRIP_STOPS  STOP_ID  \
# 0        6           2               0        2.810885     5056
# 1        6           2               0        2.810885     5336
# 2        6           2               0        2.810885     4445
# 3        6           2               0        2.810885     6294
# 4        6           2               0        2.810885     6290
#
#   ROUTE_LONG_NAME  ROUTE_TYPE     TRIP_HEADSIGN  HEADWAY_S  FARE  \
# 0      CALIFORNIA           3  Geary & 33rd Av.       30.0   2.0
# 1      CALIFORNIA           3  Geary & 33rd Av.       30.0   2.0
# 2      CALIFORNIA           3  Geary & 33rd Av.       30.0   2.0
# 3      CALIFORNIA           3  Geary & 33rd Av.       30.0   2.0
# 4      CALIFORNIA           3  Geary & 33rd Av.       30.0   2.0
#
#                        STOPNAME               STOPNAME_AVL   STOP_LAT  \
# 0        Howard St & Main St     HOWARD ST&MAIN ST E-NS/BZ  37.790410
# 1         Main St & Market St    MAIN ST&MARKET ST NE-MB/B  37.792530
# 2    Drumm St & California St    DRUMM ST&CALIFORNIA ST NE  37.793980
# 3    Sacramento St & Davis St    SACRAMENTO ST&DAVIS ST NE  37.794500
# 4  Sacramento St & Battery St     SACRAMENTO ST&BATTERY ST  37.794135
#
#      STOP_LON  EOL  SOL  TIMEPOINT  ARRIVAL_TIME_DEV  DEPARTURE_TIME_DEV  \
# 0 -122.393520    0    1        1.0         -2.589167             -1.2975
# 1 -122.395670    0    0        0.0         -0.194167              0.4625
# 2 -122.396350    0    0        0.0         -0.125000              0.7575
# 3 -122.397610    0    0        0.0          0.432500              0.5500
# 4 -122.400179    0    0        0.0         -0.249167             -0.1475
#
#    DWELL_S     DWELL  RUNTIME_S   RUNTIME  TOTTIME_S    TOTTIME  SERVMILES_S  \
# 0      0.0  0.000000       0.00  0.000000       0.00   0.000000        0.000
# 1      0.0  1.829286       4.24  9.304970       4.24  11.134256        0.382
# 2      0.0  2.401315       2.76  2.344340       2.76   4.745655        0.252
# 3      0.0  0.251369       2.20  2.175713       2.20   2.427083        0.198
# 4      0.0  0.274818       3.10  2.121527       3.10   2.396345        0.286
#
#    SERVMILES  RUNSPEED_S  RUNSPEED  TOTSPEED_S  TOTSPEED   ONTIME5         ON  \
# 0   0.000000        0.00      0.00        0.00      0.00  0.666667   4.119657
# 1   0.536879        5.41      3.46        5.41      2.89  1.000000   1.160714
# 2   0.354172        5.48      9.06        5.48      4.48  0.916667  16.422087
# 3   0.278278        5.40      7.67        5.40      6.88  0.916667   0.666667
# 4   0.401957        5.54     11.37        5.54     10.06  0.583333   2.477552
#
#         OFF   LOAD_ARR   LOAD_DEP  PASSMILES  PASSHOURS  WAITHOURS  \
# 0  0.000000   1.300636   5.420293   0.000000   0.000000   0.769737
# 1  0.696429   5.420293   5.884579   1.035276   0.418748   0.261161
# 2  0.232143   5.884579  22.074523   0.741457   0.377498   2.657059
# 3  0.000000  22.074523  22.741189   2.185378   0.290461   0.250000
# 4  0.333333  22.741189  24.885408   3.251990   0.336428   0.728739
#
#    FULLFARE_REV  PASSDELAY_DEP  PASSDELAY_ARR  RDBRDNGS  DOORCYCLES  \
# 0      8.239314       0.000000       0.000000       0.0    6.760224
# 1      2.321429       3.549464       0.673214       0.0    1.625000
# 2     32.844174      18.867710      13.905421       0.0    6.899876
# 3      1.333333       0.453333       0.066667       0.0    1.464286
# 4      4.955104       0.000000       0.000000       0.0    3.678465
#
#    WHEELCHAIR  BIKERACK  CAPACITY        VC  CROWDED  CROWDHOURS
# 0         0.0       0.0      73.5  0.006614      0.0         0.0
# 1         0.0       0.0      73.5  0.030423      0.0         0.0
# 2         0.0       0.0      73.5  0.033069      0.0         0.0
# 3         0.0       0.0      73.5  0.120370      0.0         0.0
# 4         0.0       0.0      73.5  0.125661      0.0         0.0

# %%
sns.heatmap()

# %%
#Creates Heatmap.

#fig size numbers are in inches on a sheet of paper.
plt.figure(figsize =(10, 10))
plt.title('ROUTE 1 (Inbound)')
plt.tight_layout()
plt.yticks = Heatmap.yaxis
Heatmap = sns.heatmap(pivot, robust = True, cmap = 'RdYlGn',fmt = '.1f',annot = False,
                      linecolor = 'black',linewidth = 0.1,cbar = True,square = False, 
                      xticklabels = True, yticklabels = True)

# %%
figure = Heatmap.get_figure()

# %%
bus09.ROUTE_SHORT_NAME

# %%
figure.savefig('Route1_Inbound.jpg',bbox_inches='tight')

# %%
bus13 = bus[bus["MONTH"].isin(pd.date_range('2013-01-01', '2014-12-01'))]

# %%
bus13.head()
# Out:
#              MONTH  DOW        TOD AGENCY_ID ROUTE_SHORT_NAME  DIR  SEQ  \
# 1244874 2013-01-01    1  0300-0559     SFMTA                1    0    4
# 1244875 2013-01-01    1  0300-0559     SFMTA                1    0    5
# 1244876 2013-01-01    1  0300-0559     SFMTA                1    0    6
# 1244877 2013-01-01    1  0300-0559     SFMTA                1    0    7
# 1244878 2013-01-01    1  0300-0559     SFMTA                1    0    8
#
#          NUMDAYS  OBSDAYS  TRIP_STOPS  OBS_TRIP_STOPS  WGT_TRIP_STOPS  \
# 1244874       21       13           2               0        2.816745
# 1244875       21       13           2               0        2.816745
# 1244876       21       13           2               0        2.816745
# 1244877       21       13           2               0        2.816745
# 1244878       21       13           2               0        2.816745
#
#          STOP_ID ROUTE_LONG_NAME  ROUTE_TYPE          TRIP_HEADSIGN  \
# 1244874     4015      CALIFORNIA           3  the Richmond District
# 1244875     6294      CALIFORNIA           3  the Richmond District
# 1244876     6290      CALIFORNIA           3  the Richmond District
# 1244877     6314      CALIFORNIA           3  the Richmond District
# 1244878     6307      CALIFORNIA           3  the Richmond District
#
#          HEADWAY_S  FARE                        STOPNAME  \
# 1244874       30.0   2.0            Clay St & Drumm St
# 1244875       30.0   2.0      Sacramento St & Davis St
# 1244876       30.0   2.0    Sacramento St & Battery St
# 1244877       30.0   2.0    Sacramento St & Sansome St
# 1244878       30.0   2.0  Sacramento St & Montgomery St
#
#                          STOPNAME_AVL   STOP_LAT    STOP_LON  EOL  SOL  \
# 1244874     CLAY ST&DRUMM ST SW-NS/BZ  37.795415 -122.396996    0    1
# 1244875  SACRAMENTO ST&DAVIS ST NE-NS  37.794500 -122.397610    0    0
# 1244876  SACRAMENTO ST&BATTERY ST NW-  37.794135 -122.400179    0    0
# 1244877  SACRAMENTO ST&SANSOME ST NW-  37.794030 -122.401551    0    0
# 1244878   SACRAMENTO ST&MONTGOMERY ST  37.793842 -122.403068    0    0
#
#          TIMEPOINT  ARRIVAL_TIME_DEV  DEPARTURE_TIME_DEV  DWELL_S      DWELL  \
# 1244874        1.0         -9.578462           -2.150769      0.0  19.726599
# 1244875        0.0         -2.058077           -1.646154      0.0   1.133525
# 1244876        0.0         -2.114615           -1.998462      0.0   0.298658
# 1244877        1.0          1.523077            1.612308      0.0   0.257419
# 1244878        0.0          1.377692            1.452308      0.0   0.223144
#
#          RUNTIME_S    RUNTIME  TOTTIME_S    TOTTIME  SERVMILES_S  SERVMILES  \
# 1244874       0.00   0.000000       0.00  19.726599        0.000   0.000000
# 1244875       2.26   3.524717       2.26   4.658242        0.238   0.335193
# 1244876       2.44   2.053109       2.44   2.351768        0.286   0.402794
# 1244877       1.30  13.321439       1.30  13.578858        0.150   0.211256
# 1244878       1.56   1.598556       1.56   1.821700        0.168   0.236607
#
#          RUNSPEED_S  RUNSPEED  TOTSPEED_S  TOTSPEED   ONTIME5         ON  \
# 1244874        0.00      0.00        0.00      0.00  0.576923  12.138192
# 1244875        6.32      5.71        6.32      4.32  0.500000  10.068564
# 1244876        7.03     11.77        7.03     10.28  0.423077   1.688703
# 1244877        6.92      0.95        6.92      0.93  0.423077   1.012255
# 1244878        6.46      8.88        6.46      7.79  0.423077   0.714135
#
#               OFF   LOAD_ARR   LOAD_DEP  PASSMILES  PASSHOURS  WAITHOURS  \
# 1244874  0.000000   0.572827  12.711020   0.000000   1.202545   1.171571
# 1244875  0.107880  12.461832  22.422517   1.482958   0.462938   3.028888
# 1244876  2.564219  24.847536  23.972019   3.553198   0.354528   0.294686
# 1244877  0.845427  28.457393  28.624221   2.134304   3.826657   0.131479
# 1244878  0.249187  28.624221  29.089168   2.404435   0.319123   0.101232
#
#          FULLFARE_REV  PASSDELAY_DEP  PASSDELAY_ARR  RDBRDNGS  DOORCYCLES  \
# 1244874     24.276385      14.079054      10.017335  0.606255    9.918918
# 1244875     20.137129       7.976490       7.079415  0.406000    3.880083
# 1244876      3.377405       0.092777       0.000000  0.000000    3.159538
# 1244877      2.024509       0.000000       0.000000  0.000000    3.093603
# 1244878      1.428269       0.573131       0.540737  0.000000    2.358164
#
#          WHEELCHAIR  BIKERACK   CAPACITY        VC  CROWDED  CROWDHOURS
# 1244874         0.0  0.000000  72.692308  0.003053      0.0         0.0
# 1244875         0.0  0.249187  72.692308  0.068987      0.0         0.0
# 1244876         0.0  0.000000  72.692308  0.139194      0.0         0.0
# 1244877         0.0  0.000000  72.692308  0.157509      0.0         0.0
# 1244878         0.0  0.107880  72.692308  0.158120      0.0         0.0

# %%
bus_diff['ON_09'] = bus09.ON
bus_diff['ON_13'] = bus13.ON
bus_diff['LOAD_09'] = bus09.LOAD_DEP
bus_diff['LOAD_13'] = bus13.LOAD_DEP
# Out:
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
bus09['ON_DIFF'] = bus09.ON - bus13.ON
# Out:
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
bus09.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 219479 entries, 0 to 219478
# Data columns (total 59 columns):
# MONTH                 219479 non-null datetime64[ns]
# DOW                   219479 non-null int64
# TOD                   219479 non-null object
# AGENCY_ID             219479 non-null object
# ROUTE_SHORT_NAME      219479 non-null object
# DIR                   219479 non-null int64
# SEQ                   219479 non-null int64
# NUMDAYS               219479 non-null int64
# OBSDAYS               219479 non-null int64
# TRIP_STOPS            219479 non-null int64
# OBS_TRIP_STOPS        219479 non-null int64
# WGT_TRIP_STOPS        214356 non-null float64
# STOP_ID               219479 non-null int64
# ROUTE_LONG_NAME       219479 non-null object
# ROUTE_TYPE            219479 non-null int64
# TRIP_HEADSIGN         219479 non-null object
# HEADWAY_S             212823 non-null float64
# FARE                  219479 non-null float64
# STOPNAME              219479 non-null object
# STOPNAME_AVL          219479 non-null object
# STOP_LAT              219479 non-null float64
# STOP_LON              219479 non-null float64
# EOL                   219479 non-null int64
# SOL                   219479 non-null int64
# TIMEPOINT             212339 non-null float64
# ARRIVAL_TIME_DEV      212339 non-null float64
# DEPARTURE_TIME_DEV    212339 non-null float64
# DWELL_S               219479 non-null float64
# DWELL                 212339 non-null float64
# RUNTIME_S             219479 non-null float64
# RUNTIME               212339 non-null float64
# TOTTIME_S             219479 non-null float64
# TOTTIME               212339 non-null float64
# SERVMILES_S           219479 non-null float64
# SERVMILES             214356 non-null float64
# RUNSPEED_S            219479 non-null float64
# RUNSPEED              212339 non-null float64
# TOTSPEED_S            219479 non-null float64
# TOTSPEED              212339 non-null float64
# ONTIME5               212339 non-null float64
# ON                    212339 non-null float64
# OFF                   212339 non-null float64
# LOAD_ARR              212339 non-null float64
# LOAD_DEP              212339 non-null float64
# PASSMILES             212339 non-null float64
# PASSHOURS             212339 non-null float64
# WAITHOURS             205592 non-null float64
# FULLFARE_REV          212339 non-null float64
# PASSDELAY_DEP         212339 non-null float64
# PASSDELAY_ARR         212339 non-null float64
# RDBRDNGS              212339 non-null float64
# DOORCYCLES            212339 non-null float64
# WHEELCHAIR            212339 non-null float64
# BIKERACK              212339 non-null float64
# CAPACITY              212339 non-null float64
# VC                    212339 non-null float64
# CROWDED               212339 non-null float64
# CROWDHOURS            212339 non-null float64
# LOAD_DIFF             0 non-null float64
# dtypes: datetime64[ns](1), float64(40), int64(11), object(7)
# memory usage: 100.5+ MB

# %%
bus09['LOAD_DIFF'] = bus09['LOAD_DEP'] - bus13['LOAD_DEP']
# Out:
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
bus_diff.head()
# Out:
#   ROUTE_SHORT_NAME  DIR                      STOPNAME        TOD  LOAD_DIFF  \
# 0                1    0        Howard St & Main St     0300-0559        NaN
# 1                1    0         Main St & Market St    0300-0559        NaN
# 2                1    0    Drumm St & California St    0300-0559        NaN
# 3                1    0    Sacramento St & Davis St    0300-0559        NaN
# 4                1    0  Sacramento St & Battery St    0300-0559        NaN
#
#        ON_09  ON_13    LOAD_09  LOAD_13
# 0   4.119657    NaN   5.420293      NaN
# 1   1.160714    NaN   5.884579      NaN
# 2  16.422087    NaN  22.074523      NaN
# 3   0.666667    NaN  22.741189      NaN
# 4   2.477552    NaN  24.885408      NaN

# %%
pivot = route1.pivot_table(values = 'LOAD_DIFF',index = 'STOPNAME',columns = 'TOD',aggfunc = 'sum',margins = False, fill_value = 0)

# %%
figure

# %%
plt.yticks(rotation=45)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-186-0a18aeb0abfd> in <module>()
# ----> 1 plt.yticks(rotation=45)
#
# TypeError: 'YAxis' object is not callable

# %%
locs, labels = plt.yticks()
plt.setp(labels, rotation=45)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-192-bb29c163f0e8> in <module>()
# ----> 1 locs, labels = plt.yticks()
#       2 plt.setp(labels, rotation=45)
#
# TypeError: 'YAxis' object is not callable

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gp


H5_INFILE = "E:/Transit_Casa/Output/sfmuni_monthly_ts.h5"
BASE_START_DATE = '2009-01-01'
BASE_END_DATE = '2009-12-01'
FUTURE_START_DATE = '2013-01-01'
FUTURE_END_DATE = '2013-12-01'
DIRECTIONS = [1,0]



def create_heatmap(df,direction):
    plt.figure(figsize =(10, 10))
    if direction == 1:
        plt.title('ROUTE ' + str(route) + ' (Inbound)')
        plt.tight_layout()
        Heatmap = sns.heatmap(df, robust = True, cmap = 'RdYlGn',fmt = '.1f',annot = False,
                              linecolor = 'black',linewidth = 0.1,cbar = True,square = False, 
                              xticklabels = True, yticklabels = True)
    elif direction == 0:
        plt.title('ROUTE ' + str(route) + ' (Outbound)')
        plt.tight_layout()
        Heatmap = sns.heatmap(df, robust = True, cmap = 'RdYlGn',fmt = '.1f',annot = False,
                              linecolor = 'black',linewidth = 0.1,cbar = True,square = False, 
                              xticklabels = True, yticklabels = True)

    else:
        print('Bad Direction!')

    return Heatmap
 
 
    
if __name__ == "__main__":

    store = pd.HDFStore(H5_INFILE)
    bus = store.get('rs_tod')
    
    bus09 = bus[bus["MONTH"].isin(pd.date_range(BASE_START_DATE,BASE_END_DATE))]
    bus13 = bus[bus['MONTH'].isin(pd.date_range(FUTURE_START_DATE,FUTURE_END_DATE))]
    bus09['LOAD_DIFF'] = bus09['LOAD_DEP'] - bus13['LOAD_DEP']
    
    bus_diff = pd.merge(bus09,bus13,how = 'inner',
                        on =['DOW','TOD','AGENCY_ID','ROUTE_SHORT_NAME','DIR','SEQ'],suffixes = ('_09','_13'))
    bus_diff['LOAD_DIFF'] = bus_diff['LOAD_DEP_09'] - bus_diff['LOAD_DEP_13']
    
    bus_dfs = [bus09,bus13,bus_diff]
    count = 0
    for bus_df in bus_dfs:
        print('Started new heatmaps dataframe')

        for route in bus_df['ROUTE_SHORT_NAME'].unique():
            print('Started route ' + route)
            
            for direction in DIRECTIONS:
                route_df = bus_df[(bus_df['ROUTE_SHORT_NAME'] == route) & (bus_df['DIR'] == direction)]
                
                
                if len(route_df) == 0:
                    print('Route ' + route + ' in ' + str(direction) + ' direction does not run')
                else:
                    if count != 2: 
                        pivot = route_df.pivot_table(values = 'LOAD_DEP',index = 'STOPNAME',
                                              columns = 'TOD',aggfunc = 'sum',margins = False, fill_value = 0)
                                              
                        heatmap = create_heatmap(pivot,direction)
                        figure = heatmap.get_figure()
                    else:
                        pivot = route_df.pivot_table(values = 'LOAD_DIFF',index = 'STOPNAME',
                                              columns = 'TOD',aggfunc = 'sum',margins = False, fill_value = 0)
                                              
                        heatmap = create_heatmap(pivot,direction)
                        figure = heatmap.get_figure()
    
                    if count == 0:
                        figure.savefig('E:/Transit-Casa-Alex/Output/HeatMaps/'  + '2009 ' + str(route) + '_' + 'Route ' +
                        str(direction) + '.jpg',bbox_inches='tight',pad_inches = 6)
                    elif count == 1:
                        figure.savefig('E:/Transit-Casa-Alex/Output/HeatMaps/'  + ' 2013 ' + str(route) + '_' + 'Route ' +
                        str(direction) + '.jpg',bbox_inches='tight',pad_inches = 6)
                    elif count == 2:
                        figure.savefig('E:/Transit-Casa-Alex/Output/HeatMaps/'  + 'Diff ' + str(route) + '_' + 'Route ' +
                        str(direction) + '.jpg',bbox_inches='tight')
                    else:
                        print('Something is wrong')
                        
                    plt.close('all')
        count = count + 1        
            
                
    print('ALL DONE TIME FOR YOUTUBE VIDEOS!')
# Out:
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Started new heatmaps dataframe
# Started route 1
# Started route 10
# Started route 108
# Started route 12
# Started route 14
# Started route 18
# Started route 19
# Started route 2
# Started route 21
# Started route 22
# Started route 23
# Started route 24
# Started route 26
# Started route 27
# Started route 28
# Started route 29
# Started route 30
# Started route 31
# Started route 33
# Started route 35
# Started route 36
# Started route 38
# Started route 4
# Started route 41
# Started route 43
# Started route 44
# Started route 45
# Started route 47
# Started route 48
# Started route 49
# Started route 5
# Started route 54
# Started route 6
# Started route 66
# Started route 71
# Started route 9
# Started route 91
# Started route 9X
# Started route 016AX
# Started route 016BX
# Started route 14L
# Started route 14X
# Started route 17
# Started route 1AX
# Started route 1BX
# Started route 20
# Started route 28L
# Started route 3
# Started route 30X
# Started route 31AX
# Started route 31BX
# Started route 37
# Started route 38AX
# Started route 38BX
# Started route 38L
# Started route 39
# Started route 52
# Started route 53
# Started route 56
# Started route 67
# Started route 7
# Started route 71L
# Started route 80
# Route 80 in 0 direction does not run
# Started route 81
# Route 81 in 0 direction does not run
# Started route 82
# Route 82 in 0 direction does not run
# Started route 88
# Started route 89
# Started route 9AX
# Started route 9BX
# Started route 95
# Route 95 in 1 direction does not run
# Started route 90
# Started route K-OWL
# Started route L-OWL
# Started route M-OWL
# Route M-OWL in 1 direction does not run
# Started route N-OWL
# Started route 8X
# Started route 16X
# Started route 80X
# Route 80X in 0 direction does not run
# Started route 81X
# Route 81X in 0 direction does not run
# Started route 82X
# Started route 8AX
# Started route 8BX
# Started route 9L
# Started new heatmaps dataframe
# Started route 1
# Started route 10
# Started route 12
# Started route 14
# Started route 18
# Started route 19
# Started route 2
# Started route 21
# Started route 22
# Started route 23
# Started route 24
# Started route 27
# Started route 28
# Started route 29
# Started route 30
# Started route 31
# Started route 33
# Started route 36
# Started route 38
# Started route 41
# Started route 43
# Started route 44
# Started route 45
# Started route 47
# Started route 48
# Started route 49
# Started route 5
# Started route 54
# Started route 6
# Started route 66
# Started route 71
# Started route 8X
# Started route 9
# Started route 108
# Started route 14L
# Started route 14X
# Started route 16X
# Started route 17
# Started route 1AX
# Started route 1BX
# Started route 28L
# Started route 3
# Started route 30X
# Started route 31AX
# Started route 31BX
# Started route 35
# Started route 37
# Started route 38AX
# Started route 38BX
# Started route 38L
# Started route 52
# Started route 56
# Started route 67
# Started route 71L
# Started route 80X
# Route 80X in 0 direction does not run
# Started route 81X
# Route 81X in 0 direction does not run
# Started route 82X
# Started route 83X
# Started route 88
# Started route 8AX
# Started route 8BX
# Started route 9L
# Started route NX
# Started route 39
# Started route 90
# Started route 91
# Started route K-OWL
# Started route L-OWL
# Started route N-OWL
# Started route 016X
# Started route 5L
# Started new heatmaps dataframe
# Started route 1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: 'STOPNAME'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-250-c8d81be7f852> in <module>()
#      73                     else:
#      74                         pivot = route_df.pivot_table(values = 'LOAD_DIFF',index = 'STOPNAME',
# ---> 75                                               columns = 'TOD',aggfunc = 'sum',margins = False, fill_value = 0)
#      76
#      77                         heatmap = create_heatmap(pivot,direction)
#
# C:\Anaconda\lib\site-packages\pandas\tools\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#     124         values = list(values)
#     125
# --> 126     grouped = data.groupby(keys)
#     127     agged = grouped.agg(aggfunc)
#     128
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    3989         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    3990                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 3991                        **kwargs)
#    3992
#    3993     def asfreq(self, freq, method=None, how=None, normalize=False):
#
# C:\Anaconda\lib\site-packages\pandas\core\groupby.py in groupby(obj, by, **kwds)
#    1509         raise TypeError('invalid type: %s' % type(obj))
#    1510
# -> 1511     return klass(obj, by, **kwds)
#    1512
#    1513
#
# C:\Anaconda\lib\site-packages\pandas\core\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, **kwargs)
#     368                                                     level=level,
#     369                                                     sort=sort,
# --> 370                                                     mutated=self.mutated)
#     371
#     372         self.obj = obj
#
# C:\Anaconda\lib\site-packages\pandas\core\groupby.py in _get_grouper(obj, key, axis, level, sort, mutated)
#    
# %%
len(bus09)
# Out:
# 219479

# %%
len(bus13)
# Out:
# 320990

# %%
bus_diff.LOAD_DIFF.unique()
# Out:
# array([ nan])

# %%
bus_09_grouped = bus09.groupby(by = ['MONTH','DOW','TOD','AGENCY_ID','ROUTE_SHORT_NAME','DIR','SEQ']).first()

# %%
bus_13_grouped = bus13.groupby(by = ['MONTH','DOW','TOD','AGENCY_ID','ROUTE_SHORT_NAME','DIR','SEQ']).first()

# %%
merge = pd.merge(bus09,bus13,how = 'inner',on =['DOW','TOD','AGENCY_ID','ROUTE_SHORT_NAME','DIR','SEQ'],suffixes = ('_09','_13'))

# %%
pd.merge?

# %%
merge.head()
# Out:
#     MONTH_09  DOW        TOD AGENCY_ID ROUTE_SHORT_NAME  DIR  SEQ  NUMDAYS_09  \
# 0 2009-06-01    1  0300-0559     SFMTA                1    0    5          12
# 1 2009-06-01    1  0300-0559     SFMTA                1    0    5          12
# 2 2009-06-01    1  0300-0559     SFMTA                1    0    5          12
# 3 2009-06-01    1  0300-0559     SFMTA                1    0    5          12
# 4 2009-06-01    1  0300-0559     SFMTA                1    0    5          12
#
#    OBSDAYS_09  TRIP_STOPS_09  OBS_TRIP_STOPS_09  WGT_TRIP_STOPS_09  \
# 0           6              2                  0           2.810885
# 1           6              2                  0           2.810885
# 2           6              2                  0           2.810885
# 3           6              2                  0           2.810885
# 4           6              2                  0           2.810885
#
#    STOP_ID_09 ROUTE_LONG_NAME_09  ROUTE_TYPE_09  TRIP_HEADSIGN_09  \
# 0        6294         CALIFORNIA              3  Geary & 33rd Av.
# 1        6294         CALIFORNIA              3  Geary & 33rd Av.
# 2        6294         CALIFORNIA              3  Geary & 33rd Av.
# 3        6294         CALIFORNIA              3  Geary & 33rd Av.
# 4        6294         CALIFORNIA              3  Geary & 33rd Av.
#
#    HEADWAY_S_09  FARE_09                 STOPNAME_09  \
# 0          30.0      2.0  Sacramento St & Davis St
# 1          30.0      2.0  Sacramento St & Davis St
# 2          30.0      2.0  Sacramento St & Davis St
# 3          30.0      2.0  Sacramento St & Davis St
# 4          30.0      2.0  Sacramento St & Davis St
#
#              STOPNAME_AVL_09  STOP_LAT_09  STOP_LON_09  EOL_09  SOL_09  \
# 0  SACRAMENTO ST&DAVIS ST NE      37.7945   -122.39761       0       0
# 1  SACRAMENTO ST&DAVIS ST NE      37.7945   -122.39761       0       0
# 2  SACRAMENTO ST&DAVIS ST NE      37.7945   -122.39761       0       0
# 3  SACRAMENTO ST&DAVIS ST NE      37.7945   -122.39761       0       0
# 4  SACRAMENTO ST&DAVIS ST NE      37.7945   -122.39761       0       0
#
#    TIMEPOINT_09  ARRIVAL_TIME_DEV_09  DEPARTURE_TIME_DEV_09  DWELL_S_09  \
# 0           0.0               0.4325                   0.55         0.0
# 1           0.0               0.4325                   0.55         0.0
# 2           0.0               0.4325                   0.55         0.0
# 3           0.0               0.4325                   0.55         0.0
# 4           0.0               0.4325                   0.55         0.0
#
#    DWELL_09  RUNTIME_S_09  RUNTIME_09  TOTTIME_S_09  TOTTIME_09  \
# 0  0.251369           2.2    2.175713           2.2    2.427083
# 1  0.251369           2.2    2.175713           2.2    2.427083
# 2  0.251369           2.2    2.175713           2.2    2.427083
# 3  0.251369           2.2    2.175713           2.2    2.427083
# 4  0.251369           2.2    2.175713           2.2    2.427083
#
#    SERVMILES_S_09  SERVMILES_09  RUNSPEED_S_09  RUNSPEED_09  TOTSPEED_S_09  \
# 0           0.198      0.278278            5.4         7.67            5.4
# 1           0.198      0.278278            5.4         7.67            5.4
# 2           0.198      0.278278            5.4         7.67            5.4
# 3           0.198      0.278278            5.4         7.67            5.4
# 4           0.198      0.278278            5.4         7.67            5.4
#
#    TOTSPEED_09  ONTIME5_09     ON_09  OFF_09  LOAD_ARR_09  LOAD_DEP_09  \
# 0         6.88    0.916667  0.666667     0.0    22.074523    22.741189
# 1         6.88    0.916667  0.666667     0.0    22.074523    22.741189
# 2         6.88    0.916667  0.666667     0.0    22.074523    22.741189
# 3         6.88    0.916667  0.666667     0.0    22.074523    22.741189
# 4         6.88    0.916667  0.666667     0.0    22.074523    22.741189
#
#    PASSMILES_09  PASSHOURS_09  WAITHOURS_09  FULLFARE_REV_09  \
# 0      2.185378      0.290461          0.25         1.333333
# 1      2.185378      0.290461          0.25         1.333333
# 2      2.185378      0.290461          0.25         1.333333
# 3      2.185378      0.290461          0.25         1.333333
# 4      2.185378      0.290461          0.25         1.333333
#
#    PASSDELAY_DEP_09  PASSDELAY_ARR_09  RDBRDNGS_09  DOORCYCLES_09  \
# 0          0.453333          0.066667          0.0       1.464286
# 1          0.453333          0.066667          0.0       1.464286
# 2          0.453333          0.066667          0.0       1.464286
# 3          0.453333          0.066667          0.0       1.464286
# 4          0.453333          0.066667          0.0       1.464286
#
#    WHEELCHAIR_09  BIKERACK_09  CAPACITY_09    VC_09  CROWDED_09  \
# 0            0.0          0.0         73.5  0.12037         0.0
# 1            0.0          0.0         73.5  0.12037         0.0
# 2            0.0          0.0         73.5  0.12037         0.0
# 3            0.0          0.0         73.5  0.12037         0.0
# 4            0.0          0.0         73.5  0.12037         0.0
#
#    CROWDHOURS_09  LOAD_DIFF  ON_DIFF   MONTH_13  NUMDAYS_13  OBSDAYS_13  \
# 0            0.0        NaN      NaN 2013-01-01          21          13
# 1            0.0        NaN      NaN 2013-02-01          19           8
# 2            0.0        NaN      NaN 2013-03-01          20           7
# 3            0.0        NaN      NaN 2013-04-01          22           9
# 4            0.0        NaN      NaN 2013-05-01          22           9
#
#    TRIP_STOPS_13  OBS_TRIP_STOPS_13  WGT_TRIP_STOPS_13  STOP_ID_13  \
# 0              2                  0           2.816745        6294
# 1              2                  0           2.725148        6294
# 2              2                  0           2.775838        6294
# 3              2                  0           2.627705        6294
# 4              2                  0           2.813704        6294
#
#   ROUTE_LONG_NAME_13  ROUTE_TYPE_13       TRIP_HEADSIGN_13  HEADWAY_S_13  \
# 0         CALIFORNIA              3  the Richmond District          30.0
# 1         CALIFORNIA              3  the Richmond District          30.0
# 2         CALIFORNIA              3  the Richmond District          30.0
# 3         CALIFORNIA              3  the Richmond District          30.0
# 4         CALIFORNIA              3  the Richmond District          30.0
#
#    FARE_13                 STOPNAME_13               STOPNAME_AVL_13  \
# 0      2.0  Sacramento St & Davis St    SACRAMENTO ST&DAVIS ST N