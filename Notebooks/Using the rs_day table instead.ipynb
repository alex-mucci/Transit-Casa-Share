# %%
import pandas as pd
pd.options.display.max_columns = 9999

# %%
store = pd.HDFStore('E:/Transit-Casa-Alex/Input/Bus Performence/sfmuni_monthly_ts.h5')

# %%
df = store.select('rs_day',where = "'MONTH' == ['2016-10-01','2016-11-01','2016-12-01']")

# %%
df.head()
# Out:
#             MONTH  DOW AGENCY_ID ROUTE_SHORT_NAME  DIR  SEQ  NUMDAYS  OBSDAYS  \
# 492540 2016-10-01    1     SFMTA                1    0    1       21     20.0
# 492541 2016-10-01    1     SFMTA                1    0    2       21     20.0
# 492542 2016-10-01    1     SFMTA                1    0    3       21     20.0
# 492543 2016-10-01    1     SFMTA                1    0    4       21     20.0
# 492544 2016-10-01    1     SFMTA                1    0    5       21     20.0
#
#         TRIP_STOPS  OBS_TRIP_STOPS  IMP_TRIP_STOPS  WGT_TRIP_STOPS  STOP_ID  \
# 492540         219              40             0.0      222.533704     4015
# 492541         219              40             0.0      222.533704     6294
# 492542         219              40             0.0      222.533704     6290
# 492543         219              40             0.0      222.533704     6314
# 492544         219              40             0.0      222.533704     6307
#
# ...

# %%
len(df)
# Out:
# 16806

# %%
census = pd.read_csv('E:/Transit-Casa-Alex/Output/Final Data/2009/Census Block Buffers/Tenth_Census_Block_Estimation_File.csv')

# %%
df2 = pd.merge(df,census,how = 'left',on = 'STOP_ID',suffixes = ('','_d'))

# %%
df2.sort_values(by = 'STOP_ID').head()
# Out:
#            MONTH  DOW AGENCY_ID ROUTE_SHORT_NAME  DIR  SEQ  NUMDAYS  OBSDAYS  \
# 16191 2016-12-01    1     SFMTA               91    0    1       21     13.0
# 12711 2016-12-01    1     SFMTA              28R    1    5       21     19.0
# 12657 2016-12-01    1     SFMTA               28    1    5       21     20.0
# 7109  2016-11-01    1     SFMTA              28R    1    5       21     20.0
# 7259  2016-11-01    1     SFMTA               29    1   53       21     17.0
#
#        TRIP_STOPS  OBS_TRIP_STOPS  IMP_TRIP_STOPS  WGT_TRIP_STOPS  STOP_ID  \
# 16191          10               3             0.0       10.122278      390
# 12711          73              14             0.0       73.000000      390
# 12657          98              23             0.0       98.000000      390
# 7109           73              19             0.0       73.000000      390
# 7259          102              48             1.0      100.751891      390
#
# ...

# %%
len(df[df['STOP_ID'] == 390])
# Out:
# 12

# %%
len(df2[df2['STOP_ID'] == 390])
# Out:
# 12

# %%
df.head()
# Out:
#             MONTH  DOW AGENCY_ID ROUTE_SHORT_NAME  DIR  SEQ  NUMDAYS  OBSDAYS  \
# 492540 2016-10-01    1     SFMTA                1    0    1       21     20.0
# 492541 2016-10-01    1     SFMTA                1    0    2       21     20.0
# 492542 2016-10-01    1     SFMTA                1    0    3       21     20.0
# 492543 2016-10-01    1     SFMTA                1    0    4       21     20.0
# 492544 2016-10-01    1     SFMTA                1    0    5       21     20.0
#
#         TRIP_STOPS  OBS_TRIP_STOPS  IMP_TRIP_STOPS  WGT_TRIP_STOPS  STOP_ID  \
# 492540         219              40             0.0      222.533704     4015
# 492541         219              40             0.0      222.533704     6294
# 492542         219              40             0.0      222.533704     6290
# 492543         219              40             0.0      222.533704     6314
# 492544         219              40             0.0      222.533704     6307
#
# ...

# %%
df.to_csv('E:/Transit-Casa-Alex/Output/Final Data/2016/Bus_Performance_Data_rs_day.csv')
