# %%
import geopandas as gp
import geocoder
import numpy as np
# %matplotlib inline

# %%
data = gp.read_file('E:\Transit-Casa-Alex\Output\Census Block Data/2009/Census_Block_Data.shp')

# %%
data.plot()

# %%
data['centroid'] = data.centroid

# %%
data.head()
# Out:
#        ALAND10_x  ALAND10_y  AWATER10  BLOCKCE10     BLOCKID10      BLOCK_ID  \
# 0  182505.545918    16958.0       0.0     2002.0  6.075021e+13  6.075021e+13
# 1  181052.857519    16823.0       0.0     2000.0  6.075021e+13  6.075021e+13
# 2  183174.823888    17020.0       0.0     3004.0  6.075021e+13  6.075021e+13
# 3  176663.550351    16415.0       0.0     1003.0  6.075021e+13  6.075021e+13
# 4  188584.943478    17523.0       0.0     4001.0  6.075021e+13  6.075021e+13
#
#    COUNTYFP10  EDHLTH_RAC  EDHLTH_WAC  EMP_RAC  \
# 0        75.0        16.0         7.0     61.0
# 1        75.0        19.0         0.0     79.0
# 2        75.0        25.0         0.0     84.0
# 3        75.0        10.0         8.0     58.0
# 4        75.0        22.0         1.0     90.0
#
#                        ...                       UATYP10 UR10  Unnamed_ 0  \
# 0                      ...                             U    U         0.0
# 1                      ...                             U    U         1.0
# 2                      ...                             U    U         2.0
# 3                      ...                             U    U         3.0
# 4                      ...                             U    U         4.0
#
#    createda_1  createdate                                           geometry  \
# 0  20160228.0  20160228.0  POLYGON ((-122.440616 37.75090199999977, -122....
# 1  20160228.0  20160228.0  POLYGON ((-122.438397 37.75022599999975, -122....
# 2  20160228.0  20160228.0  POLYGON ((-122.435808 37.75762299999975, -122....
# 3  20160228.0  20160228.0  POLYGON ((-122.436527 37.75353999999976, -122....
# 4  20160228.0  20160228.0  POLYGON ((-122.432331 37.75622699999975, -122....
#
#                                           geometry_y     h_geocode  \
# 0  POLYGON ((-122.440616 37.750902, -122.440459 3...  6.075021e+13
# 1  POLYGON ((-122.438397 37.750226, -122.43832 37...  6.075021e+13
# 2  POLYGON ((-122.435808 37.757623, -122.435642 3...  6.075021e+13
# 3  POLYGON ((-122.436527 37.75354, -122.436454 37...  6.075021e+13
# 4  POLYGON ((-122.432331 37.756227, -122.432254 3...  6.075021e+13
#
#       w_geocode                                      centroid
# 0  6.075021e+13  POINT (-122.4410750952718 37.75006645242288)
# 1  6.075021e+13  POINT (-122.4389330377124 37.75019580711344)
# 2  6.075021e+13  POINT (-122.4362701327225 37.75679372444293)
# 3  6.075021e+13  POINT (-122.4370498299397 37.75352911966451)
# 4  6.075021e+13  POINT (-122.4334002333296 37.75575797076656)
#
# [5 rows x 37 columns]

# %%
data.head()
# Out:
#        ALAND10_x  ALAND10_y  AWATER10  BLOCKCE10     BLOCKID10      BLOCK_ID  \
# 0  182505.545918    16958.0       0.0     2002.0  6.075021e+13  6.075021e+13
# 1  181052.857519    16823.0       0.0     2000.0  6.075021e+13  6.075021e+13
# 2  183174.823888    17020.0       0.0     3004.0  6.075021e+13  6.075021e+13
# 3  176663.550351    16415.0       0.0     1003.0  6.075021e+13  6.075021e+13
# 4  188584.943478    17523.0       0.0     4001.0  6.075021e+13  6.075021e+13
#
#    COUNTYFP10  EDHLTH_RAC  EDHLTH_WAC  EMP_RAC  \
# 0        75.0        16.0         7.0     61.0
# 1        75.0        19.0         0.0     79.0
# 2        75.0        25.0         0.0     84.0
# 3        75.0        10.0         8.0     58.0
# 4        75.0        22.0         1.0     90.0
#
#                        ...                       UATYP10 UR10  Unnamed_ 0  \
# 0                      ...                             U    U         0.0
# 1                      ...                             U    U         1.0
# 2                      ...                             U    U         2.0
# 3                      ...                             U    U         3.0
# 4                      ...                             U    U         4.0
#
#    createda_1  createdate                                           geometry  \
# 0  20160228.0  20160228.0  POLYGON ((-122.440616 37.75090199999977, -122....
# 1  20160228.0  20160228.0  POLYGON ((-122.438397 37.75022599999975, -122....
# 2  20160228.0  20160228.0  POLYGON ((-122.435808 37.75762299999975, -122....
# 3  20160228.0  20160228.0  POLYGON ((-122.436527 37.75353999999976, -122....
# 4  20160228.0  20160228.0  POLYGON ((-122.432331 37.75622699999975, -122....
#
#                                           geometry_y     h_geocode  \
# 0  POLYGON ((-122.440616 37.750902, -122.440459 3...  6.075021e+13
# 1  POLYGON ((-122.438397 37.750226, -122.43832 37...  6.075021e+13
# 2  POLYGON ((-122.435808 37.757623, -122.435642 3...  6.075021e+13
# 3  POLYGON ((-122.436527 37.75354, -122.436454 37...  6.075021e+13
# 4  POLYGON ((-122.432331 37.756227, -122.432254 3...  6.075021e+13
#
#       w_geocode                                      centroid
# 0  6.075021e+13  POINT (-122.4410750952718 37.75006645242288)
# 1  6.075021e+13  POINT (-122.4389330377124 37.75019580711344)
# 2  6.075021e+13  POINT (-122.4362701327225 37.75679372444293)
# 3  6.075021e+13  POINT (-122.4370498299397 37.75352911966451)
# 4  6.075021e+13  POINT (-122.4334002333296 37.75575797076656)
#
# [5 rows x 37 columns]

# %%
data['LON'] = data['centroid'].apply(lambda row: row.x)

# %%
data['LAT'] = data['centroid'].apply(lambda row: row.y)

# %%
data.columns
# Out:
# Index(['ALAND10_x', 'ALAND10_y', 'AWATER10', 'BLOCKCE10', 'BLOCKID10',
#        'BLOCK_ID', 'COUNTYFP10', 'EDHLTH_RAC', 'EDHLTH_WAC', 'EMP_RAC',
#        'EMP_WAC', 'FUNCSTAT10', 'GEOID10', 'HOUSING_09', 'INTPTLAT10',
#        'INTPTLON10', 'LEISER_RAC', 'LEISER_WAC', 'MTFCC10', 'NAME10',
#        'OTHER_RAC', 'OTHER_WAC', 'RETAIL_RAC', 'RETAIL_WAC', 'STATEFP10',
#        'TRACTCE10', 'UACE10', 'UATYP10', 'UR10', 'Unnamed_ 0', 'createda_1',
#        'createdate', 'geometry', 'geometry_y', 'h_geocode', 'w_geocode',
#        'centroid', 'LON', 'LAT'],
#       dtype='object')

# %%
keep = ['LAT','LON','EMP_WAC','EMP_RAC']

# %%
data_points = data[keep]

# %%
data_points.head()
# Out:
#          LAT         LON  EMP_WAC  EMP_RAC
# 0  37.750066 -122.441075      7.0     61.0
# 1  37.750196 -122.438933      1.0     79.0
# 2  37.756794 -122.436270      1.0     84.0
# 3  37.753529 -122.437050     22.0     58.0
# 4  37.755758 -122.433400      3.0     90.0

# %%
data_points.to_csv('E:/Transit-Casa-Alex/Accessbility_Points.csv')

# %%
data.head()
# Out:
#        ALAND10_x  ALAND10_y  AWATER10  BLOCKCE10     BLOCKID10      BLOCK_ID  \
# 0  182505.545918    16958.0       0.0     2002.0  6.075021e+13  6.075021e+13
# 1  181052.857519    16823.0       0.0     2000.0  6.075021e+13  6.075021e+13
# 2  183174.823888    17020.0       0.0     3004.0  6.075021e+13  6.075021e+13
# 3  176663.550351    16415.0       0.0     1003.0  6.075021e+13  6.075021e+13
# 4  188584.943478    17523.0       0.0     4001.0  6.075021e+13  6.075021e+13
#
#    COUNTYFP10  EDHLTH_RAC  EDHLTH_WAC  EMP_RAC  \
# 0        75.0        16.0         7.0     61.0
# 1        75.0        19.0         0.0     79.0
# 2        75.0        25.0         0.0     84.0
# 3        75.0        10.0         8.0     58.0
# 4        75.0        22.0         1.0     90.0
#
#                          ...                          createda_1  createdate  \
# 0                        ...                          20160228.0  20160228.0
# 1                        ...                          20160228.0  20160228.0
# 2                        ...                          20160228.0  20160228.0
# 3                        ...                          20160228.0  20160228.0
# 4                        ...                          20160228.0  20160228.0
#
#                                             geometry  \
# 0  POLYGON ((-122.440616 37.75090199999977, -122....
# 1  POLYGON ((-122.438397 37.75022599999975, -122....
# 2  POLYGON ((-122.435808 37.75762299999975, -122....
# 3  POLYGON ((-122.436527 37.75353999999976, -122....
# 4  POLYGON ((-122.432331 37.75622699999975, -122....
#
#                                           geometry_y     h_geocode  \
# 0  POLYGON ((-122.440616 37.750902, -122.440459 3...  6.075021e+13
# 1  POLYGON ((-122.438397 37.750226, -122.43832 37...  6.075021e+13
# 2  POLYGON ((-122.435808 37.757623, -122.435642 3...  6.075021e+13
# 3  POLYGON ((-122.436527 37.75354, -122.436454 37...  6.075021e+13
# 4  POLYGON ((-122.432331 37.756227, -122.432254 3...  6.075021e+13
#
#       w_geocode                                      centroid         LON  \
# 0  6.075021e+13  POINT (-122.4410750952718 37.75006645242288) -122.441075
# 1  6.075021e+13  POINT (-122.4389330377124 37.75019580711344) -122.438933
# 2  6.075021e+13  POINT (-122.4362701327225 37.75679372444293) -122.436270
# 3  6.075021e+13  POINT (-122.4370498299397 37.75352911966451) -122.437050
# 4  6.075021e+13  POINT (-122.4334002333296 37.75575797076656) -122.433400
#
#          LAT                                            ADDRESS
# 0  37.750066  <[OK] Google - Reverse [49 Fountain St, San Fr...
# 1  37.750196  <[OK] Google - Reverse [820 Douglass St, San F...
# 2  37.756794  <[OK] Google - Reverse [342 Collingwood St, Sa...
# 3  37.753529  <[OK] Google - Reverse [545 Eureka St, San Fra...
# 4  37.755758  <[OK] Google - Reverse [3855 21st St, San Fran...
#
# [5 rows x 40 columns]

# %%
geocoder.google([37,-122],method = 'reverse')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     137             conn = connection.create_connection(
# --> 138                 (self.host, self.port), self.timeout, **extra_kw)
#     139
#
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      97     if err is not None:
# ---> 98         raise err
#      99
#
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      87                 sock.bind(source_address)
# ---> 88             sock.connect(sa)
#      89             return sock
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     593                                                   body=body, headers=headers,
# --> 594                                                   chunked=chunked)
#     595
#
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     349         try:
# --> 350             self._validate_conn(conn)
#     351         except (SocketTimeout, BaseSSLError) as e:
#
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     834         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 835             conn.connect()
#     836
#
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\connection.py in connect(self)
#     280         # Add certificate verification
# --> 281         conn = self._new_conn()
#     282
#
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     146             raise NewConnectionError(
# --> 147                 self, "Failed to establish a new connection: %s" % e)
#     148
#
# NewConnectionError: <requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x000001E47FDF4630>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     642             retries = retries.increment(method, url, error=e, _pool=self,
# --> 643                                         _stacktrace=sys.exc_info()[2])
#     644             retries.sleep()
#
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     362         if new_retry.is_exhausted():
# --> 363             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     364
#
# MaxRetryError: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?sensor=false&language=&latlng=37.0%2C+-122.0 (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x000001E47FDF4630>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-56-c3027b7f2192> in <module>()
# ----> 1 geocoder.google([37,-122],method = 'reverse')
#
# C:\Anaconda\lib\site-packages\geocoder\api.py in google(location, **kwargs)
#     184         > elevation
#     185     """
# --> 186     return get(location, provider='google', **kwargs)
#     187
#     188
#
# C:\Anaconda\lib\site-packages\geocoder\api.py in get(location, **kwargs)
#     150         if method not in options[provider]:
#     151             raise ValueError("Invalid method")
# --> 152     return options[provider][method](location, **kwargs)
#     153
#     154
#
# C:\Anaconda\lib\site-packages\geocoder\google.py in __init__(self, location, **kwargs)
#      52         elif kwargs.get('key', google_key):
#      53             self.params['key'] = kwargs.get('key', google_key)
# ---> 54         self._initialize(**kwargs)
#      55
#      56     def _location_init(self, location, **kwargs):
#
# C:\Anaconda\lib\site-packages\geocoder\base.py in _initialize(self, **kwargs)
#     124         self.encoding = kwargs.get('encoding', 'utf-8')
#     125         self.session = kwargs.get('session', requests.Session())
# --> 126         self._connect(url=self.url, **kwargs)
#     127         ###
#     128         try:
#
# C:\Anaconda\lib\site-packages\geocoder\base.py in _connect(self, **kwargs)
#      94                 headers=self.headers,
#      95                 timeout=self.timeout,
# ---> 96                 proxies=self.proxies
#      97             )
#      98             self.status_code = r.status_code
#
# C:\Anaconda\lib\site-packages\geocoder\base.py in rate_limited_get(self, url, **kwargs)
#      71
#      72     def rate_limited_get(self, url, **kwargs):
# ---> 73         return self.session.get(url, **kwargs)
#      74
#      75     @staticmethod
#
# C:\Anaconda\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     499
#     500         kwargs.setdefault('allow_redirects', True)
# --> 501         return self.request('GET', url, **kwargs)
#     502
#     503     def options(self, url, **kwargs):
#
# C:\Anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# C:\Anaconda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# C:\Anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     485                 raise ProxyError(e, request=request)
#     486
# --> 487             raise ConnectionError(e, request=request)
#     488
#     489         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?sensor=false&language=&latlng=37.0%2C+-122.0 (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x000001E47FDF4630>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',))

# %%
data.ADDRESS = np.nan
index = data.index
for i in index:
    print(i)
    data.ADDRESS[i] = geocoder.google([data.LAT[i],data.LON[i]],method = 'reverse')
# Out:
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     137             conn = connection.create_connection(
# --> 138                 (self.host, self.port), self.timeout, **extra_kw)
#     139
#
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      97     if err is not None:
# ---> 98         raise err
#      99
#
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      87                 sock.bind(source_address)
# ---> 88             sock.connect(sa)
#      89             return sock
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     593                                                   body=body, headers=headers,
# --> 594                                                   chunked=chunked)
#     595
#
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     349         try:
# --> 350             self._validate_conn(conn)
#     351         except (SocketTimeout, BaseSSLError) as e:
#
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     834         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 835             conn.connect()
#     836
#
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\connection.py in connect(self)
#     280         # Add certificate verification
# --> 281         conn = self._new_conn()
#     282
#
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     146             raise NewConnectionError(
# --> 147                 self, "Failed to establish a new connection: %s" % e)
#     148
#
# NewConnectionError: <requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x000001E47C3E80F0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     642             retries = retries.increment(method, url, error=e, _pool=self,
# --> 643                                         _stacktrace=sys.exc_info()[2])
#     644             retries.sleep()
#
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     362         if new_retry.is_exhausted():
# --> 363             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     364
#
# MaxRetryError: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?sensor=false&language=&latlng=37.75549745635298%2C+-122.44190993215227 (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x000001E47C3E80F0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-45-05d849782979> in <module>()
#       3 for i in index:
#       4
# ----> 5     data.ADDRESS[i] = geocoder.google([data.LAT[i],data.LON[i]],method = 'reverse')
#
# C:\Anaconda\lib\site-packages\geocoder\api.py in google(location, **kwargs)
#     184         > elevation
#     185     """
# --> 186     return get(location, provider='google', **kwargs)
#     187
#     188
#
# C:\Anaconda\lib\site-packages\geocoder\api.py in get(location, **kwargs)
#     150         if method not in options[provider]:
#     151             raise ValueError("Invalid method")
# --> 152     return options[provider][method](location, **kwargs)
#     153
#     154
#
# C:\Anaconda\lib\site-packages\geocoder\google.py in __init__(self, location, **kwargs)
#      52         elif kwargs.get('key', google_key):
#      53             self.params['key'] = kwargs.get('key', google_key)
# ---> 54         self._initialize(**kwargs)
#      55
#      56     def _location_init(self, location, **kwargs):
#
# C:\Anaconda\lib\site-packages\geocoder\base.py in _initialize(self, **kwargs)
#     124         self.encoding = kwargs.get('encoding', 'utf-8')
#     125         self.session = kwargs.get('session', requests.Session())
# --> 126         self._connect(url=self.url, **kwargs)
#     127         ###
#     128         try:
#
# C:\Anaconda\lib\site-packages\geocoder\base.py in _connect(self, **kwargs)
#      94                 headers=self.headers,
#      95                 timeout=self.timeout,
# ---> 96                 proxies=self.proxies
#      97             )
#      98             self.status_code = r.status_code
#
# C:\Anaconda\lib\site-packages\geocoder\base.py in rate_limited_get(self, url, **kwargs)
#      71
#      72     def rate_limited_get(self, url, **kwargs):
# ---> 73         return self.session.get(url, **kwargs)
#      74
#      75     @staticmethod
#
# C:\Anaconda\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     499
#     500         kwargs.setdefault('allow_redirects', True)
# --> 501         return self.request('GET', url, **kwargs)
#     502
#     503     def options(self, url, **kwargs):
#
# C:\Anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# C:\Anaconda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# C:\Anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     485                 raise ProxyError(e, request=request)
#     486
# --> 487             raise ConnectionError(e, request=request)
#     488
#     489         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?sensor=false&language=&latlng=37.75549745635298%2C+-122.44190993215227 (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x000001E47C3E80F0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',))

# %%
data['ADDRESS'] = data.apply(lambda row: geocoder.google([row['LAT'],row['LON']],method = 'reverse'),axis = 1)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     137             conn = connection.create_connection(
# --> 138                 (self.host, self.port), self.timeout, **extra_kw)
#     139
#
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      97     if err is not None:
# ---> 98         raise err
#      99
#
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      87                 sock.bind(source_address)
# ---> 88             sock.connect(sa)
#      89             return sock
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     593                                                   body=body, headers=headers,
# --> 594                                                   chunked=chunked)
#     595
#
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     349         try:
# --> 350             self._validate_conn(conn)
#     351         except (SocketTimeout, BaseSSLError) as e:
#
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     834         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 835             conn.connect()
#     836
#
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\connection.py in connect(self)
#     280         # Add certificate verification
# --> 281         conn = self._new_conn()
#     282
#
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     146             raise NewConnectionError(
# --> 147                 self, "Failed to establish a new connection: %s" % e)
#     148
#
# NewConnectionError: <requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x000001E407EF3D30>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     642             retries = retries.increment(method, url, error=e, _pool=self,
# --> 643                                         _stacktrace=sys.exc_info()[2])
#     644             retries.sleep()
#
# C:\Anaconda\lib\site-packages\requests\packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     362         if new_retry.is_exhausted():
# --> 363             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     364
#
# MaxRetryError: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?sensor=false&language=&latlng=37.75006645242288%2C+-122.44107509527183 (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x000001E407EF3D30>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-34-267cd188b3f4> in <module>()
# ----> 1 data['ADDRESS'] = data.apply(lambda row: geocoder.google([row['LAT'],row['LON']],method = 'reverse'),axis = 1)
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4150                     if reduce is None:
#    4151                         reduce = True
# -> 4152                     return self._apply_standard(f, axis, reduce=reduce)
#    4153             else:
#    4154                 return self._apply_broadcast(f, axis)
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4246             try:
#    4247                 for i, v in enumerate(series_gen):
# -> 4248                     results[i] = func(v)
#    4249                     keys.append(v.name)
#    4250             except Exception as e:
#
# <ipython-input-34-267cd188b3f4> in <lambda>(row)
# ----> 1 data['ADDRESS'] = data.apply(lambda row: geocoder.google([row['LAT'],row['LON']],method = 'reverse'),axis = 1)
#
# C:\Anaconda\lib\site-packages\geocoder\api.py in google(location, **kwargs)
#     184         > elevation
#     185     """
# --> 186     return get(location, provider='google', **kwargs)
#     187
#     188
#
# C:\Anaconda\lib\site-packages\geocoder\api.py in get(location, **kwargs)
#     150         if method not in options[provider]:
#     151             raise ValueError("Invalid method")
# --> 152     return options[provider][method](location, **kwargs)
#     153
#     154
#
# C:\Anaconda\lib\site-packages\geocoder\google.py in __init__(self, location, **kwargs)
#      52         elif kwargs.get('key', google_key):
#      53             self.params['key'] = kwargs.get('key', google_key)
# ---> 54         self._initialize(**kwargs)
#      55
#      56     def _location_init(self, location, **kwargs):
#
# C:\Anaconda\lib\site-packages\geocoder\base.py in _initialize(self, **kwargs)
#     124         self.encoding = kwargs.get('encoding', 'utf-8')
#     125         self.session = kwargs.get('session', requests.Session())
# --> 126         self._connect(url=self.url, **kwargs)
#     127         ###
#     128         try:
#
# C:\Anaconda\lib\site-packages\geocoder\base.py in _connect(self, **kwargs)
#      94                 headers=self.headers,
#      95                 timeout=self.timeout,
# ---> 96                 proxies=self.proxies
#      97             )
#      98             self.status_code = r.status_code
#
# C:\Anaconda\lib\site-packages\geocoder\base.py in rate_limited_get(self, url, **kwargs)
#      71
#      72     def rate_limited_get(self, url, **kwargs):
# ---> 73         return self.session.get(url, **kwargs)
#      74
#      75     @staticmethod
#
# C:\Anaconda\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     499
#     500         kwargs.setdefault('allow_redirects', True)
# --> 501         return self.request('GET', url, **kwargs)
#     502
#     503     def options(self, url, **kwargs):
#
# C:\Anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# C:\Anaconda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# C:\Anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     485                 raise ProxyError(e, request=request)
#     486
# --> 487             raise ConnectionError(e, request=request)
#     488
#     489         except ClosedPoolError as e:
#
# ConnectionError: (MaxRetryError("HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?sensor=false&language=&latlng=37.75006645242288%2C+-122.44107509527183 (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x000001E407EF3D30>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',))",), 'occurred at index 0')

# %%
data.head()
# Out:
#        ALAND10_x  ALAND10_y  AWATER10  BLOCKCE10     BLOCKID10      BLOCK_ID  \
# 0  182505.545918    16958.0       0.0     2002.0  6.075021e+13  6.075021e+13
# 1  181052.857519    16823.0       0.0     2000.0  6.075021e+13  6.075021e+13
# 2  183174.823888    17020.0       0.0     3004.0  6.075021e+13  6.075021e+13
# 3  176663.550351    16415.0       0.0     1003.0  6.075021e+13  6.075021e+13
# 4  188584.943478    17523.0       0.0     4001.0  6.075021e+13  6.075021e+13
#
#    COUNTYFP10  EDHLTH_RAC  EDHLTH_WAC  EMP_RAC  \
# 0        75.0        16.0         7.0     61.0
# 1        75.0        19.0         0.0     79.0
# 2        75.0        25.0         0.0     84.0
# 3        75.0        10.0         8.0     58.0
# 4        75.0        22.0         1.0     90.0
#
#                    ...                   createda_1  createdate  \
# 0                  ...                   20160228.0  20160228.0
# 1                  ...                   20160228.0  20160228.0
# 2                  ...                   20160228.0  20160228.0
# 3                  ...                   20160228.0  20160228.0
# 4                  ...                   20160228.0  20160228.0
#
#                                             geometry  \
# 0  POLYGON ((-122.440616 37.75090199999977, -122....
# 1  POLYGON ((-122.438397 37.75022599999975, -122....
# 2  POLYGON ((-122.435808 37.75762299999975, -122....
# 3  POLYGON ((-122.436527 37.75353999999976, -122....
# 4  POLYGON ((-122.432331 37.75622699999975, -122....
#
#                                           geometry_y     h_geocode  \
# 0  POLYGON ((-122.440616 37.750902, -122.440459 3...  6.075021e+13
# 1  POLYGON ((-122.438397 37.750226, -122.43832 37...  6.075021e+13
# 2  POLYGON ((-122.435808 37.757623, -122.435642 3...  6.075021e+13
# 3  POLYGON ((-122.436527 37.75354, -122.436454 37...  6.075021e+13
# 4  POLYGON ((-122.432331 37.756227, -122.432254 3...  6.075021e+13
#
#       w_geocode                                      centroid         LON  \
# 0  6.075021e+13  POINT (-122.4410750952718 37.75006645242288) -122.441075
# 1  6.075021e+13  POINT (-122.4389330377124 37.75019580711344) -122.438933
# 2  6.075021e+13  POINT (-122.4362701327225 37.75679372444293) -122.436270
# 3  6.075021e+13  POINT (-122.4370498299397 37.75352911966451) -122.437050
# 4  6.075021e+13  POINT (-122.4334002333296 37.75575797076656) -122.433400
#
#          LAT                               ADDRESS
# 0  37.750066  <[INVALID_REQUEST] Google - Reverse>
# 1  37.750196  <[INVALID_REQUEST] Google - Reverse>
# 2  37.756794  <[INVALID_REQUEST] Google - Reverse>
# 3  37.753529  <[INVALID_REQUEST] Google - Reverse>
# 4  37.755758  <[INVALID_REQUEST] Google - Reverse>
#
# [5 rows x 40 columns]

# %%
data['ADDRESS'] = geocoder.google_reverse

# %%
data['ADDRESS'] = geocoder.distance
