# %%
import geopandas as gp

# %%
sf = gp.read_file('E:/Transit-Casa-Alex/Input/2010 Cenusus Shapefiles/2010 Census Blocks/075/tl_2010_06075_tabblock10.shp')

# %%
sm = gp.read_file('E:/Transit-Casa-Alex/Input/2010 Cenusus Shapefiles/2010 Census Blocks/081/tl_2010_06081_tabblock10.shp')

# %%
sm.head()
# Out:
#    ALAND10  AWATER10 BLOCKCE10 COUNTYFP10 FUNCSTAT10          GEOID10  \
# 0    17681         0      4001        081          S  060816129004001
# 1    24257         0      2006        081          S  060816128002006
# 2   146005         0      2000        081          S  060816086002000
# 3    38352         0      2006        081          S  060816113002006
# 4    21309         0      2005        081          S  060816096032005
#
#     INTPTLAT10    INTPTLON10 MTFCC10      NAME10 STATEFP10 TRACTCE10 UACE10  \
# 0  +37.4303914  -122.2008904   G5040  Block 4001        06    612900  78904
# 1  +37.4343706  -122.2005754   G5040  Block 2006        06    612800  78904
# 2  +37.5331810  -122.2714609   G5040  Block 2000        06    608600  78904
# 3  +37.4527839  -122.2266250   G5040  Block 2006        06    611300  78904
# 4  +37.4817289  -122.2801183   G5040  Block 2005        06    609603  78904
#
#   UATYP10 UR10                                           geometry
# ...

# %%
sf.head()
# Out:
#    ALAND10  AWATER10 BLOCKCE10 COUNTYFP10 FUNCSTAT10          GEOID10  \
# 0    16958         0      2002        075          S  060750213002002
# 1    16823         0      2000        075          S  060750213002000
# 2    17020         0      3004        075          S  060750205003004
# 3    16415         0      1003        075          S  060750212001003
# 4    17523         0      4001        075          S  060750211004001
#
#     INTPTLAT10    INTPTLON10 MTFCC10      NAME10 STATEFP10 TRACTCE10 UACE10  \
# 0  +37.7500665  -122.4410751   G5040  Block 2002        06    021300  78904
# 1  +37.7501958  -122.4389330   G5040  Block 2000        06    021300  78904
# 2  +37.7567937  -122.4362701   G5040  Block 3004        06    020500  78904
# 3  +37.7535291  -122.4370498   G5040  Block 1003        06    021200  78904
# 4  +37.7557580  -122.4334002   G5040  Block 4001        06    021100  78904
#
#   UATYP10 UR10                                           geometry
# ...
