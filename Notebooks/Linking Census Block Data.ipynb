# %%
import pandas as pd
import geopandas as gp
# %matplotlib inline
pd.set_option('max_columns',500)

# %%
gp.read_file?

# %%
pop = gp.read_file('E:\Transit-Casa-Alex\Output\Population and Housing Units/Population_Houses_Blocks_StatePlane.shp',)

# %%
emp = gp.read_file('E:/Transit-Casa-Alex/Output/Employment (LEHD)/Combined_Employment.shp')

# %%
pop.head()
# Out:
#     BLOCKID10  HOUSING10 PARTFLG  POP10  \
# 0  2147483647         33       N    116
# 1  2147483647          1       N      1
# 2  2147483647         64       N    237
# 3  2147483647          0       N      0
# 4  2147483647        145       N    196
#
#                                             geometry
# 0  POLYGON ((5992058.405556438 2087902.287818863,...
# 1  POLYGON ((5999943.672475721 2092569.274511323,...
# 2  POLYGON ((6000849.933326537 2090794.687264399,...
# 3  POLYGON ((6007169.27881051 2109632.156445771, ...
# 4  POLYGON ((6008635.042823807 2110187.406908512,...

# %%
emp.head()
# Out:
#    ALAND10  AWATER10 BLOCKCE10 COUNTYFP10  EDHEALTH_R  EDHEALTH_W FUNCSTAT10  \
# 0    16958         0      2002        075        16.0         7.0          S
# 1    16823         0      2000        075        19.0         0.0          S
# 2    17020         0      3004        075        25.0         0.0          S
# 3    16415         0      1003        075        10.0         8.0          S
# 4    17523         0      4001        075        22.0         1.0          S
#
#       GEOID10   INTPTLAT10    INTPTLON10  LEISURE_RA  LEISURE_WA MTFCC10  \
# 0  2147483647  +37.7500665  -122.4410751         6.0         0.0   G5040
# 1  2147483647  +37.7501958  -122.4389330         9.0         0.0   G5040
# 2  2147483647  +37.7567937  -122.4362701         6.0         0.0   G5040
# 3  2147483647  +37.7535291  -122.4370498         5.0         0.0   G5040
# 4  2147483647  +37.7557580  -122.4334002         5.0         0.0   G5040
#
# ...

# %%
pop.plot()

# %%
emp.plot()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-f2f47c3b5868> in <module>()
# ----> 1 emp.plot()
#
# C:\Anaconda\lib\site-packages\geopandas\geodataframe.py in plot(self, *args, **kwargs)
#     445     def plot(self, *args, **kwargs):
#     446
# --> 447         return plot_dataframe(self, *args, **kwargs)
#     448
#     449     plot.__doc__ = plot_dataframe.__doc__
#
# C:\Anaconda\lib\site-packages\geopandas\plotting.py in plot_dataframe(s, column, cmap, color, linewidth, categorical, legend, ax, scheme, k, vmin, vmax, figsize, **color_kwds)
#     238         return plot_series(s.geometry, cmap=cmap, color=color,
#     239                            ax=ax, linewidth=linewidth, figsize=figsize,
# --> 240                            **color_kwds)
#     241     else:
#     242         if s[column].dtype is np.dtype('O'):
#
# ...

# %%
print(len(pop))
len(emp)
# Out:
# 16648
# 16387

# %%
pop.BLOCKID10.unique()
# Out:
# array([2147483647], dtype=int64)

# %%
pop.sort_values(by = 'BLOCKID10')
# Out:
#         BLOCKID10  HOUSING10 PARTFLG  POP10  \
# 0      2147483647         33       N    116
# 11090  2147483647         26       N     72
# 11091  2147483647         31       N     78
# 11092  2147483647          0       N      0
# 11093  2147483647         19       N     55
# 11094  2147483647         41       N     93
# 11095  2147483647         14       N     31
# 11096  2147483647         24       N     57
# 11097  2147483647         25       N     49
# 11098  2147483647         14       N     32
# 11099  2147483647         23       N     58
# 11100  2147483647         34       N    102
# 11101  2147483647         16       N     53
# 11102  2147483647         48       N    146
# 11089  2147483647         17       N     50
# 11103  2147483647        134       N    421
# 11105  2147483647         31       N     71
# 11106  2147483647         36       N    106
# 11107  2147483647          0       N      0
# 11108  2147483647          0       N      0
# ...

# %%
pop_emp = pd.merge(pop,emp, how = 'outer', left_on = 'BLOCKID10',right_on = 'GEOID10')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6c49cfdb23dc> in <module>()
# ----> 1 pop_emp = pd.merge(pop,emp, how = 'outer', left_on = 'BLOCKID10',right_on = 'GEOID10')
#
# NameError: name 'pd' is not defined

# %%
pop_emp.plot()

# %%
pop_emp.head()
