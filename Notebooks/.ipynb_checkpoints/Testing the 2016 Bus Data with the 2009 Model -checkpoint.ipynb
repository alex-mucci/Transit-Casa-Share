# %%
import pandas as pd
import seaborn as sns
import numpy as np
import statsmodels.api as smf
from matplotlib import pyplot as plt

pd.set_option('display.max_columns', 500)


# %matplotlib inline

# %%
data = pd.read_csv('E:/Transit-Casa-Alex/Output/Modeling/2016/Final_Model_Data_2016_Bus.csv',thousands = ',')

# %%
# Run 204
# Try the 2009 model with the 2016 bus data 

mod = smf.formula.ols(formula="LOG_RIDERS \
                       ~ EDD_EMP_LOG \
                       + FREQ_S_LOG \
                       + EOL_SOL \
                       + HOUSING_16_DEN_LOG \
                       + SHR_INCOME_100P \
                       + PARK_HOURLY_AVG_ON_LOG \
                       + ONTIME5 \
                       + AVG_BART_LOG \
                       + CLOSE_STOP \
                       + LIMITED \
                       + EXPRESS \
                       + TRANSBAY \
                       + MUNI_RAIL_AVG \
                       + CAL_STATION \
                       -1",
             data = data)

res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             LOG_RIDERS   R-squared:                       0.930
# Model:                            OLS   Adj. R-squared:                  0.930
# Method:                 Least Squares   F-statistic:                 1.492e+04
# Date:                Wed, 26 Jul 2017   Prob (F-statistic):               0.00
# Time:                        18:27:13   Log-Likelihood:                -22606.
# No. Observations:               15804   AIC:                         4.524e+04
# Df Residuals:                   15790   BIC:                         4.535e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# EDD_EMP_LOG                0.1200      0.006     21.388      0.000       0.109       0.131
# FREQ_S_LOG                 2.3968      0.023    103.276      0.000       2.351       2.442
# EOL_SOL                    0.5152      0.035     14.708      0.000       0.447       0.584
# HOUSING_16_DEN_LOG         0.0680      0.007     10.320      0.000       0.055       0.081
# SHR_INCOME_100P           -1.2628      0.045    -28.253      0.000      -1.350      -1.175
# PARK_HOURLY_AVG_ON_LOG     0.0544      0.004     13.395      0.000       0.046       0.062
# ONTIME5                    0.4606      0.050      9.227      0.000       0.363       0.558
# AVG_BART_LOG               0.0515      0.006      8.152      0.000       0.039       0.064
# CLOSE_STOP                -1.1996      0.027    -45.174      0.000      -1.252      -1.148
# LIMITED                   -0.4833      0.047    -10.217      0.000      -0.576      -0.391
# EXPRESS                   -1.3256      0.033    -40.582      0.000      -1.390      -1.262
# TRANSBAY                   0.0446      0.100      0.444      0.657      -0.152       0.242
# MUNI_RAIL_AVG          -2.978e-06   5.12e-06     -0.582      0.561    -1.3e-05    7.05e-06
# CAL_STATION                0.3128      0.133      2.352      0.019       0.052       0.574
# ==============================================================================
# Omnibus:                      568.705   Durbin-Watson:                   1.154
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              726.668
# Skew:                          -0.402   Prob(JB):                    1.61e-158
# Kurtosis:                       3.676   Cond. No.                     3.53e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.53e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Run 204
# Try the 2009 model with the 2016 bus data 
# this is odd because muni bus avg did the same thing for the rail model 


mod = smf.formula.ols(formula="LOG_RIDERS \
                       ~ EDD_EMP_LOG \
                       + FREQ_S_LOG \
                       + EOL_SOL \
                       + HOUSING_16_DEN_LOG \
                       + SHR_INCOME_100P \
                       + PARK_HOURLY_AVG_ON_LOG \
                       + ONTIME5 \
                       + AVG_BART_LOG \
                       + CLOSE_STOP \
                       + LIMITED \
                       + EXPRESS \
                       + TRANSBAY \
                       + MUNI_RAIL_AVG_LOG \
                       + CAL_STATION \
                       -1",
             data = data)

res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             LOG_RIDERS   R-squared:                       0.930
# Model:                            OLS   Adj. R-squared:                  0.930
# Method:                 Least Squares   F-statistic:                 1.495e+04
# Date:                Wed, 26 Jul 2017   Prob (F-statistic):               0.00
# Time:                        18:28:12   Log-Likelihood:                -22593.
# No. Observations:               15804   AIC:                         4.521e+04
# Df Residuals:                   15790   BIC:                         4.532e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# EDD_EMP_LOG                0.1223      0.006     21.933      0.000       0.111       0.133
# FREQ_S_LOG                 2.3856      0.023    102.639      0.000       2.340       2.431
# EOL_SOL                    0.5274      0.035     15.035      0.000       0.459       0.596
# HOUSING_16_DEN_LOG         0.0679      0.007     10.316      0.000       0.055       0.081
# SHR_INCOME_100P           -1.2497      0.045    -27.951      0.000      -1.337      -1.162
# PARK_HOURLY_AVG_ON_LOG     0.0540      0.004     13.316      0.000       0.046       0.062
# ONTIME5                    0.4680      0.050      9.379      0.000       0.370       0.566
# AVG_BART_LOG               0.0598      0.006     10.791      0.000       0.049       0.071
# CLOSE_STOP                -1.1900      0.027    -44.755      0.000      -1.242      -1.138
# LIMITED                   -0.4750      0.047    -10.044      0.000      -0.568      -0.382
# EXPRESS                   -1.3271      0.033    -40.663      0.000      -1.391      -1.263
# TRANSBAY                   0.0427      0.100      0.425      0.671      -0.154       0.239
# MUNI_RAIL_AVG_LOG         -0.0183      0.004     -5.102      0.000      -0.025      -0.011
# CAL_STATION                0.3860      0.133      2.898      0.004       0.125       0.647
# ==============================================================================
# Omnibus:                      552.500   Durbin-Watson:                   1.169
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              722.386
# Skew:                          -0.386   Prob(JB):                    1.37e-157
# Kurtosis:                       3.707   Cond. No.                         142.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Run 204
# We have to use the 2009 model though

mod = smf.formula.ols(formula="LOG_RIDERS \
                       ~ EDD_EMP_LOG \
                       + FREQ_S_LOG \
                       + EOL_SOL \
                       + HOUSING_16_DEN_LOG \
                       + SHR_INCOME_100P \
                       + PARK_HOURLY_AVG_ON_LOG \
                       + ONTIME5 \
                       + AVG_BART_LOG \
                       + CLOSE_STOP \
                       + LIMITED \
                       + EXPRESS \
                       + TRANSBAY \
                       + MUNI_RAIL_AVG \
                       + CAL_STATION \
                       -1",
             data = data)

res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             LOG_RIDERS   R-squared:                       0.930
# Model:                            OLS   Adj. R-squared:                  0.930
# Method:                 Least Squares   F-statistic:                 1.492e+04
# Date:                Wed, 26 Jul 2017   Prob (F-statistic):               0.00
# Time:                        18:28:28   Log-Likelihood:                -22606.
# No. Observations:               15804   AIC:                         4.524e+04
# Df Residuals:                   15790   BIC:                         4.535e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# EDD_EMP_LOG                0.1200      0.006     21.388      0.000       0.109       0.131
# FREQ_S_LOG                 2.3968      0.023    103.276      0.000       2.351       2.442
# EOL_SOL                    0.5152      0.035     14.708      0.000       0.447       0.584
# HOUSING_16_DEN_LOG         0.0680      0.007     10.320      0.000       0.055       0.081
# SHR_INCOME_100P           -1.2628      0.045    -28.253      0.000      -1.350      -1.175
# PARK_HOURLY_AVG_ON_LOG     0.0544      0.004     13.395      0.000       0.046       0.062
# ONTIME5                    0.4606      0.050      9.227      0.000       0.363       0.558
# AVG_BART_LOG               0.0515      0.006      8.152      0.000       0.039       0.064
# CLOSE_STOP                -1.1996      0.027    -45.174      0.000      -1.252      -1.148
# LIMITED                   -0.4833      0.047    -10.217      0.000      -0.576      -0.391
# EXPRESS                   -1.3256      0.033    -40.582      0.000      -1.390      -1.262
# TRANSBAY                   0.0446      0.100      0.444      0.657      -0.152       0.242
# MUNI_RAIL_AVG          -2.978e-06   5.12e-06     -0.582      0.561    -1.3e-05    7.05e-06
# CAL_STATION                0.3128      0.133      2.352      0.019       0.052       0.574
# ==============================================================================
# Omnibus:                      568.705   Durbin-Watson:                   1.154
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              726.668
# Skew:                          -0.402   Prob(JB):                    1.61e-158
# Kurtosis:                       3.676   Cond. No.                     3.53e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.53e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
sns.distplot(res.resid)

# %%
plt.scatter(res.resid.index,res.resid)

# %%
smf.graphics.qqplot(res.resid,line = 'q')

# %%
smf.graphics.influence_plot(res)
