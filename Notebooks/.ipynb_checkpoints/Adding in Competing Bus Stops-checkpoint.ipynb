# %%
import pandas as pd
import geopandas as gp
import pyproj as proj
# %matplotlib inline

# %% [markdown]
# # Go to markdown cell below

# %%
stops = gp.read_file('E:/Transit-Casa-Alex/Input/Bus_Stops/Bus_Stops_USft.shp')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-782871da97bb> in <module>()
# ----> 1 stops = gp.read_file('E:/Transit-Casa-Alex/Input/Bus_Stops/Bus_Stops_USft.shp')
#
# C:\Anaconda\lib\site-packages\geopandas\io\file.py in read_file(filename, **kwargs)
#      19     """
#      20     bbox = kwargs.pop('bbox', None)
# ---> 21     with fiona.open(filename, **kwargs) as f:
#      22         crs = f.crs
#      23         if bbox is not None:
#
# C:\Anaconda\lib\site-packages\fiona\__init__.py in open(path, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt)
#     164                 raise IOError("no such archive file: %r" % archive)
#     165         elif path != '-' and not os.path.exists(path):
# --> 166             raise IOError("no such file or directory: %r" % path)
#     167         c = Collection(path, mode, driver=driver, encoding=encoding,
#     168                        layer=layer, vsi=vsi, archive=archive,
#
# OSError: no such file or directory: 'E:/Transit-Casa-Alex/Input/Bus_Stops/Bus_Stops_USft.shp'

# %%
data = gp.read_file('E:/Transit-Casa-Alex/Output/Buffers/Tenth/Data Shapefile/Buffer10_Data.shp')

# %%
stops.plot()

# %%
data.columns
# Out:
# Index(['AGENCY_ID', 'ALAND10', 'AREA_FT', 'ARRIVAL_TI', 'BIKERACK',
#        'BUFF_DIST', 'CAPACITY', 'CROWDED', 'CROWDHOURS', 'DEPARTURE_',
#        'DOORCYCLES', 'DOW', 'DWELL', 'DWELL_S', 'EDHEALTH', 'EDHEALTH_D',
#        'EOL', 'Employment', 'FARE', 'FULLFARE_R', 'GEOID10', 'HEADWAY_S',
#        'Join_Count', 'LEISURE', 'LEISURE_DE', 'LOAD_ARR', 'LOAD_DEP', 'MONTH',
#        'NUMDAYS', 'OBSDAYS', 'OBS_TRIP_S', 'OFF', 'ON', 'ONTIME5', 'ORIG_FID',
#        'OTHER', 'OTHER_DEN', 'PASSDELAY_', 'PASSDELA_1', 'PASSHOURS',
#        'PASSMILES', 'RDBRDNGS', 'RETAIL', 'RETAIL_DEN', 'RUNSPEED',
#        'RUNSPEED_S', 'RUNTIME', 'RUNTIME_S', 'SERVMILES', 'SERVMILES_', 'SOL',
#        'STOPNAME', 'STOPNAME_A', 'STOP_ID', 'STOP_LAT_x', 'STOP_LAT_y',
#        'STOP_LON_x', 'STOP_LON_y', 'TARGET_FID', 'TIMEPOINT', 'TOTAL_EMP',
#        'TOTSPEED', 'TOTSPEED_S', 'TOTTIME', 'TOTTIME_S', 'TRIP_STOPS', 'VC',
#        'WAITHOURS', 'WGT_TRIP_S', 'WHEELCHAIR', 'geometry', 'w_geocode'],
#       dtype='object')

# %%
data.plot()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-66a0473f7c22> in <module>()
# ----> 1 data.plot()
#
# C:\Anaconda\lib\site-packages\geopandas\geodataframe.py in plot(self, *args, **kwargs)
#     445     def plot(self, *args, **kwargs):
#     446
# --> 447         return plot_dataframe(self, *args, **kwargs)
#     448
#     449     plot.__doc__ = plot_dataframe.__doc__
#
# C:\Anaconda\lib\site-packages\geopandas\plotting.py in plot_dataframe(s, column, cmap, color, linewidth, categorical, legend, ax, scheme, k, vmin, vmax, figsize, **color_kwds)
#     238         return plot_series(s.geometry, cmap=cmap, color=color,
#     239                            ax=ax, linewidth=linewidth, figsize=figsize,
# --> 240                            **color_kwds)
#     241     else:
#     242         if s[column].dtype is np.dtype('O'):
#
# C:\Anaconda\lib\site-packages\geopandas\plotting.py in plot_series(s, cmap, color, ax, linewidth, figsize, **color_kwds)
#     141                 plot_multipolygon(ax, geom, linewidth=linewidth, **color_kwds)
#     142             else:
# --> 143                 plot_multipolygon(ax, geom, facecolor=col, linewidth=linewidth, **color_kwds)
#     144         elif geom.type == 'LineString' or geom.type == 'MultiLineString':
#     145             plot_multilinestring(ax, geom, color=col, linewidth=linewidth, **color_kwds)
#
# C:\Anaconda\lib\site-packages\geopandas\plotting.py in plot_multipolygon(ax, geom, facecolor, edgecolor, alpha, linewidth, **kwargs)
#      28     """
#      29     if geom.type == 'Polygon':
# ---> 30         plot_polygon(ax, geom, facecolor=facecolor, edgecolor=edgecolor, alpha=alpha, linewidth=linewidth, **kwargs)
#      31     elif geom.type == 'MultiPolygon':
#      32         for poly in geom.geoms:
#
# C:\Anaconda\lib\site-packages\geopandas\plotting.py in plot_polygon(ax, poly, facecolor, edgecolor, alpha, linewidth, **kwargs)
#      18     # without Descartes, we could make a Patch of exterior
#      19     ax.add_patch(PolygonPatch(poly, facecolor=facecolor, linewidth=0, alpha=alpha))  # linewidth=0 because boundaries are drawn separately
# ---> 20     ax.plot(a[:, 0], a[:, 1], color=edgecolor, linewidth=linewidth, **kwargs)
#      21     for p in poly.interiors:
#      22         x, y = zip(*p.coords)
#
# C:\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1889                     warnings.warn(msg % (label_namer, func.__name__),
#    1890                                   RuntimeWarning, stacklevel=2)
# -> 1891             return func(ax, *args, **kwargs)
#    1892         pre_doc = inner.__doc__
#    1893         if pre_doc is None:
#
# C:\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in plot(self, *args, **kwargs)
#    1408             lines.append(line)
#    1409
# -> 1410         self.autoscale_view(scalex=scalex, scaley=scaley)
#    1411         return lines
#    1412
#
# C:\Anaconda\lib\site-packages\matplotlib\axes\_base.py in autoscale_view(self, tight, scalex, scaley)
#    2258
#    2259         if self.use_sticky_edges and (self._xmargin or self._ymargin):
# -> 2260             stickies = [artist.sticky_edges for artist in self.get_children()]
#    2261             x_stickies = sum([sticky.x for sticky in stickies], [])
#    2262             y_stickies = sum([sticky.y for sticky in stickies], [])
#
# C:\Anaconda\lib\site-packages\matplotlib\axes\_base.py in <listcomp>(.0)
#    2258
#    2259         if self.use_sticky_edges and (self._xmargin or self._ymargin):
# -> 2260             stickies = [artist.sticky_edges for artist in self.get_children()]
#    2261             x_stickies = sum([sticky.x for sticky in stickies], [])
#    2262             y_stickies = sum([sticky.y for sticky in stickies], [])
#
# KeyboardInterrupt:

# %%
stops.crs
# Out:
# {'datum': 'NAD27',
#  'lat_0': 36.5,
#  'lat_1': 37.06666666666667,
#  'lat_2': 38.43333333333333,
#  'lon_0': -120.5,
#  'no_defs': True,
#  'proj': 'lcc',
#  'units': 'us-ft',
#  'x_0': 609601.2192024384,
#  'y_0': 0}

# %% [markdown]
# ## punted and did the process in GIS
# * Still need to separate competing bus stops based on whether they are the same route or from different routes

# %% [markdown]
# # Start Here, got the ball back and scored

# %%
stops = gp.read_file('E:/Transit-Casa-Alex/Input/Bus_Stops/2009/Post-Deleted_Stops/Bus_Stops.shp')

# %%
stops.plot()

# %%
stops.head()
# Out:
#    STOP_ID   STOP_LAT    STOP_LON                       geometry
# 0      390  37.721190 -122.475096   POINT (-122.475096 37.72119)
# 1      392  37.765159 -122.477210   POINT (-122.47721 37.765159)
# 2      660  37.723914 -122.435387  POINT (-122.435387 37.723914)
# 3      913  37.719192 -122.425802  POINT (-122.425802 37.719192)
# 4     3001  37.788530 -122.396044   POINT (-122.396044 37.78853)

# %%
buffer = gp.read_file('E:/Transit-Casa-Alex/Output/Buffers/2009/Quarter/Buffers_Quarter_GCS.shp')

# %%
buffer.plot()

# %%
buffer.crs = {'init':'epsg:4269'}
stops.crs = {'init':'epsg:4326'}

# %%
stops = stops.to_crs(buffer.crs)

# %%
joined = gp.sjoin(buffer[['STOP_ID','geometry']],stops[['STOP_LAT','STOP_LON','geometry']],how = 'left')

# %%
joined.head(20)
# Out:
#    STOP_ID                                           geometry  index_right  \
# 0      390  POLYGON ((-122.4690122407114 37.72129184758299...          300
# 0      390  POLYGON ((-122.4690122407114 37.72129184758299...         1507
# 0      390  POLYGON ((-122.4690122407114 37.72129184758299...         1433
# 0      390  POLYGON ((-122.4690122407114 37.72129184758299...          903
# 0      390  POLYGON ((-122.4690122407114 37.72129184758299...          308
# 0      390  POLYGON ((-122.4690122407114 37.72129184758299...          902
# 0      390  POLYGON ((-122.4690122407114 37.72129184758299...          307
# 0      390  POLYGON ((-122.4690122407114 37.72129184758299...          759
# 0      390  POLYGON ((-122.4690122407114 37.72129184758299...         1506
# 0      390  POLYGON ((-122.4690122407114 37.72129184758299...          299
# 0      390  POLYGON ((-122.4690122407114 37.72129184758299...         1051
# 0      390  POLYGON ((-122.4690122407114 37.72129184758299...          600
# 0      390  POLYGON ((-122.4690122407114 37.72129184758299...         1054
# 0      390  POLYGON ((-122.4690122407114 37.72129184758299...         1015
# 0      390  POLYGON ((-122.4690122407114 37.72129184758299...         1014
# 0      390  POLYGON ((-122.4690122407114 37.72129184758299...          304
# 0      390  POLYGON ((-122.4690122407114 37.72129184758299...          303
# 0      390  POLYGON ((-122.4690122407114 37.72129184758299...            0
# 0      390  POLYGON ((-122.4690122407114 37.72129184758299...         1718
# 0      390  POLYGON ((-122.4690122407114 37.72129184758299...         1717
#
#     STOP_LAT    STOP_LON
# 0  37.725785 -122.475051
# 0  37.716693 -122.475907
# 0  37.716782 -122.475758
# 0  37.717264 -122.474430
# 0  37.717323 -122.472970
# 0  37.717443 -122.474270
# 0  37.718050 -122.473180
# 0  37.719040 -122.475380
# 0  37.719102 -122.475633
# 0  37.719530 -122.474580
# 0  37.719719 -122.471533
# 0  37.719728 -122.471739
# 0  37.719737 -122.469735
# 0  37.720100 -122.475940
# 0  37.720218 -122.475313
# 0  37.720940 -122.475004
# 0  37.721110 -122.475302
# 0  37.721190 -122.475096
# 0  37.721485 -122.472713
# 0  37.721592 -122.472954

# %%
comp = joined[['STOP_ID','geometry']].groupby(by = 'STOP_ID',as_index = False).count()

# %%
comp.columns=['STOP_ID','NUM_BUS_STOPS']

# %%
comp.NUM_BUS_STOPS = comp.NUM_BUS_STOPS - 1

# %%
comp.head()
# Out:
#    STOP_ID  NUM_BUS_STOPS
# 0      390             29
# 1      392             26
# 2      660             31
# 3      913             30
# 4     3001             58

# %%
comp.to_csv('E:/Transit-Casa-Alex/Output/Buffer Data/Competing Stops Buffers/2009/Quarter_Comp_Bus_Stops.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-0d32495e7ba2> in <module>()
# ----> 1 comp.to_csv('E:/Transit-Casa-Alex/Output/Buffer Data/Competing Stops Buffers/2009/Quarter_Comp_Bus_Stops.csv')
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1381                                      doublequote=doublequote,
#    1382                                      escapechar=escapechar, decimal=decimal)
# -> 1383         formatter.save()
#    1384
#    1385         if path_or_buf is None:
#
# C:\Anaconda\lib\site-packages\pandas\formats\format.py in save(self)
#    1458             f = _get_handle(self.path_or_buf, self.mode,
#    1459                             encoding=self.encoding,
# -> 1460                             compression=self.compression)
#    1461             close = True
#    1462
#
# C:\Anaconda\lib\site-packages\pandas\io\common.py in _get_handle(path, mode, encoding, compression, memory_map)
#     330                 f = open(path, mode, encoding=encoding)
#     331             else:
# --> 332                 f = open(path, mode, errors='replace')
#     333         else:
#     334             f = open(path, mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:/Transit-Casa-Alex/Output/Buffer Data/Competing Stops Buffers/2009/Quarter_Comp_Bus_Stops.csv'
