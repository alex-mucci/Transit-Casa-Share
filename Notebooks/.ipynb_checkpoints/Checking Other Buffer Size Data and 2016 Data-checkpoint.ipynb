# %%
import pandas as pd
import seaborn as sns
import numpy as np
import statsmodels.api as smf
from matplotlib import pyplot as plt

pd.set_option('display.max_columns', 500)


# %matplotlib inline

# %%
data16 = pd.read_csv('E:/Transit-Casa-Alex/Output/Modeling/2016/Tenth_Data_rs_day.csv',thousands = ',')
data_4 = pd.read_csv('E:/Transit-Casa-Alex/Output/Modeling/2009/Third_Data_rs_day.csv',thousands = ',')
data_3 = pd.read_csv('E:/Transit-Casa-Alex/Output/Modeling/2009/Quarter_Data_rs_day.csv',thousands = ',')

# %%
len(data16)
# Out:
# 5580

# %%
estimate = data16
drop = ['Unnamed: 0',
'STOP_LAT_x',
'STOP_LON_x',
'STOP_LAT_y',
'STOP_LON_y',
'geometry',
'index_right',
'Id',
'Id2',
'Geography',
'geometry_a',
'geometry_e',
'geometry_f',
'STOP_LAT',
'STOP_LON',
'FID_1']

change = ['BART_FROMS','BART_TOS','MUNI_RAIL_ALIGHTINGS','MUNI_RAIL_BOARDINGS','CALTRAIN_OFF','CALTRAIN_ON','NUM_BUS_STOPS']

change2 = ['Average Hourly Price',
'Count_',
'EDHLTH_RAC_SCALED',
'EDHLTH_WAC_SCALED',
'EMP_RAC_SCALED',
'EMP_WAC_SCALED',
'HOUSING16_SCALED',
'LEISER_RAC_SCALED',
'LEISER_WAC_SCALED',
'OTHER_RAC_SCALED',
'OTHER_WAC_SCALED',
'HH_0VEH',
'INC_0_15',
'INC_100P',
'INC_15_50',
'INC_50_100',
'PRICE12HR',
'PRICE1HR',
'PRICE2HR',
'PRICE3HR',
'PRICE4HR',
'PRICEDAY',
'PRICEDAYDISCOUNT',
'RETAIL_RAC_SCALED',
'RETAIL_WAC_SCALED',
'parking_rate']

changes = ['PARK_HOURLY_AVG_ON',
'TRANSBAY',
'EDHLTH_RAC_DEN',
'EDHLTH_WAC_DEN',
'EMP_RAC_DEN',
'EMP_WAC_DEN',
'HOUSING_16_DEN',
'LEISER_RAC_DEN',
'LEISER_WAC_DEN',
'OTHER_RAC_DEN',
'OTHER_WAC_DEN',
'SHR_HH_0VEH',
'SHR_INCOME_0_15',
'SHR_INCOME_100P',
'SHR_INCOME_15_50',
'SHR_INCOME_50_100',
'PARK_12_HR_OFF_PUB',
'PARK_1_HR_OFF_PUB',
'PARK_2_HR_OFF_PUB',
'PARK_3_HR_OFF_PUB',
'PARK_4_HR_OFF_PUB',
'PARK_DAY_OFF_PUB',
'PARK_DAY_DISCOUNT_OFF_PUB',
'RETAIL_RAC_DEN',
'RETAIL_WAC_DEN',
'PARKING_RATE_OFF_RESIDENTIAL']




look = ['EMP_WAC_DEN','LEISER_RAC_DEN','LEISER_WAC_DEN','OTHER_RAC_DEN','OTHER_WAC_DEN','RETAIL_RAC_DEN','RETAIL_WAC_DEN','ON']

log_change = ['PARK_12_HR_OFF_PUB',
'BIKE_BOARDINGS',
'BIKE_ALIGHTINGS',
'PARK_1_HR_OFF_PUB',
'PARK_2_HR_OFF_PUB',
'PARK_3_HR_OFF_PUB',
'PARK_4_HR_OFF_PUB',
'AVG_BART',
'BART_FROMS',
'BIKE_AVG',
'BART_TOS',
'CALTRAIN_AVG',
'CALTRAIN_OFF',
'CALTRAIN_ON',
'CAPACITY',
'CROWDED',
'CROWDHOURS',
'PARK_DAY_DISCOUNT_OFF_PUB',
'PARK_DAY_OFF_PUB',
'DWELL',
'DWELL_S',
'EDD_EMP',
'EDHLTH_RAC_DEN',
'EDHLTH_WAC_DEN',
'EMP_RAC_DEN',
'EMP_WAC_DEN',
'FREQ_S',
'FULLFARE_REV',
'HEADWAY_S',
'HH_DEN_ACS',
'PARK_HOURLY_AVG_ON',
'HOUSING_16_DEN',
'HU_DEN_ACS',
'LEISER_RAC_DEN',
'LEISER_WAC_DEN',
'MUNI_RAIL_ALIGHTINGS',
'MUNI_RAIL_AVG',
'MUNI_RAIL_BOARDINGS',
'NUM_BUS_STOPS',
'OCC_RATE',
'OFF',
'ON',
'ONTIME5',
'OTHER_RAC_DEN',
'OTHER_WAC_DEN',
'PARKING_RATE_OFF_RESIDENTIAL',
'PASSDELAY_ARR',
'PASSDELAY_DEP',
'PASSHOURS',
'PASSMILES',
'RDBRDNGS',
'RETAIL_RAC_DEN',
'RETAIL_WAC_DEN',
'RUNSPEED',
'RUNSPEED_S',
'RUNTIME',
'RUNTIME_S',
'SHR_HH_0VEH',
'SHR_INCOME_0_15',
'SHR_INCOME_100P',
'SHR_INCOME_15_50',
'SHR_INCOME_50_100',
'TOTSPEED',
'TOTSPEED_S',
'TOTTIME',
'TOTTIME_S',
'VAC_RATE',
'VC',
'WAITHOURS']


def rename_column(old_columns,new_columns,df):
    num = len(old_columns)
    count = 0
    while count < num:
        df[new_columns[count]] = df[old_columns[count]]
        df = df.drop(old_columns[count],axis = 1)
        
        count = count + 1
    return df
    
    
def check(value):
    if value == 'N':
        value = ''
    else:
        value = value
    return value
    
    

estimate['FREQ_S'] = 1 / (estimate['HEADWAY_S'] / 60.0)
estimate['NUM_BUS_STOPS'] = estimate['NUM_BUS_STOPS'] - 1






estimate.RUNSPEED = estimate.RUNSPEED.clip(upper = 40)
estimate.RUNSPEED = estimate.TOTSPEED.clip(upper = 40)

estimate = estimate.drop(drop,axis = 1)

for column in change:
    estimate[column] = estimate[column].fillna(0)
    

for column in estimate.columns.sort_values():
    print(column)
estimate = rename_column(change2,changes,estimate)

estimate['EXCLUDE'] = 0
count = 0
for column in look:
    while count < len(estimate[column]):
        if np.isnan(estimate[column][count]):
                print('Got One')
                estimate['EXCLUDE'][count] = 1
        count = count + 1
        
data = estimate[estimate['EXCLUDE'] == 0]        

data['AVG_RIDE'] = (data.ON + data.OFF)/2
data['LOG_RIDERS'] = np.log(data.AVG_RIDE + 1)

data['AVG_BART'] = (data['BART_FROMS']+data['BART_TOS'])/2
data['CALTRAIN_AVG'] = (data.CALTRAIN_OFF + data.CALTRAIN_ON)/2
data['MUNI_RAIL_AVG'] = (data.MUNI_RAIL_ALIGHTINGS + data.MUNI_RAIL_BOARDINGS)/2
data['BIKE_AVG'] = (data.BIKE_ALIGHTINGS + data.BIKE_BOARDINGS)/2


def check_inf(row):
    if row['FREQ_S'] == np.inf:
        row['FREQ_S'] = np.nan
    else:
        row['FREQ_S'] = row['FREQ_S']
    return row

data = data.apply(lambda x: check_inf(x),axis = 1)



for column in log_change:
    data[column + '_LOG'] = data[column].apply(lambda value: np.log(value + 1))
    

data['DIST_FROM_LAST_STOP'] = data['SERVMILES_S'] / (data['FREQ_S']*24)

data['DIST_FROM_LAST_STOP_LOG'] = data['DIST_FROM_LAST_STOP'].apply(lambda value: np.log(value + 1))

data['SERVMILES_S_LOG'] = data['SERVMILES_S'].apply(lambda x : np.log(x + 1))
    
data['EOL_SOL'] = data['EOL'] + data['SOL']

data['CAL_STATION'] = np.where(data['CALTRAIN_AVG'] > 0,1,0)
data['CLOSE_STOP'] = np.where(data['DIST_FROM_LAST_STOP'] < 0.2, 1,0)

data['LIMITED'] = 0
data['EXPRESS'] = 0

express = ['016AX',
'016BX',
'1AX',
'1BX',
'14X',
'30X',
'31AX',
'31BX',
'38AX',
'38BX',
'9AX',
'9BX',
'16X',
'80X',
'81X',
'82X',
'8AX',
'8BX',
'8X',]



limited = ['14R',
'28R',
'38R',
'71R',
'9R',]

def set_routes(row,limited,express):
    """
    function that uses the .apply(lambda x: ) method to set a dummy variable for limited and express routes. Must have
    dummy variable column names already filled with zeros.
    
    """
    
    for column in limited:
        if row['ROUTE_SHORT_NAME'] == column:
            row['LIMITED'] = 1
    
    for column in express:
        if row['ROUTE_SHORT_NAME'] == column:
            row['EXPRESS'] = 1
    return row


data = data.apply(lambda x : set_routes(x,limited,express),axis = 1)
# Out:
# ALAND
# AWATER
# Average Hourly Price
# BART_FROMS
# BART_TOS
# BIKERACK
# BIKE_ALIGHTINGS
# BIKE_BOARDINGS
# BIKE_DOCKCOUNT
# CALTRAIN_OFF
# CALTRAIN_ON
# CAPACITY
# COUNTYFP
# CROWDED
# CROWDHOURS
# Count_
# DIR
# DOORCYCLES
# DOW
# DOW_e
# DWELL
# DWELL_S
# EDD_EMP
# EDHLTH_RAC_SCALED
# EDHLTH_WAC_SCALED
# EMP_RAC_SCALED
# EMP_WAC_SCALED
# EOL
# FREQ_S
# FULLFARE_REV
# HEADWAY_S
# HH_0VEH
# HH_DEN_ACS
# HH_SIZE
# HOUSING16_SCALED
# HU_ACS
# HU_DEN_ACS
# INC_0_15
# INC_100P
# INC_15_50
# INC_50_100
# LEISER_RAC_SCALED
# LEISER_WAC_SCALED
# LOAD_ARR
# LOAD_DEP
# MUNI_RAIL_ALIGHTINGS
# MUNI_RAIL_BOARDINGS
# NAME
# NUM_BUS_STOPS
# OCC_RATE
# OFF
# ON
# ONTIME5
# OTHER_RAC_SCALED
# OTHER_WAC_SCALED
# PASSDELAY_ARR
# PASSDELAY_DEP
# PASSHOURS
# PASSMILES
# POPDEN_ACS
# POP_ACS
# PRICE12HR
# PRICE1HR
# PRICE2HR
# PRICE3HR
# PRICE4HR
# PRICEDAY
# PRICEDAYDISCOUNT
# RDBRDNGS
# RETAIL_RAC_SCALED
# RETAIL_WAC_SCALED
# ROUTE_LONG_NAME
# ROUTE_SHORT_NAME
# ROUTE_TYPE
# ROUTE_TYPE_x
# ROUTE_TYPE_y
# RUNSPEED
# RUNSPEED_S
# RUNTIME
# RUNTIME_S
# SERVMILES
# SERVMILES_S
# SOL
# STOPNAME
# STOPNAME_AVL
# STOP_ID
# TOTSPEED
# TOTSPEED_S
# TOTTIME
# TOTTIME_S
# TRACTCE
# VAC_RATE
# VC
# WAITHOURS
# WHEELCHAIR
# parking_rate
# Got One
# Got One
# Got One
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:206: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:209: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dropped_out_riders = estimate[(estimate['ON'] > 0) & (estimate['EXCLUDE'] == 1)]

# %%
estimate[(estimate['ON'] > 0) & (estimate['EXCLUDE'] == 1)]
# Out:
#       STOP_ID ROUTE_SHORT_NAME  DIR  SOL         OFF     CAPACITY  CROWDED  \
# 1608     4341              14R    1  1.0    0.000000  1073.100840      0.0
# 1610     4341               28    1  1.0    4.071429  1705.349123      0.0
# 1611     4341               57    1  0.0  106.238159  2023.576430      0.0
# 2055     4808                9    0  0.0    9.653947  1599.738889      0.0
# 2056     4808               9R    0  0.0   27.166845  2803.711111      0.0
# 2057     4809                9    0  0.0    0.234024   494.346078      0.0
# 2058     4809               9R    0  0.0    0.556988   421.533333      0.0
# 2059     4809               9R    1  0.0    0.333630  2575.271777      0.0
# 2226     4895                9    1  1.0    0.908024   833.564642      0.0
# 2228     4895               9R    1  0.0   62.353955  2683.249495      0.0
# 3035     5585               14    1  0.0   22.076160  3777.279760      0.0
# 3036     5585              14R    1  0.0   33.244581  1028.562745      0.0
# 3037     5585              14X    1  0.0   19.785913   340.424603      0.0
# 3042     5588               14    0  0.0   54.983380   481.440351      0.0
# 3043     5588              14R    0  0.0  399.976752  1010.753431      0.0
# 3063     5594               14    0  0.0  329.491359  2995.436816      0.0
# 3064     5594              14R    0  0.0  618.137278  1010.753431      0.0
# 3065     5594              14X    0  0.0  182.961905   328.285714      0.0
# 4344     6384                9    0  0.0   38.139301  1631.583333      0.0
# 4345     6384               9R    0  0.0  149.529482  2770.724747      0.0
# 2226                  0.0              NaN             NaN             NaN
# 2228                  0.0              NaN             NaN             NaN
# 3035                  0.0              NaN             NaN             NaN
# 3036                  0.0              NaN             NaN             NaN
# 3037                  0.0              NaN             NaN             NaN
# 3042                  0.0              NaN             NaN             NaN
# 3043                  0.0              NaN             NaN             NaN
# 3063                  0.0              NaN             NaN             NaN
# 3064                  0.0              NaN             NaN             NaN
# 3065                  0.0              NaN             NaN             NaN
# 4344                  0.0              NaN             NaN             NaN
# 4345                  0.0              NaN             NaN             NaN
# 4346                  0.0              NaN             NaN             NaN
# 4347                  0.0              NaN             NaN             NaN
# 4352                  0.0              NaN             NaN             NaN
# 4353                  0.0              NaN             NaN             NaN
# 4354                  0.0              NaN             NaN             NaN
# 4355                  0.0              NaN             NaN             NaN
# 5174                  0.0              NaN             NaN             NaN
# 5175                  0.0              NaN             NaN             NaN
# 5176                  0.0              NaN             NaN             NaN
# 5181                  0.0              NaN             NaN             NaN
# 5182                  0.0              NaN             NaN             NaN
# 5338                  0.0              NaN             NaN             NaN
# 5363                  0.0              NaN             NaN             NaN
# 5364                  0.0              NaN             NaN             NaN
# 5387                  0.0              NaN             NaN             NaN
# 5551                  0.0              NaN             NaN             NaN
#
#       NUM_BUS_STOPS  DOW_e  ROUTE_TYPE  EDD_EMP    FREQ_S  PARK_HOURLY_AVG_ON  \
# 1608            0.0    NaN         NaN      NaN  7.647935                 NaN
# 1610            0.0    NaN         NaN      NaN  4.991511                 NaN
# 1611            0.0    NaN         NaN      NaN  3.043902                 NaN
# 2055            0.0    NaN         NaN      NaN  3.683340                 NaN
# 2056            0.0    NaN         NaN      NaN  7.401402                 NaN
# 2057            0.0    NaN         NaN      NaN  3.770253                 NaN
# 2058            0.0    NaN         NaN      NaN  7.798397                 NaN
# 2059            0.0    NaN         NaN      NaN  7.532468                 NaN
# 2226            0.0    NaN         NaN      NaN  3.827243                 NaN
# 2228            0.0    NaN         NaN      NaN  7.520891                 NaN
# 3035            0.0    NaN         NaN      NaN  3.841177                 NaN
# 3036            0.0    NaN         NaN      NaN  7.637013                 NaN
# 3037            0.0    NaN         NaN      NaN  7.744315                 NaN
# 3042            0.0    NaN         NaN      NaN  5.327195                 NaN
# 3043            0.0    NaN         NaN      NaN  7.269923                 NaN
# 3063            0.0    NaN         NaN      NaN  5.327195                 NaN
# 3064            0.0    NaN         NaN      NaN  7.271686                 NaN
# 3065            0.0    NaN         NaN      NaN  6.465517                 NaN
# 4344            0.0    NaN         NaN      NaN  3.681984                 NaN
# 4345            0.0    NaN         NaN      NaN  7.401345                 NaN
# 4346            0.0    NaN         NaN      NaN  3.829405                 NaN
# 4347            0.0    NaN         NaN      NaN  7.521134                 NaN
# 4352            0.0    NaN         NaN      NaN  3.830169                 NaN
# 4353            0.0    NaN         NaN      NaN  7.521096                 NaN
# 4354            0.0    NaN         NaN      NaN  3.681351                 NaN
# 4355            0.0    NaN         NaN      NaN  7.401122                 NaN
# 5174            0.0    NaN         NaN      NaN  3.840683                 NaN
# 5175            0.0    NaN         NaN      NaN  7.637013                 NaN
# 3043             NaN             NaN             NaN            NaN
# 3063             NaN             NaN             NaN            NaN
# 3064             NaN             NaN             NaN            NaN
# 3065             NaN             NaN             NaN            NaN
# 4344             NaN             NaN             NaN            NaN
# 4345             NaN             NaN             NaN            NaN
# 4346             NaN             NaN             NaN            NaN
# 4347             NaN             NaN             NaN            NaN
# 4352             NaN             NaN             NaN            NaN
# 4353             NaN             NaN             NaN            NaN
# 4354             NaN             NaN             NaN            NaN
# 4355             NaN             NaN             NaN            NaN
# 5174             NaN             NaN             NaN            NaN
# 5175             NaN             NaN             NaN            NaN
# 5176             NaN             NaN             NaN            NaN
# 5181             NaN             NaN             NaN            NaN
# 5182             NaN             NaN             NaN            NaN
# 5338             NaN             NaN             NaN            NaN
# 5363             NaN             NaN             NaN            NaN
# 5364             NaN             NaN             NaN            NaN
# 5387             NaN             NaN             NaN            NaN
# 5551             NaN             NaN             NaN            NaN
#
#       OTHER_WAC_DEN  SHR_HH_0VEH  SHR_INCOME_0_15  SHR_INCOME_100P  \
# 1608            NaN          NaN              NaN              NaN
# 1610            NaN          NaN              NaN              NaN
# 1611            NaN          NaN              NaN              NaN
# 2055            NaN          NaN              NaN              NaN
# 2056            NaN          NaN              NaN              NaN
# 2057            NaN          NaN              NaN              NaN
# 2058            NaN          NaN              NaN              NaN
# 2059            NaN          NaN              NaN              NaN
# 2226            NaN          NaN              NaN              NaN
# 2228            NaN          NaN              NaN              NaN
# 3035            NaN          NaN              NaN              NaN
# 3036            NaN          NaN              NaN              NaN
# 3037            NaN          NaN              NaN              NaN
# 3042            NaN          NaN              NaN              NaN
# 3043            NaN          NaN              NaN              NaN
# 3063            NaN          NaN              NaN              NaN
# 3064            NaN          NaN              NaN              NaN
# 3065            NaN          NaN              NaN              NaN
# 4344            NaN          NaN              NaN              NaN
# 4345            NaN          NaN              NaN              NaN
# 4346            NaN          NaN              NaN              NaN
# 4347            NaN          NaN              NaN              NaN
# 4352            NaN          NaN              NaN              NaN
# 4353            NaN          NaN              NaN              NaN
# 4354            NaN          NaN              NaN              NaN
# 4355            NaN          NaN              NaN              NaN
# 5174            NaN          NaN              NaN              NaN
# 5175            NaN          NaN              NaN              NaN
# 5176            NaN          NaN              NaN              NaN
# 5181            NaN          NaN              NaN              NaN
# 5182            NaN          NaN              NaN              NaN
# 5338            NaN          NaN              NaN              NaN
# 5363            NaN          NaN              NaN              NaN
# 5364            NaN          NaN              NaN              NaN
# 5387            NaN          NaN              NaN              NaN
# 5551            NaN          NaN              NaN              NaN
#
#       SHR_INCOME_15_50  SHR_INCOME_50_100  PARK_12_HR_OFF_PUB  \
# 1608               NaN                NaN                 NaN
# 1610               NaN                NaN                 NaN
# 1611               NaN                NaN                 NaN
# 2055               NaN                NaN                 NaN
# 2056               NaN                NaN                 NaN
# 2057               NaN                NaN                 NaN
# 2058               NaN                NaN                 NaN
# 2059               NaN                NaN                 NaN
# 2226               NaN                NaN                 NaN
# 2228               NaN                NaN                 NaN
# 3035               NaN                NaN                 NaN
# 3036               NaN                NaN                 NaN
# 4352                NaN               NaN                        NaN
# 4353                NaN               NaN                        NaN
# 4354                NaN               NaN                        NaN
# 4355                NaN               NaN                        NaN
# 5174                NaN               NaN                        NaN
# 5175                NaN               NaN                        NaN
# 5176                NaN               NaN                        NaN
# 5181                NaN               NaN                        NaN
# 5182                NaN               NaN                        NaN
# 5338                NaN               NaN                        NaN
# 5363                NaN               NaN                        NaN
# 5364                NaN               NaN                        NaN
# 5387                NaN               NaN                        NaN
# 5551                NaN               NaN                        NaN
#
#       RETAIL_RAC_DEN  RETAIL_WAC_DEN  PARKING_RATE_OFF_RESIDENTIAL  EXCLUDE
# 1608             NaN             NaN                           NaN        1
# 1610             NaN             NaN                           NaN        1
# 1611             NaN             NaN                           NaN        1
# 2055             NaN             NaN                           NaN        1
# 2056             NaN             NaN                           NaN        1
# 2057             NaN             NaN                           NaN        1
# 2058             NaN             NaN                           NaN        1
# 2059             NaN             NaN                           NaN        1
# 2226             NaN             NaN                           NaN        1
# 2228             NaN             NaN                           NaN        1
# 3035             NaN             NaN                           NaN        1
# 3036             NaN             NaN                           NaN        1
# 3037             NaN             NaN                           NaN        1
# 3042             NaN             NaN                           NaN        1
# 3043             NaN             NaN                           NaN        1
# 3063             NaN             NaN                           NaN        1
# 3064             NaN             NaN                           NaN        1
# 3065             NaN             NaN                           NaN        1
# 4344             NaN             NaN                           NaN        1
# 4345             NaN             NaN                           NaN        1
# 4346             NaN             NaN                           NaN        1
# 4347             NaN             NaN                           NaN        1
# 4352             NaN             NaN                           NaN        1
# 4353             NaN             NaN                           NaN        1
# 4354             NaN             NaN                           NaN        1
# 4355             NaN             NaN                           NaN        1
# 5174             NaN             NaN                           NaN        1
# 5175             NaN             NaN                           NaN        1
# 5176             NaN             NaN                           NaN        1
# 5181             NaN             NaN                           NaN        1
# 5182             NaN             NaN                           NaN        1
# 5338             NaN             NaN                           NaN        1
# 5363             NaN             NaN                           NaN        1
# 5364             NaN             NaN                           NaN        1
# 5387             NaN             NaN                           NaN        1
# 5551             NaN             NaN                           NaN        1

# %%
dropped_out_riders.to_csv('Dropped_Out_Riders.csv')

# %%
sum(dropped_out_riders.ON)
# Out:
# 5578.1255111682176

# %%
len(data)
# Out:
# 5536

# %%
dropped = data[['LOG_RIDERS','EDD_EMP_LOG','STOP_ID','AVG_RIDE','FREQ_S_LOG','EOL_SOL','HOUSING_16_DEN_LOG','SHR_INCOME_100P','PARK_HOURLY_AVG_ON_LOG','ONTIME5','AVG_BART_LOG','CLOSE_STOP','LIMITED','EXPRESS','TRANSBAY','MUNI_RAIL_AVG']].dropna()

# %%
data.ROUTE_SHORT_NAME.unique()
# Out:
# array(['28', '28R', '29', '91', '52', '10', '12', '54', '41', '45', '82X',
#        '8', '8BX', '31', '31BX', '31AX', '18', '30', '30X', '22', '38',
#        '38R', '5', '5R', '7', '7R', '81X', '19', '35', '8AX', '24', '47',
#        '83X', 'N-OWL', '27', '44', '1BX', '14X', '36', '43', '6', '66',
#        '25', '9', '90', '9R', '48', '37', 'L-OWL', '57', '33', '55', '7X',
#        '67', '1', '1AX', '38AX', '56', '2', '23', '3', 'NX', '38BX', '39',
#        '21', '88', 'K-OWL', '14', '14R', '49'], dtype=object)

# %%
dropped.to_csv('E:/Transit-Casa-Alex/Output/Modeling/2016/Final_Model_Data_Post_Drop.csv')
data.to_csv('E:/Transit-Casa-Alex/Output/Modeling/2016/Final_Model_Data.csv')

# %%
for column in data.columns.sort_values():
    print(column)
# Out:
# ALAND
# AVG_BART
# AVG_BART_LOG
# AVG_RIDE
# AWATER
# BART_FROMS
# BART_FROMS_LOG
# BART_TOS
# BART_TOS_LOG
# BIKERACK
# BIKE_ALIGHTINGS
# BIKE_ALIGHTINGS_LOG
# BIKE_AVG
# BIKE_AVG_LOG
# BIKE_BOARDINGS
# BIKE_BOARDINGS_LOG
# BIKE_DOCKCOUNT
# CALTRAIN_AVG
# CALTRAIN_AVG_LOG
# CALTRAIN_OFF
# CALTRAIN_OFF_LOG
# CALTRAIN_ON
# CALTRAIN_ON_LOG
# CAL_STATION
# CAPACITY
# CAPACITY_LOG
# CLOSE_STOP
# COUNTYFP
# CROWDED
# CROWDED_LOG
# CROWDHOURS
# CROWDHOURS_LOG
# DIR
# DIST_FROM_LAST_STOP
# DIST_FROM_LAST_STOP_LOG
# DOORCYCLES
# DOW
# DOW_e
# DWELL
# DWELL_LOG
# DWELL_S
# DWELL_S_LOG
# EDD_EMP
# EDD_EMP_LOG
# EDHLTH_RAC_DEN
# EDHLTH_RAC_DEN_LOG
# EDHLTH_WAC_DEN
# EDHLTH_WAC_DEN_LOG
# EMP_RAC_DEN
# EMP_RAC_DEN_LOG
# EMP_WAC_DEN
# EMP_WAC_DEN_LOG
# EOL
# EOL_SOL
# EXCLUDE
# EXPRESS
# FREQ_S
# FREQ_S_LOG
# FULLFARE_REV
# FULLFARE_REV_LOG
# HEADWAY_S
# HEADWAY_S_LOG
# HH_DEN_ACS
# HH_DEN_ACS_LOG
# HH_SIZE
# HOUSING_16_DEN
# HOUSING_16_DEN_LOG
# HU_ACS
# HU_DEN_ACS
# HU_DEN_ACS_LOG
# LEISER_RAC_DEN
# LEISER_RAC_DEN_LOG
# LEISER_WAC_DEN
# LEISER_WAC_DEN_LOG
# LIMITED
# LOAD_ARR
# LOAD_DEP
# LOG_RIDERS
# MUNI_RAIL_ALIGHTINGS
# MUNI_RAIL_ALIGHTINGS_LOG
# MUNI_RAIL_AVG
# MUNI_RAIL_AVG_LOG
# MUNI_RAIL_BOARDINGS
# MUNI_RAIL_BOARDINGS_LOG
# NAME
# NUM_BUS_STOPS
# NUM_BUS_STOPS_LOG
# OCC_RATE
# OCC_RATE_LOG
# OFF
# OFF_LOG
# ON
# ONTIME5
# ONTIME5_LOG
# ON_LOG
# OTHER_RAC_DEN
# OTHER_RAC_DEN_LOG
# OTHER_WAC_DEN
# OTHER_WAC_DEN_LOG
# PARKING_RATE_OFF_RESIDENTIAL
# PARKING_RATE_OFF_RESIDENTIAL_LOG
# PARK_12_HR_OFF_PUB
# PARK_12_HR_OFF_PUB_LOG
# PARK_1_HR_OFF_PUB
# PARK_1_HR_OFF_PUB_LOG
# PARK_2_HR_OFF_PUB
# PARK_2_HR_OFF_PUB_LOG
# PARK_3_HR_OFF_PUB
# PARK_3_HR_OFF_PUB_LOG
# PARK_4_HR_OFF_PUB
# PARK_4_HR_OFF_PUB_LOG
# PARK_DAY_DISCOUNT_OFF_PUB
# PARK_DAY_DISCOUNT_OFF_PUB_LOG
# PARK_DAY_OFF_PUB
# PARK_DAY_OFF_PUB_LOG
# PARK_HOURLY_AVG_ON
# PARK_HOURLY_AVG_ON_LOG
# PASSDELAY_ARR
# PASSDELAY_ARR_LOG
# PASSDELAY_DEP
# PASSDELAY_DEP_LOG
# PASSHOURS
# PASSHOURS_LOG
# PASSMILES
# PASSMILES_LOG
# POPDEN_ACS
# POP_ACS
# RDBRDNGS
# RDBRDNGS_LOG
# RETAIL_RAC_DEN
# RETAIL_RAC_DEN_LOG
# RETAIL_WAC_DEN
# RETAIL_WAC_DEN_LOG
# ROUTE_LONG_NAME
# ROUTE_SHORT_NAME
# ROUTE_TYPE
# ROUTE_TYPE_x
# ROUTE_TYPE_y
# RUNSPEED
# RUNSPEED_LOG
# RUNSPEED_S
# RUNSPEED_S_LOG
# RUNTIME
# RUNTIME_LOG
# RUNTIME_S
# RUNTIME_S_LOG
# SERVMILES
# SERVMILES_S
# SERVMILES_S_LOG
# SHR_HH_0VEH
# SHR_HH_0VEH_LOG
# SHR_INCOME_0_15
# SHR_INCOME_0_15_LOG
# SHR_INCOME_100P
# SHR_INCOME_100P_LOG
# SHR_INCOME_15_50
# SHR_INCOME_15_50_LOG
# SHR_INCOME_50_100
# SHR_INCOME_50_100_LOG
# SOL
# STOPNAME
# STOPNAME_AVL
# STOP_ID
# TOTSPEED
# TOTSPEED_LOG
# TOTSPEED_S
# TOTSPEED_S_LOG
# TOTTIME
# TOTTIME_LOG
# TOTTIME_S
# TOTTIME_S_LOG
# TRACTCE
# TRANSBAY
# VAC_RATE
# VAC_RATE_LOG
# VC
# VC_LOG
# WAITHOURS
# WAITHOURS_LOG
# WHEELCHAIR

# %%
# had to drop out the rows that had frequencies of 30 buses per hour because they did not make sense and are 
# being double counted in the data. There is an issue with the initial data.

data = data.drop(data[data['FREQ_S'] == 30].index,axis = 0)

# %%
data.HEADWAY_S.unique()
# Out:
# array([ 12.02040816,  10.01618929,  12.02117647, ...,  17.29822951,
#         17.091     ,  15.8642029 ])

# %%
# Test the 2009 model with 2016 data
# Need to change the way that the limited and express routes are calculated because the routes may change names

mod = smf.formula.ols(formula="LOG_RIDERS \
                       ~ EDD_EMP_LOG \
                       + FREQ_S_LOG \
                       + EOL_SOL \
                       + HOUSING_16_DEN \
                       + SHR_INCOME_100P_LOG \
                       + PARK_HOURLY_AVG_ON_LOG \
                       + AVG_BART \
                       + CLOSE_STOP \
                       + LIMITED \
                       + EXPRESS \
                       + ONTIME5 \
                       + TRANSBAY \
                       + MUNI_RAIL_AVG \
                       ",
             data = data)

res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             LOG_RIDERS   R-squared:                       0.556
# Model:                            OLS   Adj. R-squared:                  0.554
# Method:                 Least Squares   F-statistic:                     503.7
# Date:                Fri, 28 Jul 2017   Prob (F-statistic):               0.00
# Time:                        12:57:31   Log-Likelihood:                -7384.1
# No. Observations:                5252   AIC:                         1.480e+04
# Df Residuals:                    5238   BIC:                         1.489e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -0.4683      0.116     -4.022      0.000      -0.696      -0.240
# EDD_EMP_LOG                0.1300      0.010     12.987      0.000       0.110       0.150
# FREQ_S_LOG                 2.6407      0.046     57.389      0.000       2.550       2.731
# EOL_SOL                    0.5513      0.059      9.274      0.000       0.435       0.668
# HOUSING_16_DEN             0.0002   4.03e-05      5.810      0.000       0.000       0.000
# SHR_INCOME_100P_LOG       -1.4102      0.113    -12.497      0.000      -1.631      -1.189
# PARK_HOURLY_AVG_ON_LOG     0.0448      0.007      6.326      0.000       0.031       0.059
# AVG_BART                5.233e-05   1.18e-05      4.453      0.000    2.93e-05    7.54e-05
# CLOSE_STOP                -1.0761      0.048    -22.525      0.000      -1.170      -0.982
# LIMITED                   -0.5855      0.081     -7.254      0.000      -0.744      -0.427
# EXPRESS                   -1.3710      0.056    -24.549      0.000      -1.481      -1.262
# ONTIME5                    0.7743      0.095      8.170      0.000       0.588       0.960
# TRANSBAY                  -0.1357      0.171     -0.793      0.428      -0.471       0.200
# MUNI_RAIL_AVG           5.457e-07   8.41e-06      0.065      0.948   -1.59e-05     1.7e-05
# ==============================================================================
# Omnibus:                       76.440   Durbin-Watson:                   1.389
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               80.788
# Skew:                          -0.280   Prob(JB):                     2.86e-18
# Kurtosis:                       3.235   Cond. No.                     3.05e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.05e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
sns.distplot(data.FREQ_S.dropna())

# %%
plt.scatter(res.resid.index,res.resid)

# %%
sns.distplot(res.resid)

# %%
estimate = data_4

drop = ['Unnamed: 0',
'STOP_LAT_x',
'STOP_LON_x',
'STOP_LAT_y',
'STOP_LON_y',
'geometry',
'index_right',
'ALAND00',
'AWATER00',
'COUNTYFP00',
'CTIDFP00',
'NAME00',
'TRACTCE00',
'Id',
'Id2',
'Geography',
'geometry_a',
'geometry_e',
'geometry_f',
'STOP_LAT',
'STOP_LON',
'FID_1']


change = ['Average Hourly Price',
'Count_',
'EDHLTH_RAC_SCALED',
'EDHLTH_WAC_SCALED',
'EMP_RAC_SCALED',
'EMP_WAC_SCALED',
'HOUSING_09_SCALED',
'LEISER_RAC_SCALED',
'LEISER_WAC_SCALED',
'OTHER_RAC_SCALED',
'OTHER_WAC_SCALED',
'PER_HH_0VEH',
'PER_INCOME_0-15',
'PER_INCOME_100+',
'PER_INCOME_15-50',
'PER_INCOME_50-100',
'PRICE12HR',
'PRICE1HR',
'PRICE2HR',
'PRICE3HR',
'PRICE4HR',
'PRICEDAY',
'PRICEDAYDISCOUNT',
'RETAIL_RAC_SCALED',
'RETAIL_WAC_SCALED',
'Workers_16_And_Over_Mean_Travel_Time_To_Work_(Minutes)',
'parking_rate']

changes = ['PARK_HOURLY_AVG_ON',
'TRANSBAY',
'EDHLTH_RAC_DEN',
'EDHLTH_WAC_DEN',
'EMP_RAC_DEN',
'EMP_WAC_DEN',
'HOUSING_09_DEN',
'LEISER_RAC_DEN',
'LEISER_WAC_DEN',
'OTHER_RAC_DEN',
'OTHER_WAC_DEN',
'SHR_HH_0VEH',
'SHR_INCOME_0_15',
'SHR_INCOME_100P',
'SHR_INCOME_15_50',
'SHR_INCOME_50_100',
'PARK_12_HR_OFF_PUB',
'PARK_1_HR_OFF_PUB',
'PARK_2_HR_OFF_PUB',
'PARK_3_HR_OFF_PUB',
'PARK_4_HR_OFF_PUB',
'PARK_DAY_OFF_PUB',
'PARK_DAY_DISCOUNT_OFF_PUB',
'RETAIL_RAC_DEN',
'RETAIL_WAC_DEN',
'AVG_TT_TO_WORK_MINUTES',
'PARKING_RATE_OFF_RESIDENTIAL']



fill = ['BART_FROMS','BART_TOS','MUNI_RAIL_ALIGHTINGS','MUNI_RAIL_BOARDINGS','CALTRAIN_OFF','CALTRAIN_ON','NUM_BUS_STOPS']

look = ['EMP_WAC_DEN','LEISER_RAC_DEN','LEISER_WAC_DEN','OTHER_RAC_DEN','OTHER_WAC_DEN','RETAIL_RAC_DEN','RETAIL_WAC_DEN','ON']

log_change = ['PARK_12_HR_OFF_PUB',
'BIKE_BOARDINGS',
'BIKE_ALIGHTINGS',
'BIKE_AVG',     
'PARK_1_HR_OFF_PUB',
'PARK_2_HR_OFF_PUB',
'PARK_3_HR_OFF_PUB',
'PARK_4_HR_OFF_PUB',
'AVG_BART',
'AVG_HH_SIZE',
'AVG_TT_TO_WORK_MINUTES',
'BART_FROMS',
'BART_TOS',
'CALTRAIN_AVG',
'CALTRAIN_OFF',
'CALTRAIN_ON',
'CAPACITY',
'CROWDED',
'CROWDHOURS',
'PARK_DAY_DISCOUNT_OFF_PUB',
'PARK_DAY_OFF_PUB',
'DWELL',
'DWELL_S',
'EDD_EMP',
'EDHLTH_RAC_DEN',
'EDHLTH_WAC_DEN',
'EMP_RAC_DEN',
'EMP_WAC_DEN',
'FARE',
'FREQ_S',
'FULLFARE_REV',
'HEADWAY_S',
'HH_DEN_ACS',
'PARK_HOURLY_AVG_ON',
'HOUSING_09_DEN',
'HU_DEN_ACS',
'LEISER_RAC_DEN',
'LEISER_WAC_DEN',
'MUNI_RAIL_ALIGHTINGS',
'MUNI_RAIL_AVG',
'MUNI_RAIL_BOARDINGS',
'NUM_BUS_STOPS',
'OCC_RATE',
'OFF',
'ON',
'ONTIME5',
'OTHER_RAC_DEN',
'OTHER_WAC_DEN',
'PARKING_RATE_OFF_RESIDENTIAL',
'PASSDELAY_ARR',
'PASSDELAY_DEP',
'PASSHOURS',
'PASSMILES',
'POP_DEN_ACS',
'RDBRDNGS',
'RETAIL_RAC_DEN',
'RETAIL_WAC_DEN',
'RUNSPEED',
'RUNSPEED_S',
'RUNTIME',
'RUNTIME_S',
'SHR_HH_0VEH',
'SHR_INCOME_0_15',
'SHR_INCOME_100P',
'SHR_INCOME_15_50',
'SHR_INCOME_50_100',
'TOTSPEED',
'TOTSPEED_S',
'TOTTIME',
'TOTTIME_S',
'Total_Housing_Units',
'Total_Pop',
'VAC_RATE',
'VC',
'WAITHOURS']




def rename_column(old_columns,new_columns,df):
    num = len(old_columns)
    count = 0
    while count < num:
        df[new_columns[count]] = df[old_columns[count]]
        df = df.drop(old_columns[count],axis = 1)
        
        count = count + 1
    return df
    
    
def check(value):
    if value == 'N':
        value = ''
    else:
        value = value
    return value
    
    

estimate['FREQ_S'] = 1 / (estimate['HEADWAY_S'] / 60.0)
estimate['NUM_BUS_STOPS'] = estimate['NUM_BUS_STOPS'] - 1

estimate.RUNSPEED = estimate.RUNSPEED.clip(upper = 40)
estimate.RUNSPEED = estimate.TOTSPEED.clip(upper = 40)

estimate = estimate.drop(drop,axis = 1)

for column in fill:
    estimate[column] = estimate[column].fillna(0)
    

    
estimate = rename_column(change,changes,estimate)


estimate['EXCLUDE'] = 0
count = 0
for column in look:
    while count < len(estimate[column]):
        if np.isnan(estimate[column][count]):
                print('Got One')
                estimate['EXCLUDE'][count] = 1
        count = count + 1
        
        
data = estimate[estimate['EXCLUDE'] == 0]

data['AVG_RIDE'] = (data.ON + data.OFF)/2
data['LOG_RIDERS'] = np.log(data.AVG_RIDE + 1)

data['AVG_BART'] = (data['BART_FROMS']+data['BART_TOS'])/2
data['CALTRAIN_AVG'] = (data.CALTRAIN_OFF + data.CALTRAIN_ON)/2
data['MUNI_RAIL_AVG'] = (data.MUNI_RAIL_ALIGHTINGS + data.MUNI_RAIL_BOARDINGS)/2
data['BIKE_AVG'] = (data.BIKE_ALIGHTINGS + data.BIKE_BOARDINGS)/2

data.AVG_TT_TO_WORK_MINUTES = data.AVG_TT_TO_WORK_MINUTES.convert_objects(convert_numeric = True)


for column in log_change:
    data[column + '_LOG'] = data[column].apply(lambda value: np.log(value + 1))
    

data['DIST_FROM_LAST_STOP'] = data['SERVMILES_S'] / (data['FREQ_S']*24)

data['DIST_FROM_LAST_STOP_LOG'] = data['DIST_FROM_LAST_STOP'].apply(lambda value: np.log(value + 1))

data['SERVMILES_S_LOG'] = data['SERVMILES_S'].apply(lambda x : np.log(x + 1))
    
data['EOL_SOL'] = data['EOL'] + data['SOL']

data['CAL_STATION'] = np.where(data['CALTRAIN_AVG'] > 0,1,0)
data['CLOSE_STOP'] = np.where(data['DIST_FROM_LAST_STOP'] < 0.2, 1,0)

data['LIMITED'] = 0
data['EXPRESS'] = 0

data = data.apply(lambda x : set_routes(x,limited,express),axis = 1)
# Out:
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:216: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:217: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:219: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:220: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:221: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:222: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:224: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# C:\Anaconda\lib\site-packages\pandas\core\generic.py:2773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:228: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: 'FARE'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-d729e6013071> in <module>()
#     226
#     227 for column in log_change:
# --> 228     data[column + '_LOG'] = data[column].apply(lambda value: np.log(value + 1))
#     229
#     230
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# C:\Anaconda\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Anaconda\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: 'FARE'

# %%
data.head()

# %%
# Check the 2009 Quarter Buffer Data for the same 2009 Tenth Buffer Model
# -- Looks good!

mod = smf.formula.ols(formula="LOG_RIDERS \
                       ~ EDD_EMP_LOG \
                       + FREQ_S_LOG \
                       + EOL_SOL \
                       + HOUSING_09_DEN_LOG \
                       + SHR_INCOME_100P_LOG \
                       + PARK_HOURLY_AVG_ON_LOG \
                       + AVG_BART_LOG \
                       + CLOSE_STOP \
                       + LIMITED \
                       + EXPRESS \
                       + ONTIME5 \
                       + TRANSBAY \
                       + MUNI_RAIL_AVG \
                       + CAL_STATION \
                       -1",
             data = data)

res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             LOG_RIDERS   R-squared:                       0.901
# Model:                            OLS   Adj. R-squared:                  0.901
# Method:                 Least Squares   F-statistic:                 1.286e+04
# Date:                Tue, 18 Jul 2017   Prob (F-statistic):               0.00
# Time:                        13:25:00   Log-Likelihood:                -26990.
# No. Observations:               16938   AIC:                         5.400e+04
# Df Residuals:                   16926   BIC:                         5.410e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# EDD_EMP_LOG                0.0534      0.008      6.506      0.000       0.037       0.070
# FREQ_S_LOG                 1.8961      0.028     67.307      0.000       1.841       1.951
# EOL_SOL                    0.8502      0.041     20.933      0.000       0.771       0.930
# HOUSING_09_DEN_LOG         0.1615      0.010     16.527      0.000       0.142       0.181
# SHR_INCOME_100P_LOG       -1.4742      0.073    -20.251      0.000      -1.617      -1.331
# PARK_HOURLY_AVG_ON_LOG     0.0675      0.004     15.833      0.000       0.059       0.076
# AVG_BART_LOG               0.0553      0.004     13.570      0.000       0.047       0.063
# CLOSE_STOP                -1.3840      0.033    -41.643      0.000      -1.449      -1.319
# LIMITED                -5.458e-15   6.66e-16     -8.196      0.000   -6.76e-15   -4.15e-15
# EXPRESS                  2.66e-15   3.07e-16      8.650      0.000    2.06e-15    3.26e-15
# ONTIME5                    0.5150      0.060      8.535      0.000       0.397       0.633
# TRANSBAY                  -0.5175      0.065     -8.019      0.000      -0.644      -0.391
# MUNI_RAIL_AVG          -8.275e-05   8.84e-06     -9.363      0.000      -0.000   -6.54e-05
# CAL_STATION                0.1098      0.081      1.353      0.176      -0.049       0.269
# ==============================================================================
# Omnibus:                      210.531   Durbin-Watson:                   0.976
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              218.022
# Skew:                          -0.276   Prob(JB):                     4.54e-48
# Kurtosis:                       2.940   Cond. No.                     8.59e+20
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.06e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
sns.distplot(res.resid)

# %%
estimate = data_3

drop = ['Unnamed: 0',
'STOP_LAT_x',
'STOP_LON_x',
'STOP_LAT_y',
'STOP_LON_y',
'geometry',
'index_right',
'ALAND00',
'AWATER00',
'COUNTYFP00',
'CTIDFP00',
'NAME00',
'TRACTCE00',
'Id',
'Id2',
'Geography',
'geometry_a',
'geometry_e',
'geometry_f',
'STOP_LAT',
'STOP_LON',
'FID_1']


change = ['Average Hourly Price',
'Count_',
'EDHLTH_RAC_SCALED',
'EDHLTH_WAC_SCALED',
'EMP_RAC_SCALED',
'EMP_WAC_SCALED',
'HOUSING_09_SCALED',
'LEISER_RAC_SCALED',
'LEISER_WAC_SCALED',
'OTHER_RAC_SCALED',
'OTHER_WAC_SCALED',
'PER_HH_0VEH',
'PER_INCOME_0-15',
'PER_INCOME_100+',
'PER_INCOME_15-50',
'PER_INCOME_50-100',
'PRICE12HR',
'PRICE1HR',
'PRICE2HR',
'PRICE3HR',
'PRICE4HR',
'PRICEDAY',
'PRICEDAYDISCOUNT',
'RETAIL_RAC_SCALED',
'RETAIL_WAC_SCALED',
'Workers_16_And_Over_Mean_Travel_Time_To_Work_(Minutes)',
'parking_rate']

changes = ['PARK_HOURLY_AVG_ON',
'TRANSBAY',
'EDHLTH_RAC_DEN',
'EDHLTH_WAC_DEN',
'EMP_RAC_DEN',
'EMP_WAC_DEN',
'HOUSING_09_DEN',
'LEISER_RAC_DEN',
'LEISER_WAC_DEN',
'OTHER_RAC_DEN',
'OTHER_WAC_DEN',
'SHR_HH_0VEH',
'SHR_INCOME_0_15',
'SHR_INCOME_100P',
'SHR_INCOME_15_50',
'SHR_INCOME_50_100',
'PARK_12_HR_OFF_PUB',
'PARK_1_HR_OFF_PUB',
'PARK_2_HR_OFF_PUB',
'PARK_3_HR_OFF_PUB',
'PARK_4_HR_OFF_PUB',
'PARK_DAY_OFF_PUB',
'PARK_DAY_DISCOUNT_OFF_PUB',
'RETAIL_RAC_DEN',
'RETAIL_WAC_DEN',
'AVG_TT_TO_WORK_MINUTES',
'PARKING_RATE_OFF_RESIDENTIAL']



fill = ['BART_FROMS','BART_TOS','MUNI_RAIL_ALIGHTINGS','MUNI_RAIL_BOARDINGS','CALTRAIN_OFF','CALTRAIN_ON','NUM_BUS_STOPS']

look = ['EMP_WAC_DEN','LEISER_RAC_DEN','LEISER_WAC_DEN','OTHER_RAC_DEN','OTHER_WAC_DEN','RETAIL_RAC_DEN','RETAIL_WAC_DEN','ON']

log_change = ['PARK_12_HR_OFF_PUB',
'BIKE_BOARDINGS',
'BIKE_ALIGHTINGS',
'BIKE_AVG',     
'PARK_1_HR_OFF_PUB',
'PARK_2_HR_OFF_PUB',
'PARK_3_HR_OFF_PUB',
'PARK_4_HR_OFF_PUB',
'AVG_BART',
'AVG_HH_SIZE',
'AVG_TT_TO_WORK_MINUTES',
'BART_FROMS',
'BART_TOS',
'CALTRAIN_AVG',
'CALTRAIN_OFF',
'CALTRAIN_ON',
'CAPACITY',
'CROWDED',
'CROWDHOURS',
'PARK_DAY_DISCOUNT_OFF_PUB',
'PARK_DAY_OFF_PUB',
'DWELL',
'DWELL_S',
'EDD_EMP',
'EDHLTH_RAC_DEN',
'EDHLTH_WAC_DEN',
'EMP_RAC_DEN',
'EMP_WAC_DEN',
'FARE',
'FREQ_S',
'FULLFARE_REV',
'HEADWAY_S',
'HH_DEN_ACS',
'PARK_HOURLY_AVG_ON',
'HOUSING_09_DEN',
'HU_DEN_ACS',
'LEISER_RAC_DEN',
'LEISER_WAC_DEN',
'MUNI_RAIL_ALIGHTINGS',
'MUNI_RAIL_AVG',
'MUNI_RAIL_BOARDINGS',
'NUM_BUS_STOPS',
'OCC_RATE',
'OFF',
'ON',
'ONTIME5',
'OTHER_RAC_DEN',
'OTHER_WAC_DEN',
'PARKING_RATE_OFF_RESIDENTIAL',
'PASSDELAY_ARR',
'PASSDELAY_DEP',
'PASSHOURS',
'PASSMILES',
'POP_DEN_ACS',
'RDBRDNGS',
'RETAIL_RAC_DEN',
'RETAIL_WAC_DEN',
'RUNSPEED',
'RUNSPEED_S',
'RUNTIME',
'RUNTIME_S',
'SHR_HH_0VEH',
'SHR_INCOME_0_15',
'SHR_INCOME_100P',
'SHR_INCOME_15_50',
'SHR_INCOME_50_100',
'TOTSPEED',
'TOTSPEED_S',
'TOTTIME',
'TOTTIME_S',
'Total_Housing_Units',
'Total_Pop',
'VAC_RATE',
'VC',
'WAITHOURS']




def rename_column(old_columns,new_columns,df):
    num = len(old_columns)
    count = 0
    while count < num:
        df[new_columns[count]] = df[old_columns[count]]
        df = df.drop(old_columns[count],axis = 1)
        
        count = count + 1
    return df
    
    
def check(value):
    if value == 'N':
        value = ''
    else:
        value = value
    return value
    
    

estimate['FREQ_S'] = 1 / (estimate['HEADWAY_S'] / 60.0)
estimate['NUM_BUS_STOPS'] = estimate['NUM_BUS_STOPS'] - 1

estimate.RUNSPEED = estimate.RUNSPEED.clip(upper = 40)
estimate.RUNSPEED = estimate.TOTSPEED.clip(upper = 40)

estimate = estimate.drop(drop,axis = 1)

for column in fill:
    estimate[column] = estimate[column].fillna(0)
    

    
estimate = rename_column(change,changes,estimate)


estimate['EXCLUDE'] = 0
count = 0
for column in look:
    while count < len(estimate[column]):
        if np.isnan(estimate[column][count]):
                print('Got One')
                estimate['EXCLUDE'][count] = 1
        count = count + 1
        
        
data = estimate[estimate['EXCLUDE'] == 0]

data['AVG_RIDE'] = (data.ON + data.OFF)/2
data['LOG_RIDERS'] = np.log(data.AVG_RIDE + 1)

data['AVG_BART'] = (data['BART_FROMS']+data['BART_TOS'])/2
data['CALTRAIN_AVG'] = (data.CALTRAIN_OFF + data.CALTRAIN_ON)/2
data['MUNI_RAIL_AVG'] = (data.MUNI_RAIL_ALIGHTINGS + data.MUNI_RAIL_BOARDINGS)/2
data['BIKE_AVG'] = (data.BIKE_ALIGHTINGS + data.BIKE_BOARDINGS)/2

data.AVG_TT_TO_WORK_MINUTES = data.AVG_TT_TO_WORK_MINUTES.convert_objects(convert_numeric = True)


for column in log_change:
    data[column + '_LOG'] = data[column].apply(lambda value: np.log(value + 1))
    

data['DIST_FROM_LAST_STOP'] = data['SERVMILES_S'] / (data['FREQ_S']*24)

data['DIST_FROM_LAST_STOP_LOG'] = data['DIST_FROM_LAST_STOP'].apply(lambda value: np.log(value + 1))

data['SERVMILES_S_LOG'] = data['SERVMILES_S'].apply(lambda x : np.log(x + 1))
    
data['EOL_SOL'] = data['EOL'] + data['SOL']


data['CAL_STATION'] = np.where(data['CALTRAIN_AVG'] > 0,1,0)
data['CLOSE_STOP'] = np.where(data['DIST_FROM_LAST_STOP'] < 0.2, 1,0)

data['LIMITED'] = 0
data['EXPRESS'] = 0

data = data.apply(lambda x : set_routes(x,limited,express),axis = 1)
# Out:
# Got One
# Got One
# Got One
# Got One
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# Got One
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:216: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:217: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:219: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:220: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:221: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:222: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:224: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# C:\Anaconda\lib\site-packages\pandas\core\generic.py:2773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:228: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:231: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:233: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:235: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:237: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:240: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:241: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:243: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-163-88e9d9c08750> in <module>()
#     244 data['EXPRESS'] = 0
#     245
# --> 246 data = data.apply(lambda x : set_routes(x,limited,express),axis = 1)
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4150                     if reduce is None:
#    4151                         reduce = True
# -> 4152                     return self._apply_standard(f, axis, reduce=reduce)
#    4153             else:
#    4154                 return self._apply_broadcast(f, axis)
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4246             try:
#    4247                 for i, v in enumerate(series_gen):
# -> 4248                     results[i] = func(v)
#    4249                     keys.append(v.name)
#    4250             except Exception as e:
#
# <ipython-input-163-88e9d9c08750> in <lambda>(x)
#     244 data['EXPRESS'] = 0
#     245
# --> 246 data = data.apply(lambda x : set_routes(x,limited,express),axis = 1)
#
# NameError: ("name 'set_routes' is not defined", 'occurred at index 0')

# %%
data.head()
# Out:
#         MONTH  DOW AGENCY_ID ROUTE_SHORT_NAME  DIR  SEQ  NUMDAYS  OBSDAYS  \
# 0  2009-10-01    1     SFMTA            016AX    0    3       22     18.0
# 1  2009-10-01    1     SFMTA            016AX    0    4       22      0.0
# 2  2009-10-01    1     SFMTA            016AX    0    5       22     18.0
# 3  2009-10-01    1     SFMTA            016AX    0    6       22     18.0
# 4  2009-10-01    1     SFMTA            016AX    0    7       22     18.0
#
#    TRIP_STOPS  OBS_TRIP_STOPS  IMP_TRIP_STOPS  WGT_TRIP_STOPS  STOP_ID  \
# 0          13               2             0.0            13.0     3612
# 1          13               0             0.0            13.0     7305
# 2          13               2             0.0            13.0     6733
# 3          13               2             0.0            13.0     6719
# 4          13               2             0.0            13.0     6721
#
#   ROUTE_LONG_NAME  ROUTE_TYPE TRIP_HEADSIGN  HEADWAY_S  FARE  \
# 0   NORIEGA A EXP           3   48TH AVENUE  10.666667   2.0
# 1   NORIEGA A EXP           3   48TH AVENUE  10.666667   2.0
# 2   NORIEGA A EXP           3   48TH AVENUE  10.666667   2.0
# 3   NORIEGA A EXP           3   48TH AVENUE  10.666667   2.0
# 4   NORIEGA A EXP           3   48TH AVENUE  10.666667   2.0
#
#                       STOPNAME               STOPNAME_AVL  EOL  SOL  \
# 0  CYRIL MAGNIN ST & MARKET ST  5TH ST NORTH&MARKET ST NW    0    1
# 1    EDDY ST & CYRIL MAGNIN ST                        NaN    0    0
# 2          TURK ST & TAYLOR ST  TURK ST&TAYLOR ST N-MB/BZ    0    0
# 3           TURK ST & JONES ST  TURK ST&JONES ST NW-FS/BZ    0    0
# 4     TURK ST & LEAVENWORTH ST  TURK ST&LEAVENWORTH ST NW    0    0
#
#    TIMEPOINT  ARRIVAL_TIME_DEV  DEPARTURE_TIME_DEV  DWELL_S      DWELL  \
# 0        1.0         -3.875743           -0.070542      0.0  49.476280
# 1        NaN               NaN                 NaN      0.0        NaN
# 2        0.0          0.270194            0.350709      0.0   1.049097
# 3        0.0          0.134795            0.177869      0.0   0.563574
# 4        0.0          0.291456            0.363253      0.0   0.933352
#
#    RUNTIME_S    RUNTIME  TOTTIME_S    TOTTIME  SERVMILES_S  SERVMILES  \
# 0       0.00   0.000000       0.00  49.476280        0.000      0.000
# 1       2.99        NaN       2.99        NaN        0.429      0.429
# 2      11.05  18.514923      11.05  19.564020        1.287      1.287
# 3      12.74   9.969848      12.74  10.533422        1.937      1.937
# 4       7.80   9.271992       7.80  10.205344        1.183      1.183
#
#    RUNSPEED_S  RUNSPEED  TOTSPEED_S  TOTSPEED   ONTIME
DHLTH_RAC_DEN  EDHLTH_WAC_DEN  EMP_RAC_DEN   EMP_WAC_DEN  HOUSING_09_DEN  \
# 0      386.550972      947.978749  2304.134103  23327.688165     5228.029117
# 1      422.677807      969.977231  2523.361788  24047.208801     5628.179524
# 2      701.486744     1068.166199  4220.336888  16801.028416     8407.626181
# 3     1075.308922     1560.439442  6601.184363   7826.436312    12257.278286
# 4     1155.747384     1737.379187  7145.033298   7268.202018    12145.475864
#
#    LEISER_RAC_DEN  LEISER_WAC_DEN  OTHER_RAC_DEN  OTHER_WAC_DEN  SHR_HH_0VEH  \
# 0      389.488489     5105.395659    1347.669953    9952.476242     0.912738
# 1      434.528609     5761.387676    1468.926440    9870.496644     0.912738
# 2      720.780957     3204.212231    2466.032448    8965.385807     0.912738
# 3     1199.391538     1487.665255    3801.657862    4463.413364     0.912738
# 4     1318.267240     1918.881981    4092.822691    3402.545888     0.872892
#
#    SHR_INCOME_0_15  SHR_INCOME_100P  SHR_INCOME_15_50  SHR_INCOME_50_100  \
# 0         0.650953         0.003761          0.278084           0.067202
# 1         0.650953         0.003761          0.278084           0.067202
# 2         0.650953         0.003761          0.278084           0.067202
# 3         0.650953         0.003761          0.278084           0.067202
# 4         0.420841         0.034734          0.397433           0.146992
#
#    PARK_12_HR_OFF_PUB  PARK_1_HR_OFF_PUB  PARK_2_HR_OFF_PUB  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2              1150.0             1150.0             1150.0
# 3                 NaN                NaN                NaN
# 4              2500.0             2500.0             2500.0
#
#    PARK_3_HR_OFF_PUB  PARK_4_HR_OFF_PUB  PARK_DAY_OFF_PUB  \
# 0                NaN                NaN               NaN
# 1                NaN                NaN               NaN
# 2             1150.0             1150.0            1150.0
# 3                NaN                NaN               NaN
# 4             2500.0             2500.0            2500.0
#
#    PARK_DAY_DISCOUNT_OFF_PUB  RETAIL_RAC_DEN  RETAIL_WAC_DEN  \
# 0                        NaN      180.424689     7321.837516
# 1                        NaN      197.228932     7445.347251
# 2                      995.5      332.036740     3563.264178
# 3                        NaN      524.826041      314.918252
# 4                     1671.0      578.195983      209.394962
#
#    AVG_TT_TO_WORK_MINUTES  PARKING_RATE_OFF_RESIDENTIAL  EXCLUDE    AVG_RIDE  \
# 0                    29.4                      0.320246        0  129.266601
# 1                    29.4                      0.320246        0         NaN
# 2                    29.4                      0.167471        0    3.685053
# 3                    29.4                      0.375314        0    2.627513
# 4                    24.7                      0.625052        0    2.949074
#
#    LOG_RIDERS  AVG_BART  CALTRAIN_AVG  MUNI_RAIL_AVG  BIKE_AVG  \
# 0    4.869583    4722.5           0.0         3316.0   28567.0
# 1         NaN    4722.5           0.0         3316.0   28567.0
# 2    1.544377    4722.5           0.0         3316.0   17631.5
# 3    1.288547    6961.0           0.0         5359.5   11757.0
# 4    1.373481    6961.0           0.0         4292.5   14658.5
#
#    PARK_12_HR_OFF_PUB_LOG  BIKE_BOARDINGS_LOG  BIKE_ALIGHTINGS_LOG  \
# 0                     NaN           10.281924            10.237671
# 1                     NaN           10.281924            10.237671
# 2                7.048386            9.762788             9.791997
# 3                     NaN            9.387566             9.356776
# 4                7.824446            9.627668             9.556763
#
#    BIKE_AVG_LOG  PARK_1_HR_OFF_PUB_LOG  PARK_2_HR_OFF_PUB_LOG  \
# 0     10.260042                    NaN                    NaN
# 1     10.260042                    NaN                    NaN
# 2      9.777499               7.048386               7.048386
# 3      9.372289                    NaN                    NaN
# 4      9.592844               7.824446               7.824446
#
#    PARK_3_HR_OFF_PUB_LOG  PARK_4_HR_OFF_PUB_LOG  AVG_BART_LOG  \
# 0                    NaN                    NaN      8.460305
# 1                    NaN                    NaN      8.460305
# 2               7.048386               7.048386      8.460305
# 3                    NaN                    NaN      8.848222
# 4               7.824446               7.824446      8.848222
#
#    AVG_HH_SIZE_LOG  AVG_TT_TO_WORK_MINUTES_LOG  BART_FROMS_LOG  BART_TOS_LOG  \
# 0         0.949339                    3.414443        8.449771      8.470730
# 1         0.949339                    3.414443        8.449771      8.470730
# 2         0.949339                    3.414443        8.449771      8.470730
# 3         0.949339                    3.414443        8.854808      8.841593
# 4         1.008874                    3.246491        8.854808      8.841593
#
#    CALTRAIN_AVG_LOG  CALTRAIN_OFF_LOG  CALTRAIN_ON_LOG  CAPACITY_LOG  \
# 0               0.0               0.0              0.0      5.247024
# 1               0.0               0.0              0.0           NaN
# 2               0.0               0.0              0.0      5.247024
# 3               0.0               0.0              0.0      5.247024
# 4               0.0               0.0              0.0      5.247024
#
#    CROWDED_LOG  CROWDHOURS_LOG  PARK_DAY_DISCOUNT_OFF_PUB_LOG  \
# 0          0.0             0.0                            NaN
# 1          NaN             NaN                            NaN
# 2          0.0             0.0                       6.904249
# 3          0.0             0.0                            NaN
# 4          0.0             0.0                       7.421776
#
#    PARK_DAY_OFF_PUB_LOG  DWELL_LOG  DWELL_S_LOG  EDD_EMP_LOG  \
# 0                   NaN   3.921504          0.0    10.004328
# 1                   NaN        NaN          0.0    10.061474
# 2              7.048386   0.717399          0.0     9.678718
# 3                   NaN   0.446974          0.0     9.058936
# 4              7.824446   0.659255          0.0     9.224638
#
#    EDHLTH_RAC_DEN_LOG  EDHLTH_WAC_DEN_LOG  EMP_RAC_DEN_LOG  EMP_WAC_DEN_LOG  \
# 0            5.959847            6.855386         7.742894        10.057439
# 1            6.048973            6.878303         7.833744        10.087816
# 2            6.554627            6.974634         8.347907         9.729255
# 3            6.981293            7.353363         8.795156         8.965390
# 4            7.053367            7.460708         8.874313         8.891402
#
#    FARE_LOG  FREQ_S_LOG  FULLFARE_REV_LOG  HEADWAY_S_LOG  HH_DEN_ACS_LOG  \
# 0  1.098612     1.89085          6.249174       2.456736        4.412071
# 1  1.098612     1.89085               NaN       2.456736        4.412071
# 2  1.098612     1.89085          2.725152       2.456736        4.412071
# 3  1.098612     1.89085          2.234669       2.456736        4.412071
# 4  1.098612     1.89085          1.906520       2.456736        3.601448
#
#    PARK_HOURLY_AVG_ON_LOG  HOUSING_09_DEN_LOG  HU_DEN_ACS_LOG  \
# 0                5.860786            8.561981        4.590174
# 1                5.860786            8.635719        4.590174
# 2                5.860786            9.037013        4.590174
# 3                5.707110            9.413957        4.590174
# 4                5.707110            9.404794        3.737655
#
#    LEISER_RAC_DEN_LOG  LEISER_WAC_DEN_LOG  MUNI_RAIL_ALIGHTINGS_LOG  \
# 0            5.967398            8.538249                  7.822845
# 1            6.076560            8.659107                  7.822845
# 2            6.581722            8.072534                  7.822845
# 3            7.090403            7.305635                  8.534247
# 4            7.184832            7.560019                  8.311890
#
#    MUNI_RAIL_AVG_LOG  MUNI_RAIL_BOARDINGS_LOG  NUM_BUS_STOPS_LOG  \
# 0           8.106816                 8.327726           3.688879
# 1           8.106816                 8.327726           3.663562
# 2           8.106816                 8.327726           3.663562
# 3           8.586813                 8.636752           3.663562
# 4           8.364858                 8.415160           3.688879
#
#    OCC_RATE_LOG   OFF_LOG    ON_LOG  ONTIME5_LOG  OTHER_RAC_DEN_LOG  \
# 0      0.607144  0.215709  5.557957     0.552409           7.206874
# 1      0.607144       NaN       NaN          NaN           7.292968
# 2      0.607144  0.215709  2.095483     0.547066           7.810771
# 3      0.607144  0.733969  1.643200     0.516603           8.243456
# 4      0.625701  1.394593  1.351914     0.497885           8.317234
#
#    OTHER_WAC_DEN_LOG  PARKING_RATE_OFF_RESIDENTIAL_LOG  PASSDELAY_ARR_LOG  \
# 0           9.205677                          0.277818           4.523496
# 1           9.197407                          0.277818                NaN
# 2           9.101238                          0.154840           1.882470
# 3           8.403893                          0.318682           2.000190
# 4           8.132573                          0.485540           1.805221
#
#    PASSDELAY_DEP_LOG  PASSHOURS_LOG  PASSMILES_LOG  POP_DEN_ACS_LOG  \
# 0           5.664704       3.049410       0.000000         4.867543
# 1                NaN            NaN            NaN         4.867543
# 2           1.941989       2.041275       3.279819         4.867543
# 3           2.108683       1.528469       3.701598         4.867543
# 4           1.857885       1.500866       3.235242         4.145081
#
#    RDBRDNGS_LOG  RETAIL_RAC_DEN_LOG  RETAIL_WAC_DEN_LOG  RUNSPEED_LOG  \
# 0           0.0            5.200841            8.898753      0.000000
# 1           NaN            5.289423            8.915479           NaN
# 2           0.0            5.808253            8.178713      1.599388
# 3           0.0            6.264970            5.755483      2.487404
# 4           0.0            6.361641            5.348987      2.074429
#
#    RUNSPEED_S_LOG  RUNTIME_LOG  RUNTIME_S_LOG  SHR_HH_0VEH_LOG  \
# 0        0.000000     0.000000       0.000000         0.648536
# 1        2.262804          NaN       1.383791         0.648536
# 2        2.078191     2.971179       2.489065         0.648536
# 3        2.314514     2.395150       2.620311         0.648536
# 4        2.312535     2.329421       2.174752         0.627484
#
#    SHR_INCOME_0_15_LOG  SHR_INCOME_100P_LOG  SHR_INCOME_15_50_LOG  \
# 0             0.501353             0.003754              0.245362
# 1             0.501353             0.003754              0.245362
# 2             0.501353             0.003754              0.245362
# 3             0.501353             0.003754              0.245362
# 4             0.351249             0.034145              0.334637
#
#    SHR_INCOME_50_100_LOG  TOTSPEED_LOG  TOTSPEED_S_LOG  TOTTIME_LOG  \
# 0               0.065040      0.000000        0.000000     3.921504
# 1               0.065040           NaN        2.262804          NaN
# 2               0.065040      1.599388        2.078191     3.023543
# 3               0.065040      2.487404        2.314514     2.445249
# 4               0.137143      2.074429        2.312535     2.416391
#
#    TOTTIME_S_LOG  Total_Housing_Units_LOG  Total_Pop_LOG  VAC_RATE_LOG  \
# 0       0.000000                 8.471359       8.751158      0.152564
# 1       1.383791                 8.471359       8.751158      0.152564
# 2       2.489065                 8.471359       8.751158      0.152564
# 3       2.620311                 8.471359       8.751158      0.152564
# 4       2.174752                 8.427268       8.842749      0.122611
#
#      VC_LOG  WAITHOURS_LOG  DIST_FROM_LAST_STOP  DIST_FROM_LAST_STOP_LOG  \
# 0  0.000294       3.178739             0.000000                 0.000000
# 1       NaN            NaN             0.003178                 0.003173
# 2  0.274122       0.426308             0.009533                 0.009488
# 3  0.280496       0.298760             0.014348                 0.014246
# 4  0.283341       0.296887             0.008763                 0.008725
#
#    SERVMILES_S_LOG  EOL_SOL  CAL_STATION  CLOSE_STOP  LIMITED  EXPRESS
# 0         0.000000        1            0           1        0        0
# 1         0.356975        0            0           1        0        0
# 2         0.827241        0            0           1        0        0
# 3         1.077389        0            0           1        0        0
# 4         0.780700        0            0           1        0        0

# %%
# Check the 2009 Third Buffer Data for the same 2009 Tenth Buffer Model
# -- Looks good, but the tenth is better. 

mod = smf.formula.ols(formula="LOG_RIDERS \
                       ~ EDD_EMP_LOG \
                       + FREQ_S_LOG \
                       + EOL_SOL \
                       + HOUSING_09_DEN_LOG \
                       + SHR_INCOME_100P_LOG \
                       + PARK_HOURLY_AVG_ON_LOG \
                       + AVG_BART_LOG \
                       + CLOSE_STOP \
                       + LIMITED \
                       + EXPRESS \
                       + ONTIME5 \
                       + TRANSBAY \
                       + MUNI_RAIL_AVG \
                       + CAL_STATION \
                       -1",
             data = data)

res = mod.fit()
print(res.summary())
res.save('Bus_Final_Model_2009.jpeg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\patsy\compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#     116     try:
# --> 117         return f(*args, **kwargs)
#     118     except Exception as e:
#
# C:\Anaconda\lib\site-packages\patsy\eval.py in eval(self, expr, source_name, inner_namespace)
#     165         return eval(code, {}, VarLookupDict([inner_namespace]
# --> 166                                             + self._namespaces))
#     167
#
# <string> in <module>()
#
# NameError: name 'HOUSING_09_DEN_LOG' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# <ipython-input-12-4fab971a8508> in <module>()
#       3
#       4 mod = smf.formula.ols(formula="LOG_RIDERS                        ~ EDD_EMP_LOG                        + FREQ_S_LOG                        + EOL_SOL                        + HOUSING_09_DEN_LOG                        + SHR_INCOME_100P_LOG                        + PARK_HOURLY_AVG_ON_LOG                        + AVG_BART_LOG                        + CLOSE_STOP                        + LIMITED                        + EXPRESS                        + ONTIME5                        + TRANSBAY                        + MUNI_RAIL_AVG                        + CAL_STATION                        -1",
# ----> 5              data = data)
#       6
#       7 res = mod.fit()
#
# C:\Anaconda\lib\site-packages\statsmodels\base\model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     153
#     154         tmp = handle_formula_data(data, None, formula, depth=eval_env,
# --> 155                                   missing=missing)
#     156         ((endog, exog), missing_idx, design_info) = tmp
#     157
#
# C:\Anaconda\lib\site-packages\statsmodels\formula\formulatools.py in handle_formula_data(Y, X, formula, depth, missing)
#      63         if data_util._is_using_pandas(Y, None):
#      64             result = dmatrices(formula, Y, depth, return_type='dataframe',
# ---> 65                                NA_action=na_action)
#      66         else:
#      67             result = dmatrices(formula, Y, depth, return_type='dataframe',
#
# C:\Anaconda\lib\site-packages\patsy\highlevel.py in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     308     eval_env = EvalEnvironment.capture(eval_env, reference=1)
#     309     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
# --> 310                                       NA_action, return_type)
#     311     if lhs.shape[1] == 0:
#     312         raise PatsyError("model is missing required outcome variables")
#
# C:\Anaconda\lib\site-packages\patsy\highlevel.py in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     163         return iter([data])
#     164     design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
# --> 165                                       NA_action)
#     166     if design_infos is not None:
#     167         return build_design_matrices(design_infos, data,
#
# C:\Anaconda\lib\site-packages\patsy\highlevel.py in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      68                                       data_iter_maker,
#      69                                       eval_env,
# ---> 70                                       NA_action)
#      71     else:
#      72         return None
#
# C:\Anaconda\lib\site-packages\patsy\build.py in design_matrix_builders(termlists, data_iter_maker, eval_env, NA_action)
#     694                                                    factor_states,
#     695                                                    data_iter_maker,
# --> 696                                                    NA_action)
#     697     # Now we need the factor infos, which encapsulate the knowledge of
#     698     # how to turn any given factor into a chunk of data:
#
# C:\Anaconda\lib\site-packages\patsy\build.py in _examine_factor_types(factors, factor_states, data_iter_maker, NA_action)
#     441     for data in data_iter_maker():
#     442         for factor in list(examine_needed):
# --> 443             value = factor.eval(factor_states[factor], data)
#     444             if factor in cat_sniffers or guess_categorical(value):
#     445                 if factor not in cat_sniffers:
#
# C:\Anaconda\lib\site-packages\patsy\eval.py in eval(self, memorize_state, data)
#     564         return self._eval(memorize_state["eval_code"],
#     565                           memorize_state,
# --> 566                           data)
#     567
#     568     __getstate__ = no_pickling
#
# C:\Anaconda\lib\site-packages\patsy\eval.py in _eval(self, code, memorize_state, data)
#     549                                  memorize_state["eval_env"].eval,
#     550                                  code,
# --> 551                                  inner_namespace=inner_namespace)
#     552
#     553     def memorize_chunk(self, state, which_pass, data):
#
# C:\Anaconda\lib\site-packages\patsy\compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#     122                                  origin)
#     123             # Use 'exec' to hide this syntax from the Python 2 parser:
# --> 124             exec("raise new_exc from e")
#     125         else:
#     126             # In python 2, we just let the original exception escape -- better
#
# C:\Anaconda\lib\site-packages\patsy\compat.py in <module>()
#
# PatsyError: Error evaluating factor: NameError: name 'HOUSING_09_DEN_LOG' is not defined
#     LOG_RIDERS                        ~ EDD_EMP_LOG                        + FREQ_S_LOG                        + EOL_SOL                        + HOUSING_09_DEN_LOG                        + SHR_INCOME_100P_LOG                        + PARK_HOURLY_AVG_ON_LOG                        + AVG_BART_LOG                        + CLOSE_STOP                        + LIMITED                        + EXPRESS                        + ONTIME5                        + TRANSBAY                        + MUNI_RAIL_AVG                        + CAL_STATION                        -1
#                                                                                                                                                   ^^^^^^^^^^^^^^^^^^

# %%
sns.distplot(res.resid)
