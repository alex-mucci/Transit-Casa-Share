# %%
import pandas as pd
import numpy as np

# %%
pre_drop09 = pd.read_csv('E:/Transit-Casa-Alex/Output/Modeling/2009/Tenth_Data_rs_day09.csv',index_col = 0)
post_drop09 = pd.read_csv('E:/Transit-Casa-Alex/Output/Modeling/2009/Final_Model_Data_Post_Drop09.csv',index_col = 0)

pre_drop16 = pd.read_csv('E:/Transit-Casa-Alex/Output/Modeling/2016/Tenth_Data_rs_day16.csv',index_col = 0)
post_drop16 = pd.read_csv('E:/Transit-Casa-Alex/Output/Modeling/2016/Final_Model_Data_Post_Drop16.csv',index_col = 0)

model09 = pd.read_csv('Tenth_Modeling_Data.csv')
model16 = pd.read_csv('Tenth_Modeling_Data16.csv')

# %%
# changed all of the XXL routes to XXR

# %%
post_drop09 = pd.read_csv('post_drop.csv',index_col = 0)
model09=pd.read_csv('model09.csv',index_col = 0)

# %%
pre_drop09.head()
# Out:
#    STOP_ID ROUTE_SHORT_NAME  DIR  SOL         OFF     CAPACITY   CROWDED  \
# 0      390               17    1  0.0   55.675676  1123.374883  0.000000
# 1      390               28    1  0.0  231.755743   810.021612  0.003801
# 2      390              28L    1  0.0  142.409655   375.734804  0.000000
# 3      390               29    1  0.0  302.216678   778.930567  0.036238
# 4      390               91    0  1.0    0.054204   139.725490  0.000000
#
#        DWELL  ROUTE_TYPE  PASSHOURS  \
# 0   7.043406           3   4.945424
# 1  29.984671           3  20.862184
# 2  13.223086           3   7.500257
# 3  23.738284           3  24.812916
# 4   0.000000           3   0.000000
#
#                          ...                          RETAIL_WAC_SCALED  \
# 0                        ...                                  25.642785
# 1                        ...                                  25.642785
# 2                        ...                                  25.642785
# ...

# %%
merged_model = pd.merge(model09,model16,on = ['ROUTE_SHORT_NAME','DIR','STOP_ID'],how = 'inner',suffixes = ('_09','_16'))

# %%
merged_model['PARK_HOURLY_AVG_ON_LOG_09'] = np.log(merged_model.PARK_HOURLY_AVG_ON_09+1)
merged_model['PARK_HOURLY_AVG_ON_LOG_16'] = np.log(merged_model.PARK_HOURLY_AVG_ON_16+1)

merged_model['AVG_BART_LOG_09'] = np.log(merged_model.AVG_BART_09+1)
merged_model['AVG_BART_LOG_16'] = np.log(merged_model.AVG_BART_16+1)

merged_model['FREQ_S_LOG_09'] = np.log(merged_model.FREQ_S_09+1)
merged_model['FREQ_S_LOG_16'] = np.log(merged_model.FREQ_S_16+1)

merged_model['HOUSING_09_DEN_LOG'] = np.log(merged_model.HOUSING_09_DEN+1)
merged_model['HOUSING_16_DEN_LOG'] = np.log(merged_model.HOUSING_16_DEN+1)

merged_model['EDD_EMP_LOG_09'] = np.log(merged_model.EDD_EMP_09 + 1)
merged_model['EDD_EMP_LOG_16'] = np.log(merged_model.EDD_EMP_16 + 1)

# %%
merged_model[['EDD_EMP_LOG_09','FREQ_S_LOG_09','EOL_SOL_09','HOUSING_09_DEN_LOG','SHR_INCOME_100P_09','PARK_HOURLY_AVG_ON_LOG_09','ONTIME5_09','AVG_BART_LOG_09','CLOSE_STOP_09','LIMITED_09','EXPRESS_09','TRANSBAY_09','MUNI_RAIL_AVG_09','EDD_EMP_LOG_16','FREQ_S_LOG_16','EOL_SOL_16','HOUSING_16_DEN_LOG','SHR_INCOME_100P_16','PARK_HOURLY_AVG_ON_LOG_16','ONTIME5_16','AVG_BART_LOG_16','CLOSE_STOP_16','LIMITED_16','EXPRESS_16','TRANSBAY_16','MUNI_RAIL_AVG_16']].to_csv('Merged Model Data.csv')

# %%
merged_pre = pd.merge(pre_drop09,pre_drop16,on = ['ROUTE_SHORT_NAME','DIR','STOP_ID'],how = 'outer',suffixes = ('_09','_16'))

# %%
merged_pre.head()
# Out:
#    STOP_ID ROUTE_SHORT_NAME  DIR  SOL_09      OFF_09  CAPACITY_09  CROWDED_09  \
# 0      390               17    1     0.0   55.675676  1123.374883    0.000000
# 1      390               28    1     0.0  231.755743   810.021612    0.003801
# 2      390              28L    1     0.0  142.409655   375.734804    0.000000
# 3      390               29    1     0.0  302.216678   778.930567    0.036238
# 4      390               91    0     1.0    0.054204   139.725490    0.000000
#
#     DWELL_09  ROUTE_TYPE_09  PASSHOURS_09  \
# 0   7.043406            3.0      4.945424
# 1  29.984671            3.0     20.862184
# 2  13.223086            3.0      7.500257
# 3  23.738284            3.0     24.812916
# 4   0.000000            3.0      0.000000
#
#                          ...                          NUM_BUS_STOPS_16  \
# 0                        ...                                       NaN
# 1                        ...                                       3.0
# ...

# %%
post_drop16.head()
# Out:
#   ROUTE_SHORT_NAME  DIR  LOG_RIDERS  EDD_EMP_LOG  STOP_ID    AVG_RIDE  \
# 0               28    1    6.477286     4.442651      390  649.203572
# 1              28R    1    5.699720     4.442651      390  297.783775
# 2               29    1    3.784672     4.442651      390   43.021243
# 3               91    0    2.852759     4.442651      390   16.335544
# 4               52    0    2.781043     4.406719      913   15.135847
#
#    FREQ_S_LOG  EOL_SOL  HOUSING_16_DEN_LOG  SHR_INCOME_100P  \
# 0    1.790344      0.0            4.746781         0.697574
# 1    1.944524      0.0            4.746781         0.697574
# 2    1.790290      0.0            4.746781         0.697574
# 3    1.098612      1.0            4.746781         0.697574
# 4    1.211610      1.0            4.731255         0.208029
#
#    PARK_HOURLY_AVG_ON_LOG   ONTIME5  AVG_BART_LOG  CLOSE_STOP  LIMITED  \
# 0                5.043425  0.783766           0.0           1        0
# ...

# %%
post_drop09.head()
# Out:
#   ROUTE_SHORT_NAME  DIR  LOG_RIDERS  EDD_EMP_LOG  STOP_ID    AVG_RIDE  \
# 0               17    1    3.911894     8.361007      390   48.993570
# 1               28    1    5.930218     8.361007      390  375.236597
# 2              28R    1    5.261603     8.361007      390  191.790277
# 3               29    1    5.520213     8.361007      390  248.688301
# 4               91    0    2.746150     8.361007      390   14.582524
#
#    FREQ_S_LOG  EOL_SOL  HOUSING_09_DEN_LOG  SHR_INCOME_100P  \
# 0    1.248563      0.0            4.746781         0.065312
# 1    1.768145      0.0            4.746781         0.065312
# 2    1.368138      0.0            4.746781         0.065312
# 3    1.298248      0.0            4.746781         0.065312
# 4    1.098612      1.0            4.746781         0.065312
#
#    PARK_HOURLY_AVG_ON_LOG   ONTIME5  AVG_BART_LOG  CLOSE_STOP  LIMITED  \
# 0                5.043425  0.619299           0.0           1        0
# ...

# %%
merged_post = pd.merge(post_drop09,post_drop16,how = 'outer',on = ['ROUTE_SHORT_NAME','DIR','STOP_ID'],suffixes = ('_09','_16'))

# %%
merged_post.head()
# Out:
#   ROUTE_SHORT_NAME  DIR  LOG_RIDERS_09  EDD_EMP_LOG_09  STOP_ID  AVG_RIDE_09  \
# 0               17    1       3.911894        8.361007      390    48.993570
# 1               28    1       5.930218        8.361007      390   375.236597
# 2              28R    1       5.261603        8.361007      390   191.790277
# 3               29    1       5.520213        8.361007      390   248.688301
# 4               91    0       2.746150        8.361007      390    14.582524
#
#    FREQ_S_LOG_09  EOL_SOL_09  HOUSING_09_DEN_LOG  SHR_INCOME_100P_09  \
# 0       1.248563         0.0            4.746781            0.065312
# 1       1.768145         0.0            4.746781            0.065312
# 2       1.368138         0.0            4.746781            0.065312
# 3       1.298248         0.0            4.746781            0.065312
# 4       1.098612         1.0            4.746781            0.065312
#
#          ...         HOUSING_16_DEN_LOG  SHR_INCOME_100P_16  \
# ...

# %%
merged_pre.head()
# Out:
#    STOP_ID ROUTE_SHORT_NAME  DIR  SOL_09      OFF_09  CAPACITY_09  CROWDED_09  \
# 0      390               17    1     0.0   55.675676  1123.374883    0.000000
# 1      390               28    1     0.0  231.755743   810.021612    0.003801
# 2      390              28L    1     0.0  142.409655   375.734804    0.000000
# 3      390               29    1     0.0  302.216678   778.930567    0.036238
# 4      390               91    0     1.0    0.054204   139.725490    0.000000
#
#     DWELL_09  ROUTE_TYPE_09  PASSHOURS_09  \
# 0   7.043406            3.0      4.945424
# 1  29.984671            3.0     20.862184
# 2  13.223086            3.0      7.500257
# 3  23.738284            3.0     24.812916
# 4   0.000000            3.0      0.000000
#
#                          ...                          NUM_BUS_STOPS_16  \
# 0                        ...                                       NaN
# 1                        ...                                       3.0
# ...

# %%
merged_post.head()
# Out:
#   ROUTE_SHORT_NAME  DIR  LOG_RIDERS_09  EDD_EMP_LOG_09  STOP_ID  AVG_RIDE_09  \
# 0               17    1       3.911894        8.361007      390    48.993570
# 1               28    1       5.930218        8.361007      390   375.236597
# 2              28R    1       5.261603        8.361007      390   191.790277
# 3               29    1       5.520213        8.361007      390   248.688301
# 4               91    0       2.746150        8.361007      390    14.582524
#
#    FREQ_S_LOG_09  EOL_SOL_09  HOUSING_09_DEN_LOG  SHR_INCOME_100P_09  \
# 0       1.248563         0.0            4.746781            0.065312
# 1       1.768145         0.0            4.746781            0.065312
# 2       1.368138         0.0            4.746781            0.065312
# 3       1.298248         0.0            4.746781            0.065312
# 4       1.098612         1.0            4.746781            0.065312
#
#          ...         HOUSING_16_DEN_LOG  SHR_INCOME_100P_16  \
# ...

# %%
missing09 = merged_post[np.isnan(merged_post['AVG_RIDE_09'])]
print(missing09.AVG_RIDE_16.sum())

missing16 = merged_post[np.isnan(merged_post['AVG_RIDE_16'])]
print(missing16.AVG_RIDE_09.sum())
# Out:
# 92133.50724435228
# 124768.91028149305

# %%
merged_pre['FREQ_S_09'] = 1/(merged_pre['HEADWAY_S_09']/60)
merged_pre.FREQ_S_09.sum()*24

# %%
merged_pre['FREQ_S_16'] = 1/(merged_pre['HEADWAY_S_16']/60)


merged_pre['FREQ_S_16'].drop(7852,axis = 0).sum()*24
# Out:
# 568405.872306327

# %%
len(merged_pre[np.isnan(merged_pre['ON_09'])])
# Out:
# 1579

# %%
len(merged_pre[np.isnan(merged_pre['ON_16'])])
# Out:
# 2708

# %%
merged_pre_inner = pd.merge(pre_drop09,pre_drop16,on = ['ROUTE_SHORT_NAME','DIR','STOP_ID'],how = 'inner',suffixes = ('_09','_16'))

# %%
len(merged_pre_inner)
# Out:
# 4470

# %%
len(merged_post[np.isnan(merged_post['LOG_RIDERS_09'])])
# Out:
# 1013

# %%
len(merged_post[np.isnan(merged_post['LOG_RIDERS_16'])])
# Out:
# 2020

# %%
merged_post_inner = pd.merge(post_drop09,post_drop16,on = ['ROUTE_SHORT_NAME','DIR','STOP_ID'],how = 'inner',suffixes = ('_09','_16'))

# %%
len(merged_post_inner)
# Out:
# 4241

# %%
data = merged_post_inner

# %%
merged_post.LIMITED_09.sum()
merged_post.LIMITED_16.sum()
# Out:
# 190.0

# %%
data.head()
# Out:
#   ROUTE_SHORT_NAME  DIR  LOG_RIDERS_09  EDD_EMP_LOG_09  STOP_ID  AVG_RIDE_09  \
# 0               28    1       5.930218        8.361007      390   375.236597
# 1              28R    1       5.261603        8.361007      390   191.790277
# 2               29    1       5.520213        8.361007      390   248.688301
# 3               91    0       2.746150        8.361007      390    14.582524
# 4               52    0       3.120669        2.197225      913    21.661540
#
#    FREQ_S_LOG_09  EOL_SOL_09  HOUSING_09_DEN_LOG  SHR_INCOME_100P_09  \
# 0       1.768145         0.0            4.746781            0.065312
# 1       1.368138         0.0            4.746781            0.065312
# 2       1.298248         0.0            4.746781            0.065312
# 3       1.098612         1.0            4.746781            0.065312
# 4       1.243778         1.0            4.731415            0.055249
#
#          ...         HOUSING_16_DEN_LOG  SHR_INCOME_100P_16  \
# ...

# %%
for column in merged_pre_inner.columns.sort_values():
    print(column)
# Out:
# ALAND
# ALAND00
# AVG_HH_SIZE
# AWATER
# AWATER00
# Average Hourly Price_09
# Average Hourly Price_16
# BART_FROMS_09
# BART_FROMS_16
# BART_TOS_09
# BART_TOS_16
# BIKERACK_09
# BIKERACK_16
# BIKE_ALIGHTINGS_09
# BIKE_ALIGHTINGS_16
# BIKE_BOARDINGS_09
# BIKE_BOARDINGS_16
# BIKE_DOCKCOUNT_09
# BIKE_DOCKCOUNT_16
# CALTRAIN_OFF_09
# CALTRAIN_OFF_16
# CALTRAIN_ON_09
# CALTRAIN_ON_16
# CAPACITY_09
# CAPACITY_16
# COUNTYFP
# COUNTYFP00
# CROWDED_09
# CROWDED_16
# CROWDHOURS_09
# CROWDHOURS_16
# CTIDFP00
# Count__09
# Count__16
# DIR
# DOORCYCLES_09
# DOORCYCLES_16
# DOW
# DOW_e
# DWELL_09
# DWELL_16
# DWELL_S_09
# DWELL_S_16
# EDD_EMP_09
# EDD_EMP_16
# EDHLTH_RAC_SCALED_09
# EDHLTH_RAC_SCALED_16
# EDHLTH_WAC_SCALED_09
# EDHLTH_WAC_SCALED_16
# EMP_RAC_SCALED_09
# EMP_RAC_SCALED_16
# EMP_WAC_SCALED_09
# EMP_WAC_SCALED_16
# EOL_09
# EOL_16
# FID_1_09
# FID_1_16
# FULLFARE_REV_09
# FULLFARE_REV_16
# Geography_09
# Geography_16
# HEADWAY_S_09
# HEADWAY_S_16
# HH_0VEH
# HH_DEN_ACS_09
# ...

# %%
merged_post.L
# Out:
#   ROUTE_SHORT_NAME  DIR  LOG_RIDERS_09  EDD_EMP_LOG_09  STOP_ID  AVG_RIDE_09  \
# 0               28    1       5.930218        8.361007      390   375.236597
# 1               29    1       5.520213        8.361007      390   248.688301
# 2               91    0       2.746150        8.361007      390    14.582524
# 3               52    0       3.120669        2.197225      913    21.661540
# 4               52    1       2.612500        2.197225      913    12.633090
#
#    FREQ_S_LOG_09  EOL_SOL_09  HOUSING_09_DEN_LOG  SHR_INCOME_100P_09  \
# 0       1.768145         0.0            4.746781            0.065312
# 1       1.298248         0.0            4.746781            0.065312
# 2       1.098612         1.0            4.746781            0.065312
# 3       1.243778         1.0            4.731415            0.055249
# 4       1.229531         1.0            4.731415            0.055249
#
#          ...         HOUSING_16_DEN_LOG  SHR_INCOME_100P_16  \
# ...

# %%
merged_post_inner.to_csv('Bus Stops in Both Years Post Dropped Data.csv')

# %%
post_drop09.head()
# Out:
#   ROUTE_SHORT_NAME  DIR  LOG_RIDERS  EDD_EMP_LOG  STOP_ID    AVG_RIDE  \
# 0               17    1    3.911894     8.361007      390   48.993570
# 1               28    1    5.930218     8.361007      390  375.236597
# 2              28R    1    5.261603     8.361007      390  191.790277
# 3               29    1    5.520213     8.361007      390  248.688301
# 4               91    0    2.746150     8.361007      390   14.582524
#
#    FREQ_S_LOG  EOL_SOL  HOUSING_09_DEN_LOG  SHR_INCOME_100P  \
# 0    1.248563      0.0            4.746781         0.065312
# 1    1.768145      0.0            4.746781         0.065312
# 2    1.368138      0.0            4.746781         0.065312
# 3    1.298248      0.0            4.746781         0.065312
# 4    1.098612      1.0            4.746781         0.065312
#
#    PARK_HOURLY_AVG_ON_LOG   ONTIME5  AVG_BART_LOG  CLOSE_STOP  LIMITED  \
# 0                5.043425  0.619299           0.0           1        0
# ...

# %%
post_drop16.head()
# Out:
#    STOP_ID ROUTE_SHORT_NAME  DIR  SOL         OFF     CAPACITY   CROWDED  \
# 0      390               28    1  0.0  662.875690  1698.088596  0.026450
# 1      390              28R    1  0.0  181.841813  1283.400000  0.000870
# 2      390               29    1  0.0   50.469007  3328.636218  0.033426
# 3      390               91    0  1.0    0.000000   473.194570  0.000000
# 4      913               52    0  0.0   30.271694  1196.876026  0.000000
#
#        DWELL  ROUTE_TYPE_x  PASSHOURS   ...       VC_LOG  WAITHOURS_LOG  \
# 0  39.276110             3  45.988693   ...     0.237800       4.106451
# 1  30.364947             3  62.191315   ...     0.130646       3.543945
# 2   7.190857             3  20.181317   ...     0.305652       1.404552
# 3   0.000000             3   0.000000   ...     0.000316       2.154631
# 4  26.575731             3   1.558139   ...     0.032783       0.000000
#
#    DIST_FROM_LAST_STOP  DIST_FROM_LAST_STOP_LOG  SERVMILES_S_LOG  EOL_SOL  \
# ...
