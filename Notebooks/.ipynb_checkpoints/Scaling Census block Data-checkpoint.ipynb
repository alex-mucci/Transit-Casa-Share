# %%
import pandas as pd
import geopandas as gp
import numpy as np
import re
pd.set_option('max_columns',500)

# %%
scale = pd.read_csv('E:\Transit-Casa-Share\Data\Split Buffers/Split_Buffers_Tenth.csv')

# %%
scale_geo = gp.read_file('E:/Transit-Casa-Share/Data/Split Buffers/Split_Buffers_Tenth.shp')

# %%
scale_geo.head()
# Out:
#       ALAND   ALAND00        AREA  AWATER  AWATER00           BLKIDFP  \
# 0  469038.0  469038.0  115.901635     0.0       0.0  060750332011006A
# 1   13369.0   13369.0    3.303547     0.0       0.0  060750332011006B
# 2   10544.0   10544.0    2.605475     0.0       0.0   060750309007007
# 3   11922.0   11922.0    2.945986     0.0       0.0   060750309007009
# 4   14502.0   14502.0    3.583517     0.0       0.0   060750309007006
#
#   BLKIDFP00 BLOCKCE00 BLOCKCE0_1  BUFF_DIST  BUFF_DIST_ COUNTYFP COUNTYFP00  \
# 0      None      1006       None      528.0       528.0      075        075
# 1      None      1006       None      528.0       528.0      075        075
# 2      None      7007       None      528.0       528.0      075        075
# 3      None      7009       None      528.0       528.0      075        075
# 4      None      7006       None      528.0       528.0      075        075
#
#   COUNTYFP_1  COUNTYNS  FID_tl_200  FID_tl_201 FUNCSTAT FUNCSTAT00  \
# 0       None  00277302        5711          -1        S       None
# 1       None  00277302        2916          -1        S       None
# 2       None  00277302         164          -1        S       None
# 3       None  00277302        3916          -1        S       None
# 4       None  00277302        1878          -1        S       None
#
#       INTPTLAT INTPTLAT00      INTPTLON INTPTLON00  MTFCC MTFCC00  \
# 0  +37.7240954       None  -122.4797305       None  G5040    None
# 1  +37.7233858       None  -122.4750828       None  G5040    None
# 2  +37.7221659       None  -122.4747150       None  G5040    None
# 3  +37.7206315       None  -122.4740731       None  G5040    None
# 4  +37.7221811       None  -122.4739962       None  G5040    None
#
#           NAME NAME00  ORIG_FID  ORIG_FID_2  SPLIT_AREA  SPLIT_RATI STATEFP  \
# 0  Block 1006A   None         0           0   10.024294    0.086490      06
# 1  Block 1006B   None         0           0    0.866819    0.262390      06
# 2   Block 7007   None         0           0    1.039000    0.398776      06
# 3   Block 7009   None         0           0    0.267529    0.090812      06
# 4   Block 7006   None         0           0    0.119563    0.033365      06
#
#   STATEFP00 STATEFP0_1  STOP_ID  STOP_ID_2  STOP_LAT  STOP_LAT_2    STOP_LON  \
# 0        06       None      390        390  37.72119    37.72119 -122.475096
# 1        06       None      390        390  37.72119    37.72119 -122.475096
# 2        06       None      390        390  37.72119    37.72119 -122.475096
# 3        06       None      390        390  37.72119    37.72119 -122.475096
# 4        06       None      390        390  37.72119    37.72119 -122.475096
#
#    STOP_LON_2 SUFFIX1CE TRACTCE00 TRACTCE0_1   UACE UACE00 UR  UR00  \
# 0 -122.475096         A    033201       None  78904   None  U  None
# 1 -122.475096         B    033201       None  78904   None  U  None
# 2 -122.475096      None    030900       None  78904   None  U  None
# 3 -122.475096      None    030900       None  78904   None  U  None
# 4 -122.475096      None    030900       None  78904   None  U  None
#
#                                             geometry  index_righ
# 0  POLYGON ((5990140.555242101 2091599.49223411, ...           0
# 1  POLYGON ((5990404.358315584 2091528.488919567,...           0
# 2  POLYGON ((5990488.063115086 2091468.644502254,...           0
# 3  POLYGON ((5990640.788074084 2091115.257247695,...           0
# 4  POLYGON ((5990666.047220119 2091120.907530208,...           0

# %%
scale.head()
# Out:
#    Unnamed: 0  BUFF_DIST  ORIG_FID  STOP_ID  STOP_LAT    STOP_LON     ALAND  \
# 0         0.0      528.0       0.0    390.0  37.72119 -122.475096  469038.0
# 1         1.0      528.0       0.0    390.0  37.72119 -122.475096   13369.0
# 2         2.0      528.0       0.0    390.0  37.72119 -122.475096   10544.0
# 3         3.0      528.0       0.0    390.0  37.72119 -122.475096   11922.0
# 4         4.0      528.0       0.0    390.0  37.72119 -122.475096   14502.0
#
#     ALAND00  AWATER  AWATER00           BLKIDFP  BLKIDFP00  BLOCKCE00  \
# 0  469038.0     0.0       0.0  060750332011006A        NaN     1006.0
# 1   13369.0     0.0       0.0  060750332011006B        NaN     1006.0
# 2   10544.0     0.0       0.0          6.08E+13        NaN     7007.0
# 3   11922.0     0.0       0.0          6.08E+13        NaN     7009.0
# 4   14502.0     0.0       0.0          6.08E+13        NaN     7006.0
#
#    BLOCKCE0_1  COUNTYFP  COUNTYFP00  COUNTYFP_1  COUNTYNS  FID_tl_200  \
# 0         NaN      75.0        75.0         NaN  277302.0      5711.0
# 1         NaN      75.0        75.0         NaN  277302.0      2916.0
# 2         NaN      75.0        75.0         NaN  277302.0       164.0
# 3         NaN      75.0        75.0         NaN  277302.0      3916.0
# 4         NaN      75.0        75.0         NaN  277302.0      1878.0
#
#    FID_tl_201 FUNCSTAT FUNCSTAT00   INTPTLAT  INTPTLAT00    INTPTLON  \
# 0        -1.0        S        NaN  37.724095         NaN -122.479730
# 1        -1.0        S        NaN  37.723386         NaN -122.475083
# 2        -1.0        S        NaN  37.722166         NaN -122.474715
# 3        -1.0        S        NaN  37.720632         NaN -122.474073
# 4        -1.0        S        NaN  37.722181         NaN -122.473996
#
#    INTPTLON00  MTFCC MTFCC00         NAME NAME00  STATEFP  STATEFP00  \
# 0         NaN  G5040     NaN  Block 1006A    NaN      6.0        6.0
# 1         NaN  G5040     NaN  Block 1006B    NaN      6.0        6.0
# 2         NaN  G5040     NaN   Block 7007    NaN      6.0        6.0
# 3         NaN  G5040     NaN   Block 7009    NaN      6.0        6.0
# 4         NaN  G5040     NaN   Block 7006    NaN      6.0        6.0
#
#    STATEFP0_1 SUFFIX1CE  TRACTCE00  TRACTCE0_1     UACE  UACE00 UR UR00  \
# 0         NaN         A    33201.0         NaN  78904.0     NaN  U  NaN
# 1         NaN         B    33201.0         NaN  78904.0     NaN  U  NaN
# 2         NaN       NaN    30900.0         NaN  78904.0     NaN  U  NaN
# 3         NaN       NaN    30900.0         NaN  78904.0     NaN  U  NaN
# 4         NaN       NaN    30900.0         NaN  78904.0     NaN  U  NaN
#
#          AREA  index_right  BUFF_DIST_2  ORIG_FID_2  STOP_ID_2  STOP_LAT_2  \
# 0  115.901635          0.0        528.0         0.0      390.0    37.72119
# 1    3.303547          0.0        528.0         0.0      390.0    37.72119
# 2    2.605475          0.0        528.0         0.0      390.0    37.72119
# 3    2.945986          0.0        528.0         0.0      390.0    37.72119
# 4    3.583517          0.0        528.0         0.0      390.0    37.72119
#
#    STOP_LON_2                                           geometry  SPLIT_AREA  \
# 0 -122.475096  POLYGON ((5990140.555242101 2091599.49223411, ...   10.024294
# 1 -122.475096  POLYGON ((5990404.358315584 2091528.488919567,...    0.866819
# 2 -122.475096  POLYGON ((5990488.063115086 2091468.644502254,...    1.039000
# 3 -122.475096  POLYGON ((5990640.788074084 2091115.257247695,...    0.267529
# 4 -122.475096  POLYGON ((5990666.047220119 2091120.907530208,...    0.119563
#
#    SPLIT_RATIO
# 0     0.086490
# 1     0.262390
# 2     0.398776
# 3     0.090812
# 4     0.033365

# %%
scale_geo2 = scale_geo[['STOP_ID','BLKIDFP','BLKIDFP00','geometry','SPLIT_RATI']]

# %%
scale_geo2.head()
# Out:
#    STOP_ID           BLKIDFP BLKIDFP00  \
# 0      390  060750332011006A      None
# 1      390  060750332011006B      None
# 2      390   060750309007007      None
# 3      390   060750309007009      None
# 4      390   060750309007006      None
#
#                                             geometry  SPLIT_RATI
# 0  POLYGON ((5990140.555242101 2091599.49223411, ...    0.086490
# 1  POLYGON ((5990404.358315584 2091528.488919567,...    0.262390
# 2  POLYGON ((5990488.063115086 2091468.644502254,...    0.398776
# 3  POLYGON ((5990640.788074084 2091115.257247695,...    0.090812
# 4  POLYGON ((5990666.047220119 2091120.907530208,...    0.033365

# %%
def set_blockid(row):

    if row['BLKIDFP'] == np.nan: 
        row['BLKIDFP'] = row['BLKIDFP00']
    else:
        row['BLKIDFP'] = row['BLKIDFP']
    return row['BLKIDFP']

# %%
scale_geo2['BLKIDFP'] = scale_geo2.apply(lambda row: set_blockid(row),axis = 1)
# Out:
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
scale_geo2.BLKIDFP.count()
# Out:
# 45875

# %%
scale_geo2.head()
# Out:
#    STOP_ID           BLKIDFP BLKIDFP00  \
# 0      390  060750332011006A      None
# 1      390  060750332011006B      None
# 2      390   060750309007007      None
# 3      390   060750309007009      None
# 4      390   060750309007006      None
#
#                                             geometry  SPLIT_RATI
# 0  POLYGON ((5990140.555242101 2091599.49223411, ...    0.086490
# 1  POLYGON ((5990404.358315584 2091528.488919567,...    0.262390
# 2  POLYGON ((5990488.063115086 2091468.644502254,...    0.398776
# 3  POLYGON ((5990640.788074084 2091115.257247695,...    0.090812
# 4  POLYGON ((5990666.047220119 2091120.907530208,...    0.033365

# %%
scale_geo2 = scale_geo2[['STOP_ID','BLKIDFP','SPLIT_RATI']]

# %%
rename = ['STOP_ID','BLOCK_ID','SPLIT_RATIO']

# %%
scale_geo2.columns = rename

# %%
scale_geo2.head()
# Out:
#    STOP_ID          BLOCK_ID  SPLIT_RATIO
# 0      390  060750332011006A     0.086490
# 1      390  060750332011006B     0.262390
# 2      390   060750309007007     0.398776
# 3      390   060750309007009     0.090812
# 4      390   060750309007006     0.033365

# %%
split_grouped = scale_geo2[['SPLIT_RATIO','BLOCK_ID']].groupby(by = 'BLOCK_ID',as_index = False).sum()

# %%
others_grouped = scale_geo2[['BLOCK_ID','STOP_ID']].groupby(by = 'BLOCK_ID',as_index = False).first()

# %%
print(others_grouped.head())
print(len(others_grouped))
len(split_grouped)
# Out:
#           BLOCK_ID  STOP_ID
# 0  060750101001000     4502
# 1  060750101001003     4100
# 2  060750101001004     5460
# 3  060750101001005     5466
# 4  060750101001006     4530
# 5768
# 5768

# %%
scale = pd.merge(others_grouped,split_grouped, on = 'BLOCK_ID',how = 'outer')
len(scale)
# Out:
# 5768

# %%
lehd = gp.read_file('E:/Transit-Casa-Alex/Output/Employment (LEHD)/Combined_Employment.shp')

# %%
lehd.head()
# Out:
#    ALAND10  AWATER10 BLOCKCE10 COUNTYFP10  EDHEALTH_R  EDHEALTH_W FUNCSTAT10  \
# 0    16958         0      2002        075        16.0         7.0          S
# 1    16823         0      2000        075        19.0         0.0          S
# 2    17020         0      3004        075        25.0         0.0          S
# 3    16415         0      1003        075        10.0         8.0          S
# 4    17523         0      4001        075        22.0         1.0          S
#
#       GEOID10   INTPTLAT10    INTPTLON10  LEISURE_RA  LEISURE_WA MTFCC10  \
# 0  2147483647  +37.7500665  -122.4410751         6.0         0.0   G5040
# 1  2147483647  +37.7501958  -122.4389330         9.0         0.0   G5040
# 2  2147483647  +37.7567937  -122.4362701         6.0         0.0   G5040
# 3  2147483647  +37.7535291  -122.4370498         5.0         0.0   G5040
# 4  2147483647  +37.7557580  -122.4334002         5.0         0.0   G5040
#
#        NAME10  OTHER_RAC  OTHER_WAC  RETAIL_RAC  RETAIL_WAC STATEFP10  \
# 0  Block 2002       34.0        0.0         5.0         0.0        06
# 1  Block 2000       45.0        1.0         6.0         0.0        06
# 2  Block 3004       46.0        1.0         7.0         0.0        06
# 3  Block 1003       38.0       14.0         5.0         0.0        06
# 4  Block 4001       57.0        2.0         6.0         0.0        06
#
#    TOTAL_EMP_  TOTAL_EM_1 TRACTCE10 UACE10 UATYP10 UR10  createda_1  \
# 0         7.0        61.0    021300  78904       U    U  20160228.0
# 1         1.0        79.0    021300  78904       U    U  20160228.0
# 2         1.0        84.0    020500  78904       U    U  20160228.0
# 3        22.0        58.0    021200  78904       U    U  20160228.0
# 4         3.0        90.0    021100  78904       U    U  20160228.0
#
#    createdate                                           geometry  \
# 0  20160228.0  POLYGON ((-122.440616 37.750902, -122.440459 3...
# 1  20160228.0  POLYGON ((-122.438397 37.750226, -122.43832 37...
# 2  20160228.0  POLYGON ((-122.435808 37.757623, -122.435642 3...
# 3  20160228.0  POLYGON ((-122.436527 37.75354, -122.436454 37...
# 4  20160228.0  POLYGON ((-122.432331 37.756227, -122.432254 3...
#
#       h_geocode     w_geocode
# 0  6.075021e+13  6.075021e+13
# 1  6.075021e+13  6.075021e+13
# 2  6.075021e+13  6.075021e+13
# 3  6.075021e+13  6.075021e+13
# 4  6.075021e+13  6.075021e+13

# %%
scale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5768 entries, 0 to 5767
# Data columns (total 3 columns):
# BLOCK_ID       5768 non-null object
# STOP_ID        5768 non-null int64
# SPLIT_RATIO    5768 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 180.2+ KB

# %%
re.sub?

# %%
letters = ['A','B','C']
for letter in letters:
    scale['BLOCK_ID'] = scale['BLOCK_ID'].apply(lambda row: re.sub(letter, '', row))

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-126-10f05cc683c2> in <module>()
# ----> 1 scale['BLOCK_ID'] = scale.BLOCK_ID.apply(lambda row: float(row))
#
# C:\Anaconda\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    2292             else:
#    2293                 values = self.asobject
# -> 2294                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2295
#    2296         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\src\inference.pyx in pandas.lib.map_infer (pandas\lib.c:66124)()
#
# <ipython-input-126-10f05cc683c2> in <lambda>(row)
# ----> 1 scale['BLOCK_ID'] = scale.BLOCK_ID.apply(lambda row: float(row))
#
# ValueError: could not convert string to float: '060750104003001C'

# %%
scale.head()
# Out:
#           BLOCK_ID  STOP_ID  SPLIT_RATIO
# 0  060750101001000     4502     0.772763
# 1  060750101001003     4100     0.954680
# 2  060750101001004     5460     0.423296
# 3  060750101001005     5466     2.469411
# 4  060750101001006     4530     1.255178

# %%
employment = pd.merge(scale,lehd,how='left',left_on = 'BLOCK_ID',right_on = 'h_geocode')

# %%
employment.head()
# Out:
#           BLOCK_ID  STOP_ID  SPLIT_RATIO  ALAND10  AWATER10 BLOCKCE10  \
# 0  060750101001000     4502     0.772763      NaN       NaN       NaN
# 1  060750101001003     4100     0.954680      NaN       NaN       NaN
# 2  060750101001004     5460     0.423296      NaN       NaN       NaN
# 3  060750101001005     5466     2.469411      NaN       NaN       NaN
# 4  060750101001006     4530     1.255178      NaN       NaN       NaN
#
#   COUNTYFP10  EDHEALTH_R  EDHEALTH_W FUNCSTAT10  GEOID10 INTPTLAT10  \
# 0        NaN         NaN         NaN        NaN      NaN        NaN
# 1        NaN         NaN         NaN        NaN      NaN        NaN
# 2        NaN         NaN         NaN        NaN      NaN        NaN
# 3        NaN         NaN         NaN        NaN      NaN        NaN
# 4        NaN         NaN         NaN        NaN      NaN        NaN
#
#   INTPTLON10  LEISURE_RA  LEISURE_WA MTFCC10 NAME10  OTHER_RAC  OTHER_WAC  \
# 0        NaN         NaN         NaN     NaN    NaN        NaN        NaN
# 1        NaN         NaN         NaN     NaN    NaN        NaN        NaN
# 2        NaN         NaN         NaN     NaN    NaN        NaN        NaN
# 3        NaN         NaN         NaN     NaN    NaN        NaN        NaN
# 4        NaN         NaN         NaN     NaN    NaN        NaN        NaN
#
#    RETAIL_RAC  RETAIL_WAC STATEFP10  TOTAL_EMP_  TOTAL_EM_1 TRACTCE10 UACE10  \
# 0         NaN         NaN       NaN         NaN         NaN       NaN    NaN
# 1         NaN         NaN       NaN         NaN         NaN       NaN    NaN
# 2         NaN         NaN       NaN         NaN         NaN       NaN    NaN
# 3         NaN         NaN       NaN         NaN         NaN       NaN    NaN
# 4         NaN         NaN       NaN         NaN         NaN       NaN    NaN
#
#   UATYP10 UR10  createda_1  createdate geometry  h_geocode  w_geocode
# 0     NaN  NaN         NaN         NaN      NaN        NaN        NaN
# 1     NaN  NaN         NaN         NaN      NaN        NaN        NaN
# 2     NaN  NaN         NaN         NaN      NaN        NaN        NaN
# 3     NaN  NaN         NaN         NaN      NaN        NaN        NaN
# 4     NaN  NaN         NaN         NaN      NaN        NaN        NaN

# %%
scale.sort_values('BLOCK_ID')
# Out:
#               BLOCK_ID  STOP_ID  SPLIT_RATIO
# 0      060750101001000     4502     0.772763
# 1      060750101001003     4100     0.954680
# 2      060750101001004     5460     0.423296
# 3      060750101001005     5466     2.469411
# 4      060750101001006     4530     1.255178
# 5      060750101001007     4530     4.083370
# 6      060750101001008     4530     5.194426
# 7      060750101001009     4530     4.151867
# 8      060750101001010     3031     5.504548
# 9      060750101001011     4502     3.820862
# 10     060750101001012     3031     4.644537
# 11    060750101001013A     4502     3.192526
# 12    060750101001013B     4502     2.757195
# 13     060750101001014     3031     4.952078
# 14     060750101001015     3031     6.399849
# 15     060750101001016     4530     7.255092
# 16     060750101001017     5466     4.543749
# 17     060750101001018     5460     1.919426
# 18     060750101001019     4100     3.293906
# 19     060750101001020     4100     3.999375
# 20     060750101001021     4100     4.714783
# 21     060750101001022     4106     2.290265
# 22     060750101001023     5466     4.414823
# 23     060750101001024     3031     6.762598
# 24     060750101001999     4502          inf
# 25     060750101002000     4507     2.001453
# 26     060750101002001     4507     2.452781
# 27     060750101002002     4502     2.714483
# 28     060750101002003     4502     2.544738
# 29     060750101002004     3031     2.718839
# ...                ...      ...          ...
# 5738   060750610001007     5115     0.045647
# 5739   060750610001009     7376     0.873119
# 5740   060750610001010     3146     0.526497
# 5741   060750610001011     3146     0.407006
# 5742  060750610001012A     3619     1.288219
# 5743  060750610001012B     4575     0.252081
# 5744  060750610001012C     3619     2.095031
# 5745  060750610001012D     3619     2.256527
# 5746  060750610001012E     3619     1.679895
# 5747   060750610001013     3619     0.039151
# 5748   060750610002000     3780     0.040568
# 5749   060750610002001     3776     1.793952
# 5750   060750610002002     3776     0.969219
# 5751   060750610002003     3776     0.451502
# 5752   060750610002004     3692     2.046805
# 5753   060750610002005     3692     3.767379
# 5754   060750610002006     3655     5.019394
# 5755   060750610002007     3655     2.785942
# 5756   060750610002008     6569     1.303628
# 5757   060750610002009     3692     1.687219
# 5758   060750610002010     3692     3.912919
# 5759   060750610002011     3692     4.184999
# 5760   060750610002012     7006     2.353600
# 5761   060750610002013     7006     5.644018
# 5762   060750610002014     4576     4.140222
# 5763   060750610002015     4576     4.664458
# 5764  060750610002016A     4576     2.598026
# 5765  060750610002016B     4576     2.593521
# 5766  060750610002017A     3619     1.277875
# 5767  060750610002017B     3619     1.008457
#
# [5768 rows x 3 columns]
