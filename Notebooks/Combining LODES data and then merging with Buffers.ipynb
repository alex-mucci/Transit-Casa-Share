# %%
import pandas as pd
import geopandas as gp
# %matplotlib inline
pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
sf = pd.read_csv('E:/Transit-Casa-Alex/Input/LEHD Census Blocks/San Francisco County/075_Employment.csv')
sm = pd.read_csv('E:/Transit-Casa-Alex/Input/LEHD Census Blocks/San Mateo County/081_Employment.csv')

# %%
sf_geo = gp.read_file('E:/Transit-Casa-Alex/Input/LEHD Census Blocks/San Francisco County/075_Employment.shp')
sm_geo = gp.read_file('E:\Transit-Casa-Alex\Input\LEHD Census Blocks\San Mateo County/081_Employment.shp')

# %%
print(len(sm_geo))
len(sf_geo)
# Out:
# 9262
# 16648

# %%
sf_geo.plot()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-216-4fbe44e19bd7> in <module>()
# ----> 1 sf_geo.plot()
#
# C:\Anaconda\lib\site-packages\geopandas\geodataframe.py in plot(self, *args, **kwargs)
#     445     def plot(self, *args, **kwargs):
#     446
# --> 447         return plot_dataframe(self, *args, **kwargs)
#     448
#     449     plot.__doc__ = plot_dataframe.__doc__
#
# C:\Anaconda\lib\site-packages\geopandas\plotting.py in plot_dataframe(s, column, cmap, color, linewidth, categorical, legend, ax, scheme, k, vmin, vmax, figsize, **color_kwds)
#     238         return plot_series(s.geometry, cmap=cmap, color=color,
#     239                            ax=ax, linewidth=linewidth, figsize=figsize,
# --> 240                            **color_kwds)
#     241     else:
#     242         if s[column].dtype is np.dtype('O'):
#
# ...

# %%
sm_geo.plot()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-217-e7dbe9fb8d8b> in <module>()
# ----> 1 sm_geo.plot()
#
# C:\Anaconda\lib\site-packages\geopandas\geodataframe.py in plot(self, *args, **kwargs)
#     445     def plot(self, *args, **kwargs):
#     446
# --> 447         return plot_dataframe(self, *args, **kwargs)
#     448
#     449     plot.__doc__ = plot_dataframe.__doc__
#
# C:\Anaconda\lib\site-packages\geopandas\plotting.py in plot_dataframe(s, column, cmap, color, linewidth, categorical, legend, ax, scheme, k, vmin, vmax, figsize, **color_kwds)
#     238         return plot_series(s.geometry, cmap=cmap, color=color,
#     239                            ax=ax, linewidth=linewidth, figsize=figsize,
# --> 240                            **color_kwds)
#     241     else:
#     242         if s[column].dtype is np.dtype('O'):
#
# ...

# %%
sf.head()

# %%
sm.head()
# Out:
#    Unnamed: 0  ALAND10  AWATER10  BLOCKCE10  COUNTYFP10 FUNCSTAT10  \
# 0           0    17681         0       4001          81          S
# 1           1    24257         0       2006          81          S
# 2           2   146005         0       2000          81          S
# 3           3    38352         0       2006          81          S
# 4           4    21309         0       2005          81          S
#
#           GEOID10  INTPTLAT10  INTPTLON10 MTFCC10      NAME10  STATEFP10  \
# 0  60816129004001   37.430391 -122.200890   G5040  Block 4001          6
# 1  60816128002006   37.434371 -122.200575   G5040  Block 2006          6
# 2  60816086002000   37.533181 -122.271461   G5040  Block 2000          6
# 3  60816113002006   37.452784 -122.226625   G5040  Block 2006          6
# 4  60816096032005   37.481729 -122.280118   G5040  Block 2005          6
#
#    TRACTCE10   UACE10 UATYP10 UR10  \
# 0     612900  78904.0       U    U
# 1     612800  78904.0       U    U
# ...

# %%
employment = sf.append(sm)
employment_geo = sf_geo

# %%
# Out:
#   File "<ipython-input-231-7a8816cf80c4>", line 3
#     print(len(sf_geo)
#                      ^
# SyntaxError: unexpected EOF while parsing

# %%
employment_geo.columns
# Out:
# Index(['ALAND10', 'AWATER10', 'BLOCKCE10', 'COUNTYFP10', 'EDHEALTH_R',
#        'EDHEALTH_W', 'FUNCSTAT10', 'GEOID10', 'INTPTLAT10', 'INTPTLON10',
#        'LEISURE_RA', 'LEISURE_WA', 'MTFCC10', 'NAME10', 'OTHER_RAC',
#        'OTHER_WAC', 'RETAIL_RAC', 'RETAIL_WAC', 'STATEFP10', 'TOTAL_EMP_',
#        'TOTAL_EM_1', 'TRACTCE10', 'UACE10', 'UATYP10', 'UR10', 'createda_1',
#        'createdate', 'geometry', 'h_geocode', 'w_geocode'],
#       dtype='object')

# %%
rename  = ['ALAND10', 'AWATER10', 'BLOCKCE10', 'COUNTYFP10', 'EDHEALTH_RAC',
'EDHEALTH_WAC', 'FUNCSTAT10', 'GEOID10', 'INTPTLAT10', 'INTPTLON10',
'LEISURE_RAC', 'LEISURE_WAC', 'MTFCC10', 'NAME10', 'OTHER_RAC',
'OTHER_WAC', 'RETAIL_RAC', 'RETAIL_WAC', 'STATEFP10', 'TOTAL_EMP_RAC',
'TOTAL_EMP_WAC', 'TRACTCE10', 'UACE10', 'UATYP10', 'UR10', 'createda_1',
'createdate', 'geometry', 'h_geocode', 'w_geocode']

# %%
employment_geo.columns = rename

# %%
employment.columns
# Out:
# Index(['Unnamed: 0', 'ALAND10', 'AWATER10', 'BLOCKCE10', 'COUNTYFP10',
#        'FUNCSTAT10', 'GEOID10', 'INTPTLAT10', 'INTPTLON10', 'MTFCC10',
#        'NAME10', 'STATEFP10', 'TRACTCE10', 'UACE10', 'UATYP10', 'UR10',
#        'geometry', 'w_geocode', 'createdate_WAC', 'TOTAL_EMP_WAC',
#        'RETAIL_WAC', 'EDHEALTH_WAC', 'LEISURE_WAC', 'OTHER_WAC', 'h_geocode',
#        'createdate_RAC', 'TOTAL_EMP_RAC', 'RETAIL_RAC', 'EDHEALTH_RAC',
#        'LEISURE_RAC', 'OTHER_RAC'],
#       dtype='object')

# %%
drop =['Unnamed: 0', 
'COUNTYFP10',
'FUNCSTAT10', 'INTPTLAT10', 'INTPTLON10', 'MTFCC10',
'NAME10', 'STATEFP10', 'TRACTCE10', 'UACE10', 'UATYP10', 'UR10',
'w_geocode', 'createdate_WAC', 'h_geocode',
'createdate_RAC']

# %%
employment.head()
# Out:
#    Unnamed: 0  ALAND10  AWATER10  BLOCKCE10  COUNTYFP10 FUNCSTAT10  \
# 0           0    16958         0       2002          75          S
# 1           1    16823         0       2000          75          S
# 2           2    17020         0       3004          75          S
# 3           3    16415         0       1003          75          S
# 4           4    17523         0       4001          75          S
#
#           GEOID10  INTPTLAT10  INTPTLON10 MTFCC10      NAME10  STATEFP10  \
# 0  60750213002002   37.750066 -122.441075   G5040  Block 2002          6
# 1  60750213002000   37.750196 -122.438933   G5040  Block 2000          6
# 2  60750205003004   37.756794 -122.436270   G5040  Block 3004          6
# 3  60750212001003   37.753529 -122.437050   G5040  Block 1003          6
# 4  60750211004001   37.755758 -122.433400   G5040  Block 4001          6
#
#    TRACTCE10   UACE10 UATYP10 UR10  \
# 0      21300  78904.0       U    U
# 1      21300  78904.0       U    U
# ...

# %%
for column in drop:
    employment = employment.drop(drop,axis = 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-244-b5a39105b643> in <module>()
#       1 for column in drop:
# ----> 2     employment = employment.drop(drop,axis = 1)
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    1905                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1906             else:
# -> 1907                 new_axis = axis.drop(labels, errors=errors)
#    1908             dropped = self.reindex(**{axis_name: new_axis})
#    1909             try:
#
# C:\Anaconda\lib\site-packages\pandas\indexes\base.py in drop(self, labels, errors)
#    3260             if errors != 'ignore':
#    3261                 raise ValueError('labels %s not contained in axis' %
# -> 3262                                  labels[mask])
#    3263             indexer = indexer[~mask]
# ...

# %%
employment_geo.head()
# Out:
#    ALAND10  AWATER10 BLOCKCE10 COUNTYFP10  EDHEALTH_RAC  EDHEALTH_WAC  \
# 0    16958         0      2002        075          16.0           7.0
# 1    16823         0      2000        075          19.0           0.0
# 2    17020         0      3004        075          25.0           0.0
# 3    16415         0      1003        075          10.0           8.0
# 4    17523         0      4001        075          22.0           1.0
#
#   FUNCSTAT10     GEOID10   INTPTLAT10    INTPTLON10  LEISURE_RAC  LEISURE_WAC  \
# 0          S  2147483647  +37.7500665  -122.4410751          6.0          0.0
# 1          S  2147483647  +37.7501958  -122.4389330          9.0          0.0
# 2          S  2147483647  +37.7567937  -122.4362701          6.0          0.0
# 3          S  2147483647  +37.7535291  -122.4370498          5.0          0.0
# 4          S  2147483647  +37.7557580  -122.4334002          5.0          0.0
#
# ...

# %%
for column in drop: 
    employment_geo = employment_geo.drop(drop,axis = 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-246-9f617938d5b2> in <module>()
#       1 for column in drop:
# ----> 2     employment_geo = employment_geo.drop(drop,axis = 1)
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    1905                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1906             else:
# -> 1907                 new_axis = axis.drop(labels, errors=errors)
#    1908             dropped = self.reindex(**{axis_name: new_axis})
#    1909             try:
#
# C:\Anaconda\lib\site-packages\pandas\indexes\base.py in drop(self, labels, errors)
#    3260             if errors != 'ignore':
#    3261                 raise ValueError('labels %s not contained in axis' %
# -> 3262                                  labels[mask])
# ...

# %%
df.head()
# Out:
#    ALAND10  AWATER10  BLOCKCE10  COUNTYFP10         GEOID10  TRACTCE10  \
# 0    16958         0       2002          75  60750213002002      21300
# 1    16823         0       2000          75  60750213002000      21300
# 2    17020         0       3004          75  60750205003004      20500
# 3    16415         0       1003          75  60750212001003      21200
# 4    17523         0       4001          75  60750211004001      21100
#
#                                             geometry  TOTAL_EMP_WAC  \
# 0  POLYGON ((-122.440616 37.750902, -122.440459 3...            7.0
# 1  POLYGON ((-122.438397 37.750226, -122.43832 37...            1.0
# 2  POLYGON ((-122.435808 37.757623, -122.435642 3...            1.0
# 3  POLYGON ((-122.436527 37.75354, -122.436454 37...           22.0
# 4  POLYGON ((-122.432331 37.756227, -122.432254 3...            3.0
#
#    RETAIL_WAC  EDHEALTH_WAC  LEISURE_WAC  OTHER_WAC  TOTAL_EMP_RAC  \
# ...

# %%
employment.to_csv('E:\Transit-Casa-Alex\Output\Employment (LEHD)/Combined_Employment.csv')

# %%
df_geo.head()
# Out:
#    ALAND10  AWATER10 BLOCKCE10 COUNTYFP10     GEOID10 TRACTCE10  \
# 0    16958         0      2002        075  2147483647    021300
# 1    16823         0      2000        075  2147483647    021300
# 2    17020         0      3004        075  2147483647    020500
# 3    16415         0      1003        075  2147483647    021200
# 4    17523         0      4001        075  2147483647    021100
#
#                                             geometry  TOTAL_EMP_WAC  \
# 0  POLYGON ((-122.440616 37.750902, -122.440459 3...           61.0
# 1  POLYGON ((-122.438397 37.750226, -122.43832 37...           79.0
# 2  POLYGON ((-122.435808 37.757623, -122.435642 3...           84.0
# 3  POLYGON ((-122.436527 37.75354, -122.436454 37...           58.0
# 4  POLYGON ((-122.432331 37.756227, -122.432254 3...           90.0
#
#    RETAIL_WAC  EDHEALTH_WAC  LEISURE_WAC  OTHER_WAC  TOTAL_EMP_RAC  \
# 0         0.0           7.0          0.0        0.0            7.0
# ...

# %%
df_geo.to_file('E:/Transit-Casa-Alex/Output/Employment (LEHD)/Combined_Employment.shp',driver = 'ESRI Shapefile')

# %%
buffers = gp.read_file('E:/Transit-Casa-Alex/Output/Buffers/Tenth/Buffers/Buffers_Tenth_GCS.shp')

# %%
df_geo.crs = buffers.crs

# %%
buffers.crs
# Out:
# {'init': 'epsg:4269'}

# %%
buffers.plot(ax = df_geo.plot())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-117-b89f5a9225ac> in <module>()
# ----> 1 buffers.plot(ax = df_geo.plot())
#
# C:\Anaconda\lib\site-packages\geopandas\geodataframe.py in plot(self, *args, **kwargs)
#     445     def plot(self, *args, **kwargs):
#     446
# --> 447         return plot_dataframe(self, *args, **kwargs)
#     448
#     449     plot.__doc__ = plot_dataframe.__doc__
#
# C:\Anaconda\lib\site-packages\geopandas\plotting.py in plot_dataframe(s, column, cmap, color, linewidth, categorical, legend, ax, scheme, k, vmin, vmax, figsize, **color_kwds)
#     238         return plot_series(s.geometry, cmap=cmap, color=color,
#     239                            ax=ax, linewidth=linewidth, figsize=figsize,
# --> 240                            **color_kwds)
#     241     else:
#     242         if s[column].dtype is np.dtype('O'):
#
# ...

# %% [markdown]
# # Bring in the pop and housing unit census block data

# %%
pop = gp.read_file('E:/Transit-Casa-Alex/Input/2010 Population (Blocks)/Population_Houses_Blocks.shp',crs = 'crs')

# %%
pop.head()
# Out:
#   BLOCKCE        BLOCKID10 COUNTYFP10  HOUSING10 PARTFLG  POP10 STATEFP10  \
# 0    3028  060750313023028        075         33       N    116        06
# 1    6025  060750255006025        075          1       N      1        06
# 2    1010  060750261001010        075         64       N    237        06
# 3    1001  060750201001001        075          0       N      0        06
# 4    2006  060750178022006        075        145       N    196        06
#
#   TRACTCE10                                           geometry
# 0    031302  POLYGON ((-122.469306 37.712526, -122.468748 3...
# 1    025500  POLYGON ((-122.442387 37.725793, -122.443066 3...
# 2    026100  POLYGON ((-122.439127 37.720972, -122.439382 3...
# 3    020100  POLYGON ((-122.418618 37.773053, -122.418855 3...
# 4    017802  POLYGON ((-122.413587 37.77466, -122.413161 37...

# %%
pop.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 16648 entries, 0 to 16647
# Data columns (total 9 columns):
# BLOCKCE       16648 non-null object
# BLOCKID10     16648 non-null int64
# COUNTYFP10    16648 non-null object
# HOUSING10     16648 non-null int64
# PARTFLG       16648 non-null object
# POP10         16648 non-null int64
# STATEFP10     16648 non-null object
# TRACTCE10     16648 non-null object
# geometry      16648 non-null object
# dtypes: int64(3), object(6)
# memory usage: 1.1+ MB

# %%
pop['BLOCKID10'] = pop.BLOCKID10.apply(lambda row: int(row))

# %%
df_geo.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 16648 entries, 0 to 9261
# Data columns (total 17 columns):
# ALAND10          16648 non-null int64
# AWATER10         16648 non-null int64
# BLOCKCE10        16648 non-null object
# COUNTYFP10       16648 non-null object
# GEOID10          16648 non-null int64
# TRACTCE10        16648 non-null object
# geometry         16648 non-null object
# TOTAL_EMP_WAC    12795 non-null float64
# RETAIL_WAC       10464 non-null float64
# EDHEALTH_WAC     10464 non-null float64
# LEISURE_WAC      10464 non-null float64
# OTHER_WAC        10464 non-null float64
# TOTAL_EMP_RAC    10464 non-null float64
# RETAIL_RAC       12795 non-null float64
# EDHEALTH_RAC     12795 non-null float64
# LEISURE_RAC      12795 non-null float64
# OTHER_RAC        12795 non-null float64
# dtypes: float64(10), int64(3), object(4)
# memory usage: 2.3+ MB

# %%
df_geo.GEOID10.unique()
# Out:
# array([2147483647], dtype=int64)

# %%
pop.head()
# Out:
#   BLOCKCE       BLOCKID10 COUNTYFP10  HOUSING10 PARTFLG  POP10 STATEFP10  \
# 0    3028  60750313023028        075         33       N    116        06
# 1    6025  60750255006025        075          1       N      1        06
# 2    1010  60750261001010        075         64       N    237        06
# 3    1001  60750201001001        075          0       N      0        06
# 4    2006  60750178022006        075        145       N    196        06
#
#   TRACTCE10                                           geometry
# 0    031302  POLYGON ((-122.469306 37.712526, -122.468748 3...
# 1    025500  POLYGON ((-122.442387 37.725793, -122.443066 3...
# 2    026100  POLYGON ((-122.439127 37.720972, -122.439382 3...
# 3    020100  POLYGON ((-122.418618 37.773053, -122.418855 3...
# 4    017802  POLYGON ((-122.413587 37.77466, -122.413161 37...

# %%
print(len(df_geo))
print(len(pop))
len(block_data)
# Out:
# 16648
# 16648
# 16648

# %%
block_data.head()
# Out:
#    Unnamed: 0  ALAND10  AWATER10  BLOCKCE10  COUNTYFP10_x FUNCSTAT10  \
# 0           0    16958         0       2002            75          S
# 1           1    16823         0       2000            75          S
# 2           2    17020         0       3004            75          S
# 3           3    16415         0       1003            75          S
# 4           4    17523         0       4001            75          S
#
#           GEOID10  INTPTLAT10  INTPTLON10 MTFCC10      NAME10  STATEFP10_x  \
# 0  60750213002002   37.750066 -122.441075   G5040  Block 2002            6
# 1  60750213002000   37.750196 -122.438933   G5040  Block 2000            6
# 2  60750205003004   37.756794 -122.436270   G5040  Block 3004            6
# 3  60750212001003   37.753529 -122.437050   G5040  Block 1003            6
# 4  60750211004001   37.755758 -122.433400   G5040  Block 4001            6
#
#    TRACTCE10_x   UACE10 UATYP10 UR10  \
# 0        21300  78904.0       U    U
# ...

# %%
block_data.columns
# Out:
# Index(['Unnamed: 0', 'ALAND10', 'AWATER10', 'BLOCKCE10', 'COUNTYFP10_x',
#        'FUNCSTAT10', 'GEOID10', 'INTPTLAT10', 'INTPTLON10', 'MTFCC10',
#        'NAME10', 'STATEFP10_x', 'TRACTCE10_x', 'UACE10', 'UATYP10', 'UR10',
#        'geometry_x', 'w_geocode', 'createdate_WAC', 'TOTAL_EMP_WAC',
#        'RETAIL_WAC', 'EDHEALTH_WAC', 'LEISURE_WAC', 'OTHER_WAC', 'h_geocode',
#        'createdate_RAC', 'TOTAL_EMP_RAC', 'RETAIL_RAC', 'EDHEALTH_RAC',
#        'LEISURE_RAC', 'OTHER_RAC', 'BLOCKCE', 'BLOCKID10', 'COUNTYFP10_y',
#        'HOUSING10', 'PARTFLG', 'POP10', 'STATEFP10_y', 'TRACTCE10_y',
#        'geometry_y'],
#       dtype='object')

# %%
drop  = ['Unnamed: 0', 'COUNTYFP10_x',
       'FUNCSTAT10', 'INTPTLAT10', 'INTPTLON10', 'MTFCC10',
       'NAME10', 'STATEFP10_x', 'TRACTCE10_x', 'UACE10', 'UATYP10', 'UR10',
       'w_geocode', 'createdate_WAC', 'h_geocode',
       'createdate_RAC', 'BLOCKCE', 'BLOCKID10', 'COUNTYFP10_y',
       'PARTFLG', 'STATEFP10_y', 'TRACTCE10_y',
       'geometry_y'],

# %%
block_data.head()
# Out:
#    Unnamed: 0  ALAND10  AWATER10  BLOCKCE10  COUNTYFP10_x FUNCSTAT10  \
# 0           0    16958         0       2002            75          S
# 1           1    16823         0       2000            75          S
# 2           2    17020         0       3004            75          S
# 3           3    16415         0       1003            75          S
# 4           4    17523         0       4001            75          S
#
#           GEOID10  INTPTLAT10  INTPTLON10 MTFCC10      NAME10  STATEFP10_x  \
# 0  60750213002002   37.750066 -122.441075   G5040  Block 2002            6
# 1  60750213002000   37.750196 -122.438933   G5040  Block 2000            6
# 2  60750205003004   37.756794 -122.436270   G5040  Block 3004            6
# 3  60750212001003   37.753529 -122.437050   G5040  Block 1003            6
# 4  60750211004001   37.755758 -122.433400   G5040  Block 4001            6
#
#    TRACTCE10_x   UACE10 UATYP10 UR10  \
# 0        21300  78904.0       U    U
# ...

# %%
for column in drop:
    block_data = block_data.drop(column,axis =1)

# %%
block_data.head()
# Out:
#    ALAND10  AWATER10  BLOCKCE10         GEOID10  \
# 0    16958         0       2002  60750213002002
# 1    16823         0       2000  60750213002000
# 2    17020         0       3004  60750205003004
# 3    16415         0       1003  60750212001003
# 4    17523         0       4001  60750211004001
#
#                                           geometry_x  TOTAL_EMP_WAC  \
# 0  POLYGON ((-122.440616 37.750902, -122.440459 3...            7.0
# 1  POLYGON ((-122.438397 37.750226, -122.43832 37...            1.0
# 2  POLYGON ((-122.435808 37.757623, -122.435642 3...            1.0
# 3  POLYGON ((-122.436527 37.75354, -122.436454 37...           22.0
# 4  POLYGON ((-122.432331 37.756227, -122.432254 3...            3.0
#
#    RETAIL_WAC  EDHEALTH_WAC  LEISURE_WAC  OTHER_WAC  TOTAL_EMP_RAC  \
# 0         0.0           7.0          0.0        0.0           61.0
# 1         0.0           0.0          0.0        1.0           79.0
# ...

# %%
block_data['geometry'] = block_data['geometry_x']

# %%
block_data_geo = gp.GeoDataFrame?

# %%
block_data_geo = gp.GeoDataFrame(block_data, geometry = 'geometry')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-198-d453863b1a21> in <module>()
# ----> 1 block_data_geo = gp.GeoDataFrame(block_data, geometry = 'geometry')
#
# C:\Anaconda\lib\site-packages\geopandas\geodataframe.py in __init__(self, *args, **kwargs)
#      55         self.crs = crs
#      56         if geometry is not None:
# ---> 57             self.set_geometry(geometry, inplace=True)
#      58         self._invalidate_sindex()
#      59
#
# C:\Anaconda\lib\site-packages\geopandas\geodataframe.py in set_geometry(self, col, drop, inplace, crs)
#     154         # Check that we are using a listlike of geometries
#     155         if not all(isinstance(item, BaseGeometry) or not item for item in level):
# --> 156             raise TypeError("Input geometry column must contain valid geometry objects.")
#     157         frame[geo_column_name] = level
# ...

# %%
block_data_geo.head()
# Out:
#    ALAND10  AWATER10  BLOCKCE10         GEOID10  \
# 0    16958         0       2002  60750213002002
# 1    16823         0       2000  60750213002000
# 2    17020         0       3004  60750205003004
# 3    16415         0       1003  60750212001003
# 4    17523         0       4001  60750211004001
#
#                                           geometry_x  TOTAL_EMP_WAC  \
# 0  POLYGON ((-122.440616 37.750902, -122.440459 3...            7.0
# 1  POLYGON ((-122.438397 37.750226, -122.43832 37...            1.0
# 2  POLYGON ((-122.435808 37.757623, -122.435642 3...            1.0
# 3  POLYGON ((-122.436527 37.75354, -122.436454 37...           22.0
# 4  POLYGON ((-122.432331 37.756227, -122.432254 3...            3.0
#
#    RETAIL_WAC  EDHEALTH_WAC  LEISURE_WAC  OTHER_WAC  TOTAL_EMP_RAC  \
# 0         0.0           7.0          0.0        0.0           61.0
# 1         0.0           0.0          0.0        1.0           79.0
# ...
