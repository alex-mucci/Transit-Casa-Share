# %%
import pandas as pd
pd.set_option('max_columns',500)

# %%
split10 = pd.read_csv('E:/Transit-Casa-Alex/Output/Buffers/Split Buffers/2010_Split_Buffers_Tenth.csv')

# %%
split4 = pd.read_csv('E:/Transit-Casa-Alex/Output/Buffers/Split Buffers/2010_Split_Buffers_Quarter.csv')

# %%
split3 = pd.read_csv('E:/Transit-Casa-Alex/Output/Buffers/Split Buffers/2010_Split_Buffers_Third.csv')

# %%
split10.head()
# Out:
#    Unnamed: 0  BUFF_DIST  ORIG_FID  STOP_ID  STOP_LAT    STOP_LON   ALAND10  \
# 0           0      528.0         0      390  37.72119 -122.475096  466354.0
# 1           1      528.0         0      390  37.72119 -122.475096   17204.0
# 2           2      528.0         0      390  37.72119 -122.475096   10544.0
# 3           3      528.0         0      390  37.72119 -122.475096   14502.0
# 4           4      528.0         0      390  37.72119 -122.475096     718.0
#
#    AWATER10  BLOCKCE  BLOCKCE10     BLOCKID10      BLOCK_ID  COUNTYFP10  \
# 0       0.0     1005     1005.0  6.075033e+13  6.075033e+13          75
# 1       0.0     1012     1012.0  6.075033e+13  6.075033e+13          75
# 2       0.0     7011     7011.0  6.075031e+13  6.075031e+13          75
# 3       0.0     7012     7012.0  6.075031e+13  6.075031e+13          75
# 4       0.0     7013     7013.0  6.075031e+13  6.075031e+13          75
#
#    COUNTYFP_1  EDHLTH_RAC  EDHLTH_WAC  EMP_RAC  EMP_WAC FUNCSTAT10  \
# ...

# %%
#the Split_Area column should equal 20.096 for a buffer with a 528 ft radius, the error between the two can be considered a 
#rounding error
split10.groupby(by = 'STOP_ID').sum()
# Out:
#          Unnamed: 0  BUFF_DIST  ORIG_FID    STOP_LAT     STOP_LON    ALAND10  \
# STOP_ID
# 390             253    12144.0         0  867.587370 -2816.927208   589574.0
# 392             120     8448.0        16  604.242544 -1959.635360   388768.0
# 660             171    10032.0        38  716.754366 -2326.272353   198753.0
# 913              55     5808.0        33  414.911112 -1346.683822   291273.0
# 3001             78     6864.0        52  491.250890 -1591.148572   161627.0
# 3003            136     8976.0        85  642.291059 -2080.663065   252853.0
# 3004            136     8976.0       102  642.291518 -2080.667944   224462.0
# 3005            120     8448.0       112  604.532656 -1958.300448   207422.0
# 3006            171    10032.0       152  717.874055 -2325.475911   252215.0
# 3007             91     7392.0       126  528.997000 -1713.551420   203769.0
# 3008            105     7920.0       150  566.779770 -1835.948430   225135.0
# ...

# %%
split10.columns
# Out:
# Index(['Unnamed: 0', 'BUFF_DIST', 'ORIG_FID', 'STOP_ID', 'STOP_LAT',
#        'STOP_LON', 'ALAND10', 'AWATER10', 'BLOCKCE', 'BLOCKCE10', 'BLOCKID10',
#        'BLOCK_ID', 'COUNTYFP10', 'COUNTYFP_1', 'EDHLTH_RAC', 'EDHLTH_WAC',
#        'EMP_RAC', 'EMP_WAC', 'FUNCSTAT10', 'GEOID10', 'HOUSING10',
#        'INTPTLAT10', 'INTPTLON10', 'LEISER_RAC', 'LEISER_WAC', 'MTFCC10',
#        'NAME10', 'OTHER_RAC', 'OTHER_WAC', 'PARTFLG', 'POP10', 'RETAIL_RAC',
#        'RETAIL_WAC', 'STATEFP10_', 'STATEFP1_1', 'TRACTCE10_', 'TRACTCE1_1',
#        'UACE10', 'UATYP10', 'UR10', 'Unnamed_ 0', 'Unnamed__1', 'createda_1',
#        'createdate', 'geometry_y', 'h_geocode', 'w_geocode', 'AREA',
#        'index_right', 'BUFF_DIST_2', 'ORIG_FID_2', 'STOP_ID_2', 'STOP_LAT_2',
#        'STOP_LON_2', 'geometry', 'SPLIT_AREA', 'SPLIT_RATIO'],
#       dtype='object')

# %%
keep = ['EDHLTH_RAC', 'STOP_ID', 'EDHLTH_WAC',
       'EMP_RAC', 'EMP_WAC', 'HOUSING10',
       'LEISER_RAC', 'LEISER_WAC', 'OTHER_RAC', 
       'OTHER_WAC', 'POP10', 'RETAIL_RAC',
       'RETAIL_WAC', 'AREA','geometry', 'SPLIT_AREA', 'SPLIT_RATIO']

# %%
split10_2 = split10[keep]

# %%
split10_2.head()
# Out:
#    EDHLTH_RAC  STOP_ID  EDHLTH_WAC  EMP_RAC  EMP_WAC  HOUSING10  LEISER_RAC  \
# 0       107.0      390      4606.0    453.0   5477.0        535        59.0
# 1         4.0      390       118.0     17.0    240.0          0         4.0
# 2         5.0      390        30.0     20.0     34.0         15         2.0
# 3         7.0      390         0.0     41.0      1.0         32         5.0
# 4         1.0      390         NaN      2.0      NaN          0         0.0
#
#    LEISER_WAC  OTHER_RAC  OTHER_WAC  POP10  RETAIL_RAC  RETAIL_WAC  \
# 0       296.0      242.0      452.0   3169        45.0       123.0
# 1        25.0        6.0       21.0      0         3.0        76.0
# 2         0.0       11.0        4.0     60         2.0         0.0
# 3         0.0       28.0        1.0     77         1.0         0.0
# 4         NaN        1.0        NaN      0         0.0         NaN
#
#          AREA                                           geometry  SPLIT_AREA  \
# ...

# %%
split10_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51560 entries, 0 to 51559
# Data columns (total 17 columns):
# EDHLTH_RAC     41614 non-null float64
# STOP_ID        51560 non-null int64
# EDHLTH_WAC     41726 non-null float64
# EMP_RAC        41614 non-null float64
# EMP_WAC        41726 non-null float64
# HOUSING10      51560 non-null int64
# LEISER_RAC     41614 non-null float64
# LEISER_WAC     41726 non-null float64
# OTHER_RAC      41614 non-null float64
# OTHER_WAC      41726 non-null float64
# POP10          51560 non-null int64
# RETAIL_RAC     41614 non-null float64
# RETAIL_WAC     41726 non-null float64
# AREA           47058 non-null float64
# geometry       51560 non-null object
# SPLIT_AREA     51560 non-null float64
# SPLIT_RATIO    47058 non-null float64
# dtypes: float64(13), int64(3), object(1)
# memory usage: 6.7+ MB

# %%
scale = ['EDHLTH_RAC','EDHLTH_WAC','EMP_RAC','EMP_WAC','LEISER_RAC',
         'LEISER_WAC','OTHER_RAC','OTHER_WAC',
         'RETAIL_RAC','RETAIL_WAC','POP10','HOUSING10']

# %%
scale
# Out:
# ['EDHLTH_RAC',
#  'EDHLTH_WAC',
#  'EMP_RAC',
#  'EMP_WAC',
#  'LEISER_RAC',
#  'LEISER_WAC',
#  'OTHER_RAC',
#  'OTHER_WAC',
#  'RETAIL_RAC',
#  'RETAIL_WAC',
#  'POP10',
#  'HOUSING10']

# %%
split10_2.head()
# Out:
#    EDHLTH_RAC  STOP_ID  EDHLTH_WAC  EMP_RAC  EMP_WAC  HOUSING10  LEISER_RAC  \
# 0       107.0      390      4606.0    453.0   5477.0        535        59.0
# 1         4.0      390       118.0     17.0    240.0          0         4.0
# 2         5.0      390        30.0     20.0     34.0         15         2.0
# 3         7.0      390         0.0     41.0      1.0         32         5.0
# 4         1.0      390         NaN      2.0      NaN          0         0.0
#
#    LEISER_WAC  OTHER_RAC  OTHER_WAC  POP10  RETAIL_RAC  RETAIL_WAC  \
# 0       296.0      242.0      452.0   3169        45.0       123.0
# 1        25.0        6.0       21.0      0         3.0        76.0
# 2         0.0       11.0        4.0     60         2.0         0.0
# 3         0.0       28.0        1.0     77         1.0         0.0
# 4         NaN        1.0        NaN      0         0.0         NaN
#
#          AREA                                           geometry  SPLIT_AREA  \
# ...

# %%
split10_2.head()
# Out:
#    EDHLTH_RAC  STOP_ID  EDHLTH_WAC  EMP_RAC  EMP_WAC  HOUSING10  LEISER_RAC  \
# 0       107.0      390      4606.0    453.0   5477.0        535        59.0
# 1         4.0      390       118.0     17.0    240.0          0         4.0
# 2         5.0      390        30.0     20.0     34.0         15         2.0
# 3         7.0      390         0.0     41.0      1.0         32         5.0
# 4         1.0      390         NaN      2.0      NaN          0         0.0
#
#    LEISER_WAC  OTHER_RAC  OTHER_WAC  POP10  RETAIL_RAC  RETAIL_WAC  \
# 0       296.0      242.0      452.0   3169        45.0       123.0
# 1        25.0        6.0       21.0      0         3.0        76.0
# 2         0.0       11.0        4.0     60         2.0         0.0
# 3         0.0       28.0        1.0     77         1.0         0.0
# 4         NaN        1.0        NaN      0         0.0         NaN
#
#          AREA                                           geometry  SPLIT_AREA  \
# ...

# %%
for column in scale:
    name = column + '_SCALED'
    split10_2[name] = split10_2[column]*split10_2['SPLIT_RATIO']
# Out:
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
split10_3 = split10_2[['EDHLTH_RAC_SCALED', 'EDHLTH_WAC_SCALED',
       'EMP_RAC_SCALED', 'EMP_WAC_SCALED', 'LEISER_RAC_SCALED',
       'LEISER_WAC_SCALED', 'OTHER_RAC_SCALED', 'OTHER_WAC_SCALED',
       'RETAIL_RAC_SCALED', 'RETAIL_WAC_SCALED', 'POP10_SCALED',
       'HOUSING10_SCALED','STOP_ID']].groupby(by = 'STOP_ID',as_index = False).sum()

# %%
split10_3.head()
# Out:
#    STOP_ID  EDHLTH_RAC_SCALED  EDHLTH_WAC_SCALED  EMP_RAC_SCALED  \
# 0      390          27.003059         434.514459      122.858598
# 1      392          98.412984           7.902557      387.736656
# 2      660          70.748797          18.953505      338.623118
# 3      913          78.147960           1.745138      376.821605
# 4     3001           9.253711         108.506606       63.663333
#
#    EMP_WAC_SCALED  LEISER_RAC_SCALED  LEISER_WAC_SCALED  OTHER_RAC_SCALED  \
# 0      537.569378          18.670254          31.610569         61.756072
# 1      120.879861          52.155595          44.862426        201.140238
# 2      261.192332          50.837914          10.573595        185.931699
# 3       17.651898          56.115970           0.058914        211.086100
# 4     4637.668258           5.924808         352.961147         41.867562
#
#    OTHER_WAC_SCALED  RETAIL_RAC_SCALED  RETAIL_WAC_SCALED  POP10_SCALED  \
# ...

# %%
split10_3.columns
# Out:
# Index(['STOP_ID', 'EDHLTH_RAC', 'EDHLTH_WAC', 'EMP_RAC', 'EMP_WAC',
#        'HOUSING10', 'LEISER_RAC', 'LEISER_WAC', 'OTHER_RAC', 'OTHER_WAC',
#        'POP10', 'RETAIL_RAC', 'RETAIL_WAC', 'AREA', 'SPLIT_AREA',
#        'SPLIT_RATIO', 'EDHLTH_RAC_SCALED', 'EDHLTH_WAC_SCALED',
#        'EMP_RAC_SCALED', 'EMP_WAC_SCALED', 'LEISER_RAC_SCALED',
#        'LEISER_WAC_SCALED', 'OTHER_RAC_SCALED', 'OTHER_WAC_SCALED',
#        'RETAIL_RAC_SCALED', 'RETAIL_WAC_SCALED', 'POP10_SCALED',
#        'HOUSING10_SCALED'],
#       dtype='object')

# %%
print(len(split10_2))
len(split10_3)
# Out:
# 51560
# 3744

# %%
split10_3.to_csv('E:/Transit-Casa-Alex/Output/Census_Block_Estimation_File.csv')

# %%
#checked to make sure the group by was summing correctly
split10_2[split10_2['STOP_ID'] == 390]
# Out:
#     EDHLTH_RAC  STOP_ID  EDHLTH_WAC  EMP_RAC  EMP_WAC  HOUSING10  LEISER_RAC  \
# 0        107.0      390      4606.0    453.0   5477.0        535        59.0
# 1          4.0      390       118.0     17.0    240.0          0         4.0
# 2          5.0      390        30.0     20.0     34.0         15         2.0
# 3          7.0      390         0.0     41.0      1.0         32         5.0
# 4          1.0      390         NaN      2.0      NaN          0         0.0
# 5          1.0      390         0.0     16.0      1.0          0         2.0
# 6          2.0      390         0.0      9.0      2.0         14         0.0
# 7          NaN      390         NaN      NaN      NaN          0         NaN
# 8          4.0      390         NaN     11.0      NaN          9         1.0
# 9          5.0      390         0.0     14.0      4.0         16         2.0
# 10         NaN      390         NaN      NaN      NaN          0         NaN
# ...

# %% [markdown]
# # STOP HERE

# %%
geo = pd.merge(split10_3,split10_2,how = 'left',on = ['STOP_ID','GEOID10','SPLIT_RATIO'])

# %%
bad_blocks = pd.merge(t,split10_2,how = 'inner',on = ['STOP_ID','GEOID10'])

# %%
#create a geodataframe of the bad blocks and write it to a shapefile and then see if they are all in SM
import geopandas as gp
bb = gp.GeoDataFrame()

# %%
bb = gp.GeoDataFrame

# %%
t.head()
# Out:
#     STOP_ID         GEOID10  SPLIT_RATIO  Unnamed: 0  Unnamed: 0.1  ALAND10  \
# 12      390  60750332041000     0.999761         NaN           NaN      NaN
# 17      390  60750332041005     1.000111         NaN           NaN      NaN
# 18      390  60750332041006     0.881349         NaN           NaN      NaN
# 19      390  60750332041007     0.999023         NaN           NaN      NaN
# 21      390  60750332041013     0.203556         NaN           NaN      NaN
#
#     AWATER10  BLOCKCE10  COUNTYFP10 FUNCSTAT10  INTPTLAT10  INTPTLON10  \
# 12       NaN        NaN         NaN        NaN         NaN         NaN
# 17       NaN        NaN         NaN        NaN         NaN         NaN
# 18       NaN        NaN         NaN        NaN         NaN         NaN
# 19       NaN        NaN         NaN        NaN         NaN         NaN
# 21       NaN        NaN         NaN        NaN         NaN         NaN
#
#    MTFCC10 NAME10  STATEFP10  TRACTCE10  UACE10 UATYP10 UR10 geometry  \
# ...

# %%
bb.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 4541 entries, 0 to 4540
# Data columns (total 37 columns):
# STOP_ID           4541 non-null int64
# GEOID10           4541 non-null int64
# SPLIT_RATIO_x     4541 non-null float64
# Unnamed: 0        0 non-null float64
# Unnamed: 0.1      0 non-null float64
# ALAND10           0 non-null float64
# AWATER10          0 non-null float64
# BLOCKCE10         0 non-null float64
# COUNTYFP10        0 non-null float64
# FUNCSTAT10        0 non-null object
# INTPTLAT10        0 non-null float64
# INTPTLON10        0 non-null float64
# MTFCC10           0 non-null object
# NAME10            0 non-null object
# STATEFP10         0 non-null float64
# TRACTCE10         0 non-null float64
# UACE10            0 non-null float64
# UATYP10           0 non-null object
# UR10              0 non-null object
# geometry_x        0 non-null object
# h_geocode         0 non-null float64
# createdate_RAC    0 non-null float64
# ...

# %%
bb.head()
# Out:
#    STOP_ID         GEOID10  SPLIT_RATIO_x  Unnamed: 0  Unnamed: 0.1  ALAND10  \
# 0      390  60750332041000       0.999761         NaN           NaN      NaN
# 1      390  60750332041005       1.000111         NaN           NaN      NaN
# 2      390  60750332041006       0.881349         NaN           NaN      NaN
# 3      390  60750332041007       0.999023         NaN           NaN      NaN
# 4      390  60750332041013       0.203556         NaN           NaN      NaN
#
#    AWATER10  BLOCKCE10  COUNTYFP10 FUNCSTAT10  INTPTLAT10  INTPTLON10 MTFCC10  \
# 0       NaN        NaN         NaN        NaN         NaN         NaN     NaN
# 1       NaN        NaN         NaN        NaN         NaN         NaN     NaN
# 2       NaN        NaN         NaN        NaN         NaN         NaN     NaN
# 3       NaN        NaN         NaN        NaN         NaN         NaN     NaN
# 4       NaN        NaN         NaN        NaN         NaN         NaN     NaN
#
# ...

# %%
bb.to_file('BAD_BLOCKS.shp',driver = 'ESRI Shapefile')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-163-c57abfc601a2> in <module>()
# ----> 1 bb.to_file('BAD_BLOCKS.shp',driver = 'ESRI Shapefile')
#
# C:\Anaconda\lib\site-packages\geopandas\geodataframe.py in to_file(self, filename, driver, schema, **kwargs)
#     341         """
#     342         from geopandas.io.file import to_file
# --> 343         to_file(self, filename, driver, schema, **kwargs)
#     344
#     345     def to_crs(self, crs=None, epsg=None, inplace=False):
#
# C:\Anaconda\lib\site-packages\geopandas\io\file.py in to_file(df, filename, driver, schema, **kwargs)
#      56     """
#      57     if schema is None:
# ---> 58         schema = infer_schema(df)
#      59     filename = os.path.abspath(os.path.expanduser(filename))
#      60     with fiona.open(filename, 'w', driver=driver, crs=df.crs,
#
# ...
